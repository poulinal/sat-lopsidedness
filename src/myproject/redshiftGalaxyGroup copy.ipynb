# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %%
from myproject.getRedshiftGalaxyGroupData import GalaxyGroupData

# %%
galaxyGroupData = GalaxyGroupData()
galaxyGroupData.computeAllData()

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis

# %%
galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=False)
# Out:
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# Progress: Processing Galaxy Group ID 3732 / 3732

# %%
galaxyAnalysisZ0.setSnapshot(99)
# Out:
# Progress: 108/3733

# %%
galaxyAnalysisZ0.computeAllPlots()

# %%
galaxyAnalysisZ0.computeRedShiftPlots()
# Out:
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# Fetching data from http://www.tng-project.org/api/TNG300-1/ with params None and saving to temp
# Fetching data from http://www.tng-project.org/api/TNG300-1/snapshots/ with params None and saving to temp
# Total number of satellites to process: 75931
# jointime: nanbhalo 695799, progress: 0/22 satellites in this group, total progress: 0/75931 satellites
# Fetching data from https://www.tng-project.org/api/TNG300-1/snapshots/99/subhalos/695837/sublink/mpb.hdf5 with params None and saving to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/mergerTree/sublink_mpb_695837
# No merger tree for satellite 695837: 404 Client Error: Not Found for url: https://data-eu.tng-project.org/tree/sublink_mpb/L205n2500TNG/99/695837/hdf5/?token=06b46cea35a3e1c489dc
# Skipping subhalo 695837 (no merger tree available)
# jointime: nanbhalo 696132, progress: 0/21 satellites in this group, total progress: 22/75931 satellitess
# jointime: nanbhalo 696345, progress: 0/6 satellites in this group, total progress: 43/75931 satelliteses
# jointime: nanbhalo 696543, progress: 0/8 satellites in this group, total progress: 49/75931 satellites
# jointime: nanbhalo 696903, progress: 0/18 satellites in this group, total progress: 57/75931 satellites
# jointime: nanbhalo 697135, progress: 0/15 satellites in this group, total progress: 75/75931 satellitess
# jointime: nanbhalo 697482, progress: 0/20 satellites in this group, total progress: 90/75931 satellitess
# jointime: nanbhalo 697716, progress: 0/17 satellites in this group, total progress: 110/75931 satellitess
# jointime: nanbhalo 697913, progress: 0/17 satellites in this group, total progress: 127/75931 satellitess
# jointime: nanbhalo 698172, progress: 0/18 satellites in this group, total progress: 144/75931 satellitess
# jointime: nanbhalo 698463, progress: 0/15 satellites in this group, total progress: 162/75931 satellitess
# jointime: nanbhalo 698662, progress: 0/14 satellites in this group, total progress: 177/75931 satellitess
# Fetching data from https://www.tng-project.org/api/TNG300-1/snapshots/99/subhalos/698801/sublink/mpb.hdf5 with params None and saving to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/mergerTree/sublink_mpb_698801
# No merger tree for satellite 698801: 404 Client Error: Not Found for url: https://data-eu.tng-project.org/tree/sublink_mpb/L205n2500TNG/99/698801/hdf5/?token=db1b8dfd50acdc7c43eb
# Skipping subhalo 698801 (no merger tree available)
# jointime: nanbhalo 698832, progress: 0/23 satellites in this group, total progress: 191/75931 satellitess
# Fetching data from https://www.tng-project.org/api/TNG300-1/snapshots/99/subhalos/698966/sublink/mpb.hdf5 with params None and saving to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/mergerTree/sublink_mpb_698966
# No merger tree for satellite 698966: 404 Client Error: Not Found for url: https://data-eu.tng-project.org/tree/sublink_mpb/L205n2500TNG/99/698966/hdf5/?token=fae367780aa7f7ede979
# Skipping subhalo 698966 (no merger tree available)
# Fetching data from https://www.tng-project.org/api/TNG300-1/snapshots/99/subhalos/698996/sublink/mpb.hdf5 with params None and saving to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/mergerTree/sublink_mpb_698996
# No merger tree for satellite 698996: 404 Client Error: Not Found for url: https://data-eu.tng-project.org/tree/sublink_mpb/L205n2500TNG/99/698996/hdf5/?token=5f473a3633975dd67d0a
# Skipping subhalo 698996 (no merger tree available)
# jointime: nanbhalo 699126, progress: 0/26 satellites in this group, total progress: 214/75931 satellitess
# jointime: nanbhalo 699417, progress: 0/27 satellites in this group, total progress: 240/75931 satellitess
# jointime: nanbhalo 699685, progress: 0/14 satellites in this group, total progress: 267/75931 satellitess
# jointime: nanbhalo 699856, progress: 0/23 satellites in this group, total progress: 281/75931 satellitess
# jointime: nanbhalo 700067, progress: 0/24 satellites in this group, total progress: 304/75931 satellitess
# jointime: nanbhalo 700293, progress: 0/15 satellites in this group, total progress: 328/75931 satellitess
# jointime: nanbhalo 700629, progress: 0/17 satellites in this group, total progress: 343/75931 satellitess
# jointime: nanbhalo 700888, progress: 0/10 satellites in this group, total progress: 360/75931 satellitess
# jointime: nanbhalo 701171, progress: 0/23 satellites in this group, total progress: 370/75931 satellites
# jointime: nanbhalo 701421, progress: 0/19 satellites in this group, total progress: 393/75931 satellitess
# Processing subhalo 701443, progress: 5/19 satellites in this group, total progress: 398/75931 satellites
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 galaxyAnalysisZ0.computeRedShiftPlots()
#
# File ~/git/sat-lopsidedness/src/myproject/redshiftGalaxyAnalysis.py:50, in GalaxyAnalysis.computeRedShiftPlots(self)
#      49 def computeRedShiftPlots(self):
# ---> 50     self.plot_joining_redshift_for_all_mass_bins(self.scratchPlotDirc)
#
# File ~/git/sat-lopsidedness/src/myproject/redshiftGalaxyAnalysis.py:1408, in plot_joining_redshift_for_all_mass_bins(self, plot_dirc)
#    1406 def plot_joining_redshift_for_all_mass_bins(self, plot_dirc : str = None):
#    1407     list_of_mass_list_galaxy_groups = [self.filtered_gt13_ls13p5_list_of_galaxy_groups, self.filtered_gt13p5_ls14_list_of_galaxy_groups, self.filtered_gt14_ls14p5_list_of_galaxy_groups, self.filtered_gt14p5_ls15_list_of_galaxy_groups, self.filtered_gt15_list_of_galaxy_groups]
# -> 1408     mass_bin_labels = ['$13<M_{200}<13.5$', '$13.5<M_{200}<14$', '$14<M_{200}<14.5$', '$14.5<M_{200}<15$', '$M_{200}>15$']
#    1409     list_of_mass_bin_galaxy_groups = list(zip(list_of_mass_list_galaxy_groups, mass_bin_labels))
#    1410     # self.get_satellite_join_time(list_of_mass_bin_galaxy_groups)
#
# File <string>:5, in plot_joining_redshift_distribution_by_mass_bins(self, listGG)
#
# File <string>:43, in get_satellite_join_time(self, listGG, rewrite)
#
# File ~/git/sat-lopsidedness/src/myproject/utilities/joinTime.py:67, in JoinTime.computeJoinTimes(self, ID, hostID, L, halfbox, fname)
#      65 snapnum= f['SnapNum'][:]
#      66 #grVel = f['GroupVel'][:]
# ---> 67 subVel = f['SubhaloVel'][:]
#      68 subMasstype = f['SubhaloMassType'][:]
#      69 progID = f['SubfindID'][:]
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:257, in h5py.h5o.open()
#
# File h5py/h5i.pyx:44, in h5py.h5i.wrap_identifier()
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:

# %%
galaxyAnalysisZ0.plot_pairwise_polar_difference_across_redshifts()
# Out:
# GATHERING FOR SNAPSHOT: 99
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 99 from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# GATHERING FOR SNAPSHOT: 91y Group ID 3732 / 3732
# Progress: 3367/3367
# Loaded 3367 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 91 from /scratch/poulin.al/lopsided/TNG300-1/z0p1/data/galaxy_data_TNG300-1.hdf5
# total to process: 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# GATHERING FOR SNAPSHOT: 84y Group ID 3367 / 3367
# Progress: 3006/3006
# Loaded 3006 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 84 from /scratch/poulin.al/lopsided/TNG300-1/z0p2/data/galaxy_data_TNG300-1.hdf5
# total to process: 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# GATHERING FOR SNAPSHOT: 78y Group ID 3006 / 3006
# Progress: 2664/2664
# Loaded 2664 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 78 from /scratch/poulin.al/lopsided/TNG300-1/z0p3/data/galaxy_data_TNG300-1.hdf5
# total to process: 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# GATHERING FOR SNAPSHOT: 72y Group ID 2664 / 2664
# Progress: 2361/2361
# Loaded 2361 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 72 from /scratch/poulin.al/lopsided/TNG300-1/z0p4/data/galaxy_data_TNG300-1.hdf5
# total to process: 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# GATHERING FOR SNAPSHOT: 67y Group ID 2361 / 2361
# Progress: 2054/2054
# Loaded 2054 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 67 from /scratch/poulin.al/lopsided/TNG300-1/z0p5/data/galaxy_data_TNG300-1.hdf5
# total to process: 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# GATHERING FOR SNAPSHOT: 59y Group ID 2054 / 2054
# Progress: 1531/1531
# Loaded 1531 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 59 from /scratch/poulin.al/lopsided/TNG300-1/z0p7/data/galaxy_data_TNG300-1.hdf5
# total to process: 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# GATHERING FOR SNAPSHOT: 50y Group ID 1531 / 1531
# Progress: 900/900
# Loaded 900 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 50 from /scratch/poulin.al/lopsided/TNG300-1/z1p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# GATHERING FOR SNAPSHOT: 40y Group ID 900 / 900
# Progress: 313/313
# Loaded 313 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 40 from /scratch/poulin.al/lopsided/TNG300-1/z1p5/data/galaxy_data_TNG300-1.hdf5
# total to process: 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# GATHERING FOR SNAPSHOT: 33y Group ID 313 / 313
# Progress: 74/74
# Loaded 74 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 33 from /scratch/poulin.al/lopsided/TNG300-1/z2p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# GATHERING FOR SNAPSHOT: 25y Group ID 74 / 74
# Progress: 2/2
# Loaded 2 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 25 from /scratch/poulin.al/lopsided/TNG300-1/z3p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# COMPUTING FOR redshift index: 0, label: $13<M_{200}<13.5$, z=z0p0
# Total Galaxy Groups to process: 3032 with pairs : 228318
# Processing Subhalo 12/12 in Galaxy Group ID 1099 with total pairs 663
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1199 with total pairs 171
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 1299 with total pairs 450
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 1401 with total pairs 660
# Intermediate save after processing 400 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 1502 with total pairs 120
# Intermediate save after processing 500 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 1604 with total pairs 105
# Intermediate save after processing 600 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 1705 with total pairs 916
# Intermediate save after processing 700 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 1806 with total pairs 21120
# Intermediate save after processing 800 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 1909 with total pairs 21553
# Intermediate save after processing 900 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 2014 with total pairs 28456
# Intermediate save after processing 1000 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 2115 with total pairs 785
# Intermediate save after processing 1100 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 2219 with total pairs 10105
# Intermediate save after processing 1200 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 2325 with total pairs 28451
# Intermediate save after processing 1300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 2436 with total pairs 455
# Intermediate save after processing 1400 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 2547 with total pairs 6 666
# Intermediate save after processing 1500 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 2657 with total pairs 28780
# Intermediate save after processing 1600 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 2782 with total pairs 21665
# Intermediate save after processing 1700 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 2894 with total pairs 21555
# Intermediate save after processing 1800 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 3018 with total pairs 1566
# Intermediate save after processing 1900 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 3137 with total pairs 1066
# Intermediate save after processing 2000 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 3274 with total pairs 2166
# Intermediate save after processing 2100 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 3408 with total pairs 2855
# Intermediate save after processing 2200 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 3559 with total pairs 2145
# Intermediate save after processing 2300 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 3711 with total pairs 1591
# Intermediate save after processing 2400 galaxy groups.
# Processing Subhalo 2/2 in Galaxy Group ID 3881 with total pairs 1045
# Intermediate save after processing 2500 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 4117 with total pairs 2890
# Intermediate save after processing 2600 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 4494 with total pairs 1566
# Intermediate save after processing 2700 galaxy groups.
# Processing Subhalo 17/17 in Galaxy Group ID 709 with total pairs 136
# Intermediate save after processing 2800 galaxy groups.
# Processing Subhalo 23/23 in Galaxy Group ID 863 with total pairs 253
# Intermediate save after processing 2900 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 967 with total pairs 120
# Intermediate save after processing 3000 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 999 with total pairs 661
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 0
# Warning: ax is a numpy array, using the first axes in the array.
# COMPUTING FOR redshift index: 0, label: $13.5<M_{200}<14$, z=z0p0
# Total Galaxy Groups to process: 420 with pairs : 253173
# Processing Subhalo 19/37 in Galaxy Group ID 165 with total pairs 6661
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Processing Subhalo 40/40 in Galaxy Group ID 387 with total pairs 7805
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 38/38 in Galaxy Group ID 494 with total pairs 7038
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 39/39 in Galaxy Group ID 611 with total pairs 7415
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 25/25 in Galaxy Group ID 783 with total pairs 300
# Intermediate save after processing 400 galaxy groups.
# Processing Subhalo 23/23 in Galaxy Group ID 946 with total pairs 253
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 1
# Warning: ax is a numpy array, using the first axes in the array.
# COMPUTING FOR redshift index: 0, label: $14<M_{200}<14.5$, z=z0p0
# Total Galaxy Groups to process: 268 with pairs : 1220564
# Processing Subhalo 85/85 in Galaxy Group ID 202 with total pairs 357028
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 42/42 in Galaxy Group ID 348 with total pairs 861503
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 57/57 in Galaxy Group ID 99 with total pairs 1596210
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 galaxyAnalysisZ0.plot_pairwise_polar_difference_across_redshifts()
#
# File ~/git/sat-lopsidedness/src/myproject/redshiftGalaxyAnalysis.py:1470, in plot_pairwise_polar_difference_across_redshifts(self, plot_dirc)
#    1468 for snapshot_index, snapshot in enumerate(self.snapshot_dic.keys()):
#    1469     print(f"GATHERING FOR SNAPSHOT: {snapshot}")
# -> 1470     list_galaxy_group = self.load_galaxy_groups_for_snapshot_sim(snapshot, self.sim)
#    1471     list_galaxy_group_gt13_ls13p5, list_galaxy_group_gt13p5_ls14, list_galaxy_group_gt14_ls14p5, list_galaxy_group_gt14p5_ls15, list_galaxy_group_gt15 = self.initializeMassSubgroups(list_galaxy_group)
#    1472     group_list = []
#
# File ~/git/sat-lopsidedness/src/myproject/redshiftGalaxyAnalysis.py:1430, in overlay_polar_pairwise_across_redshifts(self, listRedshiftGG, plot_dirc, polar_plotter, polar_fig, polar_ax, mrlOrPolar, plotRows, plotCols)
#    1428 for i, (listGalaxyGroup, label) in enumerate(listGG):
#    1429     print(f"COMPUTING FOR redshift index: {redshift_index}, label: {label}")
# -> 1430     if mrlOrPolar == 'mrl':
#    1431         pairwise_polar_differences = listGalaxyGroup.compute_mrl_distribution_of_polar_differences(parallelize=False, tempSaveDir=f'{self.scratchDataDirc}/MRL_values_{label}_{self.plotIdentifier}', rewrite=self.generalRewrite)
#    1432     else:
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
