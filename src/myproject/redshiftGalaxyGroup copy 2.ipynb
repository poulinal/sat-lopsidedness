# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis

# %%
galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=True)
# Out:
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# Progress: Processing Galaxy Group ID 3732 / 3732

# %%
galaxyAnalysisZ0.plot_pairwise_polar_difference_across_redshifts()
# Out:
# Processing Subhalo 17/17 in Galaxy Group ID 1000 with total pairs 13615choosing ax, 5
# Total Galaxy Groups to process: 2055 with pairs : 458779
# Processing Subhalo 5/5 in Galaxy Group ID 1003 with total pairs 10276choosing ax, 0
# Total Galaxy Groups to process: 212 with pairs : 419574
# Processing Subhalo 50/50 in Galaxy Group ID 97 with total pairs 12255choosing ax, 1
# Total Galaxy Groups to process: 90 with pairs : 1036148
# Processing Subhalo 80/80 in Galaxy Group ID 99 with total pairs 3160650choosing ax, 2
# Total Galaxy Groups to process: 4 with pairs : 543491
# Processing Subhalo 400/400 in Galaxy Group ID 3 with total pairs 798006choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 2361 with pairs : 2457992
# Processing Subhalo 56/686 in Galaxy Group ID 0 with total pairs 234955
# /home/poulin.al/.conda/envs/myenv/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:901: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Processing Subhalo 5/5 in Galaxy Group ID 1003 with total pairs 1027650choosing ax, 5
# Total Galaxy Groups to process: 1821 with pairs : 526662
# Processing Subhalo 20/20 in Galaxy Group ID 1008 with total pairs 190choosing ax, 0
# Total Galaxy Groups to process: 169 with pairs : 424064
# Processing Subhalo 102/102 in Galaxy Group ID 99 with total pairs 51511choosing ax, 1
# Total Galaxy Groups to process: 63 with pairs : 1033048
# Processing Subhalo 328/328 in Galaxy Group ID 9 with total pairs 536288choosing ax, 2
# Total Galaxy Groups to process: 1 with pairs : 222111
# Processing Subhalo 666/666 in Galaxy Group ID 0 with total pairs 221445choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 2054 with pairs : 2205885
# Processing Subhalo 20/20 in Galaxy Group ID 1008 with total pairs 19018choosing ax, 5
# Total Galaxy Groups to process: 1388 with pairs : 568050
# Processing Subhalo 26/26 in Galaxy Group ID 1043 with total pairs 325choosing ax, 0
# Total Galaxy Groups to process: 109 with pairs : 390512
# Processing Subhalo 92/92 in Galaxy Group ID 99 with total pairs 418678choosing ax, 1
# Total Galaxy Groups to process: 33 with pairs : 623954
# Processing Subhalo 249/249 in Galaxy Group ID 9 with total pairs 308765choosing ax, 2
# Total Galaxy Groups to process: 1 with pairs : 150426
# Processing Subhalo 548/548 in Galaxy Group ID 0 with total pairs 149878choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 1531 with pairs : 1732942
# Processing Subhalo 26/26 in Galaxy Group ID 1043 with total pairs 32565choosing ax, 5
# Total Galaxy Groups to process: 850 with pairs : 598974
# Processing Subhalo 67/67 in Galaxy Group ID 99 with total pairs 221165choosing ax, 0
# Total Galaxy Groups to process: 40 with pairs : 259113
# Processing Subhalo 186/186 in Galaxy Group ID 9 with total pairs 172053choosing ax, 1
# Total Galaxy Groups to process: 10 with pairs : 263462
# Processing Subhalo 132/132 in Galaxy Group ID 8 with total pairs 864658choosing ax, 2
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 900 with pairs : 1121549
# Processing Subhalo 67/67 in Galaxy Group ID 99 with total pairs 2211653choosing ax, 5
# Total Galaxy Groups to process: 303 with pairs : 380267
# Processing Subhalo 49/49 in Galaxy Group ID 102 with total pairs 11763choosing ax, 0
# Total Galaxy Groups to process: 10 with pairs : 117960
# Processing Subhalo 119/119 in Galaxy Group ID 9 with total pairs 702138choosing ax, 1
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 2
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 313 with pairs : 498227
# Processing Subhalo 49/49 in Galaxy Group ID 102 with total pairs 117638choosing ax, 5
# Total Galaxy Groups to process: 74 with pairs : 151211
# Processing Subhalo 78/78 in Galaxy Group ID 10 with total pairs 300350choosing ax, 0
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 1
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 2
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 74 with pairs : 151211
# Processing Subhalo 78/78 in Galaxy Group ID 10 with total pairs 300350choosing ax, 5
# Total Galaxy Groups to process: 2 with pairs : 3818
# Processing Subhalo 67/67 in Galaxy Group ID 1 with total pairs 2211choosing ax, 0
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 1
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 2
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 3
# Total Galaxy Groups to process: 0 with pairs : 0
# choosing ax, 4
# Total Galaxy Groups to process: 2 with pairs : 3818
# Processing Subhalo 67/67 in Galaxy Group ID 1 with total pairs 2211choosing ax, 5
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar_difference_distribution_across_redshifts_TNG300-1.png
