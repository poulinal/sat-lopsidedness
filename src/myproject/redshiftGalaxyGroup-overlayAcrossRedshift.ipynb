# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis

# %%
galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=False)
# Out:
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# Progress: Processing Galaxy Group ID 3733 / 3733

# %%
galaxyAnalysisZ0.plot_pairwise_polar_difference_across_redshifts()
# Out:
# GATHERING FOR SNAPSHOT: 99
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 99 from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# GATHERING FOR SNAPSHOT: 91y Group ID 3733 / 3733
# Progress: 3366/3366
# Loaded 3366 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 91 from /scratch/poulin.al/lopsided/TNG300-1/z0p1/data/galaxy_data_TNG300-1.hdf5
# total to process: 3366
# total to process: 3366alaxy Group ID 3366 / 3366
# total to process: 3366alaxy Group ID 3366 / 3366
# total to process: 3366alaxy Group ID 3366 / 3366
# total to process: 3366alaxy Group ID 3366 / 3366
# GATHERING FOR SNAPSHOT: 84y Group ID 3366 / 3366
# Progress: 3006/3006
# Loaded 3006 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 84 from /scratch/poulin.al/lopsided/TNG300-1/z0p2/data/galaxy_data_TNG300-1.hdf5
# total to process: 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# GATHERING FOR SNAPSHOT: 78y Group ID 3006 / 3006
# Progress: 2664/2664
# Loaded 2664 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 78 from /scratch/poulin.al/lopsided/TNG300-1/z0p3/data/galaxy_data_TNG300-1.hdf5
# total to process: 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# GATHERING FOR SNAPSHOT: 72y Group ID 2664 / 2664
# Progress: 2361/2361
# Loaded 2361 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 72 from /scratch/poulin.al/lopsided/TNG300-1/z0p4/data/galaxy_data_TNG300-1.hdf5
# total to process: 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# GATHERING FOR SNAPSHOT: 67y Group ID 2361 / 2361
# Progress: 2054/2054
# Loaded 2054 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 67 from /scratch/poulin.al/lopsided/TNG300-1/z0p5/data/galaxy_data_TNG300-1.hdf5
# total to process: 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# GATHERING FOR SNAPSHOT: 59y Group ID 2054 / 2054
# Progress: 1531/1531
# Loaded 1531 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 59 from /scratch/poulin.al/lopsided/TNG300-1/z0p7/data/galaxy_data_TNG300-1.hdf5
# total to process: 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# GATHERING FOR SNAPSHOT: 50y Group ID 1531 / 1531
# Progress: 900/900
# Loaded 900 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 50 from /scratch/poulin.al/lopsided/TNG300-1/z1p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# GATHERING FOR SNAPSHOT: 40y Group ID 900 / 900
# Progress: 313/313
# Loaded 313 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 40 from /scratch/poulin.al/lopsided/TNG300-1/z1p5/data/galaxy_data_TNG300-1.hdf5
# total to process: 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# total to process: 313Galaxy Group ID 313 / 313
# GATHERING FOR SNAPSHOT: 33y Group ID 313 / 313
# Progress: 74/74
# Loaded 74 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 33 from /scratch/poulin.al/lopsided/TNG300-1/z2p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# total to process: 74 Galaxy Group ID 74 / 74
# GATHERING FOR SNAPSHOT: 25y Group ID 74 / 74
# Progress: 2/2
# Loaded 2 galaxy groups from HDF5.
# Loaded galaxy data for snapshot 25 from /scratch/poulin.al/lopsided/TNG300-1/z3p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# total to process: 2g Galaxy Group ID 2 / 2
# COMPUTING FOR redshift index: 0, label: $13<M_{200}<13.5$, z=z0p0
# Total Galaxy Groups to process: 3033 with pairs : 358688
# Resuming from existing temp file: pairwise_differences_3033.hdf5
#
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 0
# COMPUTING FOR redshift index: 0, label: $13.5<M_{200}<14$, z=z0p0
# Total Galaxy Groups to process: 420 with pairs : 340216
# Resuming from existing temp file: pairwise_differences_420.hdf5
#
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 1
# COMPUTING FOR redshift index: 0, label: $14<M_{200}<14.5$, z=z0p0
# Total Galaxy Groups to process: 268 with pairs : 1457070
# Resuming from existing temp file: pairwise_differences_268.hdf5
#
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 2
# COMPUTING FOR redshift index: 0, label: $14.5<M_{200}<15$, z=z0p0
# Total Galaxy Groups to process: 9 with pairs : 439327
# Processing Subhalo 306/306 in Galaxy Group ID 9 with total pairs 466651
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 3
# COMPUTING FOR redshift index: 0, label: $M_{200}>15$, z=z0p0
# Total Galaxy Groups to process: 3 with pairs : 442105
# Processing Subhalo 419/419 in Galaxy Group ID 2 with total pairs 875710
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 4
# COMPUTING FOR redshift index: 0, label: All Masses, z=z0p0
# Total Galaxy Groups to process: 3733 with pairs : 3037406
# Processing Subhalo 22/22 in Galaxy Group ID 1087 with total pairs 23171
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 1177 with total pairs 10571
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 24/24 in Galaxy Group ID 1267 with total pairs 27665
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1359 with total pairs 17156
# Intermediate save after processing 400 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 1449 with total pairs 3612078
# Intermediate save after processing 500 galaxy groups.
# Processing Subhalo 21/21 in Galaxy Group ID 1540 with total pairs 21000
# Intermediate save after processing 600 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1633 with total pairs 17100
# Intermediate save after processing 700 galaxy groups.
# Processing Subhalo 20/20 in Galaxy Group ID 1723 with total pairs 19056
# Intermediate save after processing 800 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 1814 with total pairs 78131
# Intermediate save after processing 900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 1908 with total pairs 55650
# Intermediate save after processing 1000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2003 with total pairs 55095
# Intermediate save after processing 1100 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 2093 with total pairs 66015
# Intermediate save after processing 1200 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2185 with total pairs 91090
# Intermediate save after processing 1300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 2281 with total pairs 45021
# Intermediate save after processing 1400 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2380 with total pairs 91605
# Intermediate save after processing 1500 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 2476 with total pairs 10503
# Intermediate save after processing 1600 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2580 with total pairs 915
# Intermediate save after processing 1700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 2680 with total pairs 155556
# Intermediate save after processing 1800 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 2792 with total pairs 3670136
# Intermediate save after processing 1900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2893 with total pairs 556
# Intermediate save after processing 2000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 3002 with total pairs 55020
# Intermediate save after processing 2100 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 3110 with total pairs 217861
# Intermediate save after processing 2200 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3230 with total pairs 3610555
# Intermediate save after processing 2300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 3351 with total pairs 45645
# Intermediate save after processing 2400 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 3486 with total pairs 2878531
# Intermediate save after processing 2500 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3623 with total pairs 3645103
# Intermediate save after processing 2600 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 3766 with total pairs 6 45528
# Intermediate save after processing 2700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 3927 with total pairs 1578246
# Intermediate save after processing 2800 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 4156 with total pairs 1066676
# Intermediate save after processing 2900 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 4505 with total pairs 60558
# Intermediate save after processing 3000 galaxy groups.
# Processing Subhalo 39/39 in Galaxy Group ID 428 with total pairs 741505
# Intermediate save after processing 3100 galaxy groups.
# Processing Subhalo 47/47 in Galaxy Group ID 518 with total pairs 108106
# Intermediate save after processing 3200 galaxy groups.
# Processing Subhalo 38/38 in Galaxy Group ID 608 with total pairs 703175
# Intermediate save after processing 3300 galaxy groups.
# Processing Subhalo 32/32 in Galaxy Group ID 699 with total pairs 496860
# Intermediate save after processing 3400 galaxy groups.
# Processing Subhalo 28/28 in Galaxy Group ID 789 with total pairs 378110
# Intermediate save after processing 3500 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 879 with total pairs 231811
# Intermediate save after processing 3600 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 969 with total pairs 23155
# Intermediate save after processing 3700 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 999 with total pairs 12026
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 5
# COMPUTING FOR redshift index: 1, label: $13<M_{200}<13.5$, z=z0p1
# Total Galaxy Groups to process: 2790 with pairs : 449435
# Processing Subhalo 22/22 in Galaxy Group ID 1100 with total pairs 231
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 18/18 in Galaxy Group ID 1200 with total pairs 153
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 1302 with total pairs 28378
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 1403 with total pairs 28153
# Intermediate save after processing 400 galaxy groups.
# Processing Subhalo 18/18 in Galaxy Group ID 1504 with total pairs 153
# Intermediate save after processing 500 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 1606 with total pairs 120
# Intermediate save after processing 600 galaxy groups.
# Processing Subhalo 18/18 in Galaxy Group ID 1709 with total pairs 153
# Intermediate save after processing 700 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 1811 with total pairs 551
# Intermediate save after processing 800 galaxy groups.
# Processing Subhalo 17/17 in Galaxy Group ID 1915 with total pairs 136
# Intermediate save after processing 900 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2020 with total pairs 916
# Intermediate save after processing 1000 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2128 with total pairs 915
# Intermediate save after processing 1100 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 2241 with total pairs 105
# Intermediate save after processing 1200 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 2350 with total pairs 785
# Intermediate save after processing 1300 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 2468 with total pairs 105
# Intermediate save after processing 1400 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 2587 with total pairs 660
# Intermediate save after processing 1500 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 2712 with total pairs 666
# Intermediate save after processing 1600 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 2830 with total pairs 785
# Intermediate save after processing 1700 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2959 with total pairs 915
# Intermediate save after processing 1800 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 3108 with total pairs 10555
# Intermediate save after processing 1900 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 3263 with total pairs 910
# Intermediate save after processing 2000 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 3436 with total pairs 660
# Intermediate save after processing 2100 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 3612 with total pairs 10455
# Intermediate save after processing 2200 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3849 with total pairs 3666
# Intermediate save after processing 2300 galaxy groups.
# Processing Subhalo 36/36 in Galaxy Group ID 522 with total pairs 6305
# Intermediate save after processing 2400 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 701 with total pairs 1058
# Intermediate save after processing 2500 galaxy groups.
# Processing Subhalo 17/17 in Galaxy Group ID 809 with total pairs 136
# Intermediate save after processing 2600 galaxy groups.
# Processing Subhalo 29/29 in Galaxy Group ID 909 with total pairs 406
# Intermediate save after processing 2700 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 1000 with total pairs 91
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 0
# COMPUTING FOR redshift index: 1, label: $13.5<M_{200}<14$, z=z0p1
# Total Galaxy Groups to process: 356 with pairs : 388942
# Processing Subhalo 43/43 in Galaxy Group ID 326 with total pairs 9038
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 46/46 in Galaxy Group ID 440 with total pairs 1035
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 45/45 in Galaxy Group ID 577 with total pairs 9908
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 71/71 in Galaxy Group ID 89 with total pairs 24855
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# choosing ax, 1
# COMPUTING FOR redshift index: 1, label: $14<M_{200}<14.5$, z=z0p1
# Total Galaxy Groups to process: 213 with pairs : 1539104
# Processing Subhalo 215/215 in Galaxy Group ID 21 with total pairs 23005
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 87/87 in Galaxy Group ID 85 with total pairs 3741701
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 117/117 in Galaxy Group ID 99 with total pairs 6786
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
