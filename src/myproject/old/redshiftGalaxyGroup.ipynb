# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %% [markdown]
# Plot distribution of m200
# Save the plot data points in txt
# Check what's wrong with bootstrap

# %%
from myproject.getRedshiftGalaxyGroupData import GalaxyGroupData

# %%
galaxyGroupData = GalaxyGroupData(sim='TNG300-1')
galaxyGroupData.computeAllData()
# Out:
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# New z: 0
# (14485709, 6)
# [0. 0. 0. ... 0. 0. 0.]
# [530.9484   253.66284   57.365696 ...   0.         0.         0.      ]
# [ 43718.812  48813.64  147594.95 ]
# [ 64539.14  72060.29 217884.48]
# <KeysViewHDF5 ['Subhalo_StellarPhot_p07c_cf00dust_res_conv_ns1_rad30pkpc', 'subhaloIDs']>
# (14485709, 8, 12)
# [   0    1    2 ... 4810 4857 5230]
# Number of galaxy groups with M200 > 1e13 solar masses: 7293664
# Max valid group index: 5230
# 1647.9259
# 2432.7222
# num subhalos: 14485709
# rough number of galaxygroups: 11504190
# Constructed ListGalaxyGroup with 5231 galaxy groups.
#  Average satellites: 231.48709615752247
# Correcting positions in parallel with 4 processes...
# Progress: 5231/5231 (100.0%)
# After correcting, ListGalaxyGroup has 5231 galaxy groups.
#  Average satellites: 231.48709615752247
# total to process: 5231
# Filtering subhalos in parallel with 27 processes...
# Progress: 5231/5231 (100.0%)
# After filtering: 5231 galaxy groups retained.
# After filtering, ListGalaxyGroup has 3733 galaxy groups.
#  Average satellites: 23.969997321189393
#  Range of satellites: (1, 604)
# Serializing galaxy group data in parallel with 27 processes...
# Serialization: 3733/3733 (100.0%)
# Writing serialized data to HDF5 file...
# Writing: 3733/3733 (100.0%)
# Completed writing 3733 galaxy groups to HDF5.
# Saved galaxy data to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# 0
# Finished processing for sim: TNG300-1, snapshot: 99 of index 0/11
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# New z: 0.1
# (14746091, 6)
# [0. 0. 0. ... 0. 0. 0.]
# [434.7648   240.35625   62.599895 ...   0.         0.         0.      ]
# [ 43304.91   48348.746 147946.25 ]
# [ 58116.477  64885.453 198548.27 ]
# <KeysViewHDF5 ['Subhalo_StellarPhot_p07c_cf00dust_res_conv_ns1_rad30pkpc', 'subhaloIDs']>
# (14746091, 8, 12)
# [   0    1    2 ... 4394 4398 4419]
# Number of galaxy groups with M200 > 1e13 solar masses: 5942579
# Max valid group index: 4419
# 1690.4274
# 2268.6038
# num subhalos: 14746091
# rough number of galaxygroups: 11777612
# Constructed ListGalaxyGroup with 4420 galaxy groups.
#  Average satellites: 244.99886877828055
# Correcting positions in parallel with 4 processes...
# Progress: 4420/4420 (100.0%)
# After correcting, ListGalaxyGroup has 4420 galaxy groups.
#  Average satellites: 244.99886877828055
# total to process: 4420
# Filtering subhalos in parallel with 27 processes...
# Progress: 4420/4420 (100.0%)
# After filtering: 4420 galaxy groups retained.
# After filtering, ListGalaxyGroup has 3366 galaxy groups.
#  Average satellites: 26.459893048128343
#  Range of satellites: (2, 601)
# Serializing galaxy group data in parallel with 27 processes...
# Serialization: 3366/3366 (100.0%)
# Writing serialized data to HDF5 file...
# Writing: 3366/3366 (100.0%)
# Completed writing 3366 galaxy groups to HDF5.
# Saved galaxy data to /scratch/poulin.al/lopsided/TNG300-1/z0p1/data/galaxy_data_TNG300-1.hdf5
# 1
# Finished processing for sim: TNG300-1, snapshot: 91 of index 1/11
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# New z: 0.2
# (15012055, 6)
# [0. 0. 0. ... 0. 0. 0.]
# [372.0791  231.454    64.53201 ...   0.        0.        0.     ]
# [ 43027.344  47971.984 148261.66 ]
# [ 52931.973  59014.84  182390.58 ]
# <KeysViewHDF5 ['Subhalo_StellarPhot_p07c_cf00dust_res_conv_ns1_rad30pkpc', 'subhaloIDs']>
# (15012055, 8, 12)
# [   0    1    2 ... 3908 3980 4138]
# Number of galaxy groups with M200 > 1e13 solar masses: 4752617
# Max valid group index: 4138
# 1710.3221
# 2104.0278
# num subhalos: 15012055
# rough number of galaxygroups: 12046872
# Constructed ListGalaxyGroup with 4139 galaxy groups.
#  Average satellites: 240.85117178062333
# Correcting positions in parallel with 4 processes...
# Progress: 2583/4139 (62.4%)

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis

# %%
galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=True)
# Out:
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# Progress: Processing Galaxy Group ID 3732 / 3732

# %%
galaxyAnalysisZ0.setSnapshot(99)
# Out:
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# Progress: Processing Galaxy Group ID 3732 / 3732

# %%
galaxyAnalysisZ0.computeAllPlots()
# Out:
# Total Galaxy Groups to process: 280 with pairs : 2068402
# Resuming from existing temp file: pairwise_differences_3732.hdf5
# Processing Subhalo 66/66 in Galaxy Group ID 197 with total pairs 214528
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 168/168 in Galaxy Group ID 32 with total pairs 14028
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 57/57 in Galaxy Group ID 99 with total pairs 1596210
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# warning ax is none
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar_difference_TNG300-1_z0p0.png
# Resuming from existing temp file: MRL_values_280.hdf5
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# Progress: Processing Galaxy Group 100 / 280 with 67 satellites
# Intermediate save after processing 100 galaxy groups.
# Progress: Processing Galaxy Group 200 / 280 with 169 satellites
# Intermediate save after processing 200 galaxy groups.
# Progress: Processing Galaxy Group 280 / 280 with 58 satellitess
# Final save after processing all galaxy groups.
# warning ax is none
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/MRL_directionality_TNG300-1_z0p0.png
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/color_distribution_TNG300-1_z0p0.png
# total to process: 280
# Number of galaxy groups with only red satellites: (0, 0)
# total to process: 280
# Number of galaxy groups with only blue satellites: (31, 597)
# Total Galaxy Groups to process: 0 with pairs : 0
# Resuming from existing temp file: pairwise_differences_280.hdf5
#
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# Total Galaxy Groups to process: 280 with pairs : 2068402
# Resuming from existing temp file: pairwise_differences_280.hdf5
# Processing Subhalo 66/66 in Galaxy Group ID 197 with total pairs 214528
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 168/168 in Galaxy Group ID 32 with total pairs 14028
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 57/57 in Galaxy Group ID 99 with total pairs 1596210
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# Computed pairwise polar differences between red and blue satellite galaxies.
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar/pairwise_polar_difference_red_blue_TNG300-1_z0p0.png
# data to be saved: [[5.00000000e+00 6.53907745e-03 5.11330653e-05 6.33500921e-03
#   3.21630432e-05]
#  [1.50000000e+01 6.33831735e-03 5.03420131e-05 6.18120373e-03
#   3.17702065e-05]
#  [2.50000000e+01 6.10792904e-03 4.94186162e-05 5.98077815e-03
#   3.12508875e-05]
#  [3.50000000e+01 5.81580531e-03 4.82223663e-05 5.76188416e-03
#   3.06736720e-05]
#  [4.50000000e+01 5.60632868e-03 4.73459534e-05 5.58704657e-03
#   3.02047089e-05]
#  [5.50000000e+01 5.42156222e-03 4.65592324e-05 5.42964865e-03
#   2.97762068e-05]
#  [6.50000000e+01 5.28973469e-03 4.59896954e-05 5.31367811e-03
#   2.94564991e-05]
#  [7.50000000e+01 5.18341700e-03 4.55251791e-05 5.23735506e-03
#   2.92441846e-05]
#  [8.50000000e+01 5.12743928e-03 4.52786898e-05 5.20009164e-03
#   2.91399637e-05]
#  [9.50000000e+01 5.08493620e-03 4.50906340e-05 5.18356641e-03
#   2.90936253e-05]
#  [1.05000000e+02 5.10884668e-03 4.51965227e-05 5.18787734e-03
#   2.91057207e-05]
#  [1.15000000e+02 5.17721947e-03 4.54979549e-05 5.26486989e-03
#   2.93209022e-05]
#  [1.25000000e+02 5.25334917e-03 4.58312521e-05 5.33324058e-03
#   2.95106718e-05]
#  [1.35000000e+02 5.38937503e-03 4.64208182e-05 5.42943637e-03
#   2.97756247e-05]
#  [1.45000000e+02 5.51196624e-03 4.69458128e-05 5.52172945e-03
#   3.00276310e-05]
#  [1.55000000e+02 5.62404163e-03 4.74206881e-05 5.61828448e-03
#   3.02890304e-05]
#  [1.65000000e+02 5.67746037e-03 4.76453634e-05 5.69206017e-03
#   3.04872498e-05]
#  [1.75000000e+02 5.74319421e-03 4.79203895e-05 5.74224004e-03
#   3.06213392e-05]]
# Warning: Raw arrays have different lengths, padding to 6123969 with NaN for saving raw pairwise polar color difference.
# total to process: 280
# Number of galaxy groups with more than 150 satellites: 40
# total to process: 280
# Number of galaxy groups with less than 50 satellites: 35
# Total Galaxy Groups to process: 40 with pairs : 1334730
# Resuming from existing temp file: pairwise_differences_40.hdf5
# Processing Subhalo 294/294 in Galaxy Group ID 9 with total pairs 430710
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# Total Galaxy Groups to process: 35 with pairs : 33908
# Resuming from existing temp file: pairwise_differences_35.hdf5
# Processing Subhalo 36/36 in Galaxy Group ID 75 with total pairs 63016
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# Computed pairwise polar differences for galaxy groups with >150 and <50 satellites.
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# /home/poulin.al/.conda/envs/myenv/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:901: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:247: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x_smooth, spline(x_smooth),'k--', alpha=0.5, linewidth=3, c=scatter_color, label=label)

# %%
from myproject.utilities.snapshotEnum import SnapshotEnum
# snapshotEnum = SnapshotEnum() #(99, 0, 'z0p0')
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #already processed these snapshots
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisZ0.setSnapshot(snapshot[0])
    # galaxyAnalysisZ0.computeAllPlots()
    galaxyAnalysisZ0.plot_M200_distribution_for_all_mass_bins()
# Out:
# Processing snapshot 99...
# Progress: 3732/3732
# Loaded 3732 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# choosing ax, 0axy group 999 for M200 distributionn
# choosing ax, 1axy group 946 for M200 distribution
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 9 for M200 distributionn
# choosing ax, 4axy group 2 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/M200_distribution_TNG300-1_z0p0.png
# Processing snapshot 91...
# Progress: 3367/3367
# Loaded 3367 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p1/data/galaxy_data_TNG300-1.hdf5
# total to process: 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# total to process: 3367alaxy Group ID 3367 / 3367
# choosing ax, 0axy group 1000 for M200 distribution
# choosing ax, 1axy group 89 for M200 distributionn
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 8 for M200 distribution
# choosing ax, 4axy group 1 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p1/plots/M200_distribution_TNG300-1_z0p1.png
# Processing snapshot 84...
# Progress: 3006/3006
# Loaded 3006 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p2/data/galaxy_data_TNG300-1.hdf5
# total to process: 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# total to process: 3006alaxy Group ID 3006 / 3006
# choosing ax, 0axy group 1001 for M200 distribution
# choosing ax, 1axy group 97 for M200 distributionn
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 5 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p2/plots/M200_distribution_TNG300-1_z0p2.png
# Processing snapshot 78...
# Progress: 2664/2664
# Loaded 2664 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p3/data/galaxy_data_TNG300-1.hdf5
# total to process: 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# total to process: 2664alaxy Group ID 2664 / 2664
# choosing ax, 0axy group 1000 for M200 distribution
# choosing ax, 1axy group 96 for M200 distributionn
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 3 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p3/plots/M200_distribution_TNG300-1_z0p3.png
# Processing snapshot 72...
# Progress: 2361/2361
# Loaded 2361 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p4/data/galaxy_data_TNG300-1.hdf5
# total to process: 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# total to process: 2361alaxy Group ID 2361 / 2361
# choosing ax, 0axy group 1003 for M200 distribution
# choosing ax, 1axy group 97 for M200 distributionn
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 3 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p4/plots/M200_distribution_TNG300-1_z0p4.png
# Processing snapshot 67...
# Progress: 2054/2054
# Loaded 2054 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p5/data/galaxy_data_TNG300-1.hdf5
# total to process: 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# total to process: 2054alaxy Group ID 2054 / 2054
# choosing ax, 0axy group 1008 for M200 distribution
# choosing ax, 1axy group 99 for M200 distributionn
# choosing ax, 2axy group 9 for M200 distributionn
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p5/plots/M200_distribution_TNG300-1_z0p5.png
# Processing snapshot 59...
# Progress: 1531/1531
# Loaded 1531 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p7/data/galaxy_data_TNG300-1.hdf5
# total to process: 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# total to process: 1531alaxy Group ID 1531 / 1531
# choosing ax, 0axy group 1043 for M200 distribution
# choosing ax, 1axy group 99 for M200 distributionn
# choosing ax, 2axy group 9 for M200 distributionn
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p7/plots/M200_distribution_TNG300-1_z0p7.png
# Processing snapshot 50...
# Progress: 900/900
# Loaded 900 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z1p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# total to process: 900Galaxy Group ID 900 / 900
# choosing ax, 0axy group 99 for M200 distributionon
# choosing ax, 1axy group 9 for M200 distributionn
# choosing ax, 2axy group 8 for M200 distributionn
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/M200_distribution_TNG300-1_z1p0.png
