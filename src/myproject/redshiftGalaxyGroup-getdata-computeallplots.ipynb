# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %% [markdown]
# Plot distribution of m200
# Save the plot data points in txt
# Check what's wrong with bootstrap

# %%
from myproject.getRedshiftGalaxyGroupData import GalaxyGroupData

# %%
galaxyGroupData = GalaxyGroupData(sim='TNG300-1')
galaxyGroupData.computeAllData()
# Out:
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# New z: 0
# (14485709, 6)
# [0. 0. 0. ... 0. 0. 0.]
# [530.9484   253.66284   57.365696 ...   0.         0.         0.      ]
# [ 43718.812  48813.64  147594.95 ]
# [ 64539.14  72060.29 217884.48]
# <KeysViewHDF5 ['Subhalo_StellarPhot_p07c_cf00dust_res_conv_ns1_rad30pkpc', 'subhaloIDs']>
# (14485709, 8, 12)
# [   0    1    2 ... 4810 4857 5230]
# Number of galaxy groups with M200 > 1e13 solar masses: 7293664
# Max valid group index: 5230
# 1647.9259
# 2432.7222
# num subhalos: 14485709
# rough number of galaxygroups: 11504190
# Constructed ListGalaxyGroup with 5231 galaxy groups.
#  Average satellites: 231.48709615752247
# Correcting positions in parallel with 4 processes...
# Progress: 5231/5231 (100.0%)
# After correcting, ListGalaxyGroup has 5231 galaxy groups.
#  Average satellites: 231.48709615752247
# total to process: 5231
# Filtering subhalos in parallel with 27 processes...
# Progress: 5231/5231 (100.0%)
# After filtering: 5231 galaxy groups retained.
# After filtering, ListGalaxyGroup has 3733 galaxy groups.
#  Average satellites: 23.969997321189393
#  Range of satellites: (1, 604)
# Serializing galaxy group data in parallel with 27 processes...
# Serialization: 3733/3733 (100.0%)
# Writing serialized data to HDF5 file...
# Writing: 3733/3733 (100.0%)
# Completed writing 3733 galaxy groups to HDF5.
# Saved galaxy data to /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# 0
# Finished processing for sim: TNG300-1, snapshot: 99 of index 0/11
# Fetching data from http://www.tng-project.org/api/ with params None and saving to temp
# r:  {'simulations': [{'name': 'Illustris-1', 'num_snapshots': 134, 'url': 'http://www.tng-project.org/api/Illustris-1/'}, {'name': 'Illustris-1-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-1-Dark/'}, {'name': 'Illustris-2', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2/'}, {'name': 'Illustris-2-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-2-Dark/'}, {'name': 'Illustris-3', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3/'}, {'name': 'Illustris-3-Dark', 'num_snapshots': 136, 'url': 'http://www.tng-project.org/api/Illustris-3-Dark/'}, {'name': 'TNG100-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1/'}, {'name': 'TNG100-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-1-Dark/'}, {'name': 'TNG100-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2/'}, {'name': 'TNG100-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-2-Dark/'}, {'name': 'TNG100-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3/'}, {'name': 'TNG100-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG100-3-Dark/'}, {'name': 'TNG300-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3/'}, {'name': 'TNG300-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2-Dark/'}, {'name': 'TNG300-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-2/'}, {'name': 'TNG300-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1-Dark/'}, {'name': 'TNG300-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-1/'}, {'name': 'TNG300-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG300-3-Dark/'}, {'name': 'TNG50-1', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1/'}, {'name': 'TNG50-1-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-1-Dark/'}, {'name': 'TNG50-2', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2/'}, {'name': 'TNG50-2-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-2-Dark/'}, {'name': 'TNG50-3', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3/'}, {'name': 'TNG50-3-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-3-Dark/'}, {'name': 'TNG50-4', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4/'}, {'name': 'TNG50-4-Dark', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG50-4-Dark/'}, {'name': 'TNG-Cluster', 'num_snapshots': 100, 'url': 'http://www.tng-project.org/api/TNG-Cluster/'}, {'name': 'Illustris-1-Subbox0', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox0/'}, {'name': 'Illustris-1-Subbox1', 'num_snapshots': 3969, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox1/'}, {'name': 'Illustris-1-Subbox2', 'num_snapshots': 3972, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox2/'}, {'name': 'Illustris-1-Subbox3', 'num_snapshots': 3970, 'url': 'http://www.tng-project.org/api/Illustris-1-Subbox3/'}, {'name': 'Illustris-2-Subbox0', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox0/'}, {'name': 'Illustris-2-Subbox1', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox1/'}, {'name': 'Illustris-2-Subbox2', 'num_snapshots': 2264, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox2/'}, {'name': 'Illustris-2-Subbox3', 'num_snapshots': 2265, 'url': 'http://www.tng-project.org/api/Illustris-2-Subbox3/'}, {'name': 'Illustris-3-Subbox0', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox0/'}, {'name': 'Illustris-3-Subbox1', 'num_snapshots': 1426, 'url': 'http://www.tng-project.org/api/Illustris-3-Subbox1/'}, {'name': 'Illustris-3-Subbox2', 'num_snapshots': 1426, 'url': 'http://www.tng- ...
# http://www.tng-project.org/api/TNG300-1
# Fetching data from http://www.tng-project.org/api/TNG300-1 with params None and saving to temp
# Main high-resolution IllustrisTNG300 run including the full TNG physics model.
# hubble: 0.6774
# New z: 0.1
# (14746091, 6)
# [0. 0. 0. ... 0. 0. 0.]
# [434.7648   240.35625   62.599895 ...   0.         0.         0.      ]
# [ 43304.91   48348.746 147946.25 ]
# [ 58116.477  64885.453 198548.27 ]
# <KeysViewHDF5 ['Subhalo_StellarPhot_p07c_cf00dust_res_conv_ns1_rad30pkpc', 'subhaloIDs']>
# (14746091, 8, 12)
# [   0    1    2 ... 4394 4398 4419]
# Number of galaxy groups with M200 > 1e13 solar masses: 5942579
# Max valid group index: 4419
# 1690.4274
# 2268.6038
# num subhalos: 14746091
# rough number of galaxygroups: 11777612
# Constructed ListGalaxyGroup with 4420 galaxy groups.
#  Average satellites: 244.99886877828055
# Correcting positions in parallel with 4 processes...
# Progress: 219/4420 (5.0%)

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis

# %%
galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=True)
# Out:
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# Progress: Processing Galaxy Group ID 3733 / 3733

# %%
galaxyAnalysisZ0.setSnapshot(99)
# Out:
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1.hdf5
# total to process: 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# total to process: 3733alaxy Group ID 3733 / 3733
# Progress: Processing Galaxy Group ID 3733 / 3733

# %%
galaxyAnalysisZ0.computeAllPlots()
# Out:
# Processing Subhalo 21/21 in Galaxy Group ID 1540 with total pairs 21000
# Intermediate save after processing 600 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1633 with total pairs 17100
# Intermediate save after processing 700 galaxy groups.
# Processing Subhalo 20/20 in Galaxy Group ID 1723 with total pairs 19056
# Intermediate save after processing 800 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 1814 with total pairs 78131
# Intermediate save after processing 900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 1908 with total pairs 55650
# Intermediate save after processing 1000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2003 with total pairs 55095
# Intermediate save after processing 1100 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 2093 with total pairs 66015
# Intermediate save after processing 1200 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2185 with total pairs 91090
# Intermediate save after processing 1300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 2281 with total pairs 45021
# Intermediate save after processing 1400 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2380 with total pairs 91605
# Intermediate save after processing 1500 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 2476 with total pairs 10503
# Intermediate save after processing 1600 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2580 with total pairs 915
# Intermediate save after processing 1700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 2680 with total pairs 155556
# Intermediate save after processing 1800 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 2792 with total pairs 3670136
# Intermediate save after processing 1900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2893 with total pairs 556
# Intermediate save after processing 2000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 3002 with total pairs 55020
# Intermediate save after processing 2100 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 3110 with total pairs 217861
# Intermediate save after processing 2200 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3230 with total pairs 3610555
# Intermediate save after processing 2300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 3351 with total pairs 45645
# Intermediate save after processing 2400 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 3486 with total pairs 2878531
# Intermediate save after processing 2500 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3623 with total pairs 3645103
# Intermediate save after processing 2600 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 3766 with total pairs 6 45528
# Intermediate save after processing 2700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 3927 with total pairs 1578246
# Intermediate save after processing 2800 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 4156 with total pairs 1066676
# Intermediate save after processing 2900 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 4505 with total pairs 60558
# Intermediate save after processing 3000 galaxy groups.
# Processing Subhalo 39/39 in Galaxy Group ID 428 with total pairs 741505
# Intermediate save after processing 3100 galaxy groups.
# Processing Subhalo 47/47 in Galaxy Group ID 518 with total pairs 108106
# Intermediate save after processing 3200 galaxy groups.
# Processing Subhalo 38/38 in Galaxy Group ID 608 with total pairs 703175
# Intermediate save after processing 3300 galaxy groups.
# Processing Subhalo 32/32 in Galaxy Group ID 699 with total pairs 496860
# Intermediate save after processing 3400 galaxy groups.
# Processing Subhalo 28/28 in Galaxy Group ID 789 with total pairs 378110
# Intermediate save after processing 3500 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 879 with total pairs 231811
# Intermediate save after processing 3600 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 969 with total pairs 23155
# Intermediate save after processing 3700 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 999 with total pairs 12026
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# len: (18, 18, 18)
# first 5 values centralMassive: [0.00667333 0.00607347 0.00568721 0.00552771 0.0053991 ], notCentralMassive: [nan nan nan nan nan], total: [0.00667333 0.00607347 0.00568721 0.00552771 0.0053991 ]
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar_difference_allMasses_TNG300-1_z0p0_differentYlim.pdf
# Total Galaxy Groups to process: 3733 with pairs : 3037406
# Resuming from existing temp file: pairwise_differences_3732.hdf5
# Processing Subhalo 22/22 in Galaxy Group ID 1087 with total pairs 23171
# Intermediate save after processing 100 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 1177 with total pairs 10571
# Intermediate save after processing 200 galaxy groups.
# Processing Subhalo 24/24 in Galaxy Group ID 1267 with total pairs 27665
# Intermediate save after processing 300 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1359 with total pairs 17156
# Intermediate save after processing 400 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 1449 with total pairs 3612078
# Intermediate save after processing 500 galaxy groups.
# Processing Subhalo 21/21 in Galaxy Group ID 1540 with total pairs 21000
# Intermediate save after processing 600 galaxy groups.
# Processing Subhalo 19/19 in Galaxy Group ID 1633 with total pairs 17100
# Intermediate save after processing 700 galaxy groups.
# Processing Subhalo 20/20 in Galaxy Group ID 1723 with total pairs 19056
# Intermediate save after processing 800 galaxy groups.
# Processing Subhalo 13/13 in Galaxy Group ID 1814 with total pairs 78131
# Intermediate save after processing 900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 1908 with total pairs 55650
# Intermediate save after processing 1000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2003 with total pairs 55095
# Intermediate save after processing 1100 galaxy groups.
# Processing Subhalo 12/12 in Galaxy Group ID 2093 with total pairs 66015
# Intermediate save after processing 1200 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2185 with total pairs 91090
# Intermediate save after processing 1300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 2281 with total pairs 45021
# Intermediate save after processing 1400 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2380 with total pairs 91605
# Intermediate save after processing 1500 galaxy groups.
# Processing Subhalo 15/15 in Galaxy Group ID 2476 with total pairs 10503
# Intermediate save after processing 1600 galaxy groups.
# Processing Subhalo 14/14 in Galaxy Group ID 2580 with total pairs 915
# Intermediate save after processing 1700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 2680 with total pairs 155556
# Intermediate save after processing 1800 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 2792 with total pairs 3670136
# Intermediate save after processing 1900 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 2893 with total pairs 556
# Intermediate save after processing 2000 galaxy groups.
# Processing Subhalo 11/11 in Galaxy Group ID 3002 with total pairs 55020
# Intermediate save after processing 2100 galaxy groups.
# Processing Subhalo 7/7 in Galaxy Group ID 3110 with total pairs 217861
# Intermediate save after processing 2200 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3230 with total pairs 3610555
# Intermediate save after processing 2300 galaxy groups.
# Processing Subhalo 10/10 in Galaxy Group ID 3351 with total pairs 45645
# Intermediate save after processing 2400 galaxy groups.
# Processing Subhalo 8/8 in Galaxy Group ID 3486 with total pairs 2878531
# Intermediate save after processing 2500 galaxy groups.
# Processing Subhalo 9/9 in Galaxy Group ID 3623 with total pairs 3645103
# Intermediate save after processing 2600 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 3766 with total pairs 6 45528
# Intermediate save after processing 2700 galaxy groups.
# Processing Subhalo 6/6 in Galaxy Group ID 3927 with total pairs 1578246
# Intermediate save after processing 2800 galaxy groups.
# Processing Subhalo 5/5 in Galaxy Group ID 4156 with total pairs 1066676
# Intermediate save after processing 2900 galaxy groups.
# Processing Subhalo 4/4 in Galaxy Group ID 4505 with total pairs 60558
# Intermediate save after processing 3000 galaxy groups.
# Processing Subhalo 39/39 in Galaxy Group ID 428 with total pairs 741505
# Intermediate save after processing 3100 galaxy groups.
# Processing Subhalo 47/47 in Galaxy Group ID 518 with total pairs 108106
# Intermediate save after processing 3200 galaxy groups.
# Processing Subhalo 38/38 in Galaxy Group ID 608 with total pairs 703175
# Intermediate save after processing 3300 galaxy groups.
# Processing Subhalo 32/32 in Galaxy Group ID 699 with total pairs 496860
# Intermediate save after processing 3400 galaxy groups.
# Processing Subhalo 28/28 in Galaxy Group ID 789 with total pairs 378110
# Intermediate save after processing 3500 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 879 with total pairs 231811
# Intermediate save after processing 3600 galaxy groups.
# Processing Subhalo 22/22 in Galaxy Group ID 969 with total pairs 23155
# Intermediate save after processing 3700 galaxy groups.
# Processing Subhalo 16/16 in Galaxy Group ID 999 with total pairs 12026
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# warning ax is none
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar/pairwise_polar_difference_TNG300-1_z0p0.pdf
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/pairwise_polar_difference_allMasses_TNG300-1_z0p0_overlay.pdf
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:247: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x_smooth, spline(x_smooth),'k--', alpha=0.5, linewidth=3, c=scatter_color, label=label)
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/MRL_distribution_curves_TNG300-1_z0p0.pdf
# (np.float64(-1.5792853034413348), np.float64(12.716473903338482))
# (np.float64(-1.5792853034413348), np.float64(12.716473903338482))
# Resuming from existing temp file: MRL_values_280.hdf5
# final: [np.float64(0.0768305673514619), np.float64(0.06112656128062886), np.float64(0.06796948860329918)]
# Progress: Processing Galaxy Group 100 / 280 with 71 satellites
# Intermediate save after processing 100 galaxy groups.
# Progress: Processing Galaxy Group 200 / 280 with 180 satellites
# Intermediate save after processing 200 galaxy groups.
# Progress: Processing Galaxy Group 280 / 280 with 67 satellitess
# Final save after processing all galaxy groups.
# 99th percentile MRL: 0.2600953434133876ution for Galaxy Group 280 / 280 with 67 satellitess
# Overall number of MRL values above 99th percentile: 65 out of 840
# len listGG: 1, len MRL_values: 840, len random_MRL_values: 280
# processing galaxy group 164/280 for fraction
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:247: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x_smooth, spline(x_smooth),'k--', alpha=0.5, linewidth=3, c=scatter_color, label=label)
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/MRL_distribution_curves_overlay_TNG300-1_z0p0.pdf
# Resuming from existing temp file: MRL_values_3032.hdf5
# Progress: Processing Galaxy Group 100 / 3033 with 21 satellites
# Intermediate save after processing 100 galaxy groups.
# Progress: Processing Galaxy Group 200 / 3033 with 24 satellites
# Intermediate save after processing 200 galaxy groups.
# Progress: Processing Galaxy Group 300 / 3033 with 12 satellites
# Intermediate save after processing 300 galaxy groups.
# Progress: Processing Galaxy Group 400 / 3033 with 14 satellites
# Intermediate save after processing 400 galaxy groups.
# Progress: Processing Galaxy Group 500 / 3033 with 19 satellites
# Intermediate save after processing 500 galaxy groups.
# Progress: Processing Galaxy Group 600 / 3033 with 22 satellites
# Intermediate save after processing 600 galaxy groups.
# Progress: Processing Galaxy Group 700 / 3033 with 30 satellites
# Intermediate save after processing 700 galaxy groups.
# Progress: Processing Galaxy Group 800 / 3033 with 14 satellites
# Intermediate save after processing 800 galaxy groups.
# Progress: Processing Galaxy Group 900 / 3033 with 12 satellites
# Intermediate save after processing 900 galaxy groups.
# Progress: Processing Galaxy Group 1000 / 3033 with 12 satellites
# Intermediate save after processing 1000 galaxy groups.
# Progress: Processing Galaxy Group 1100 / 3033 with 17 satellites
# Intermediate save after processing 1100 galaxy groups.
# Progress: Processing Galaxy Group 1200 / 3033 with 8 satellitess
# Intermediate save after processing 1200 galaxy groups.
# Progress: Processing Galaxy Group 1300 / 3033 with 14 satellites
# Intermediate save after processing 1300 galaxy groups.
# Progress: Processing Galaxy Group 1400 / 3033 with 11 satellites
# Intermediate save after processing 1400 galaxy groups.
# Progress: Processing Galaxy Group 1500 / 3033 with 5 satellitess
# Intermediate save after processing 1500 galaxy groups.
# Progress: Processing Galaxy Group 1600 / 3033 with 10 satellites
# Intermediate save after processing 1600 galaxy groups.
# Progress: Processing Galaxy Group 1700 / 3033 with 13 satellites
# Intermediate save after processing 1700 galaxy groups.
# Progress: Processing Galaxy Group 1800 / 3033 with 9 satellitess
# Intermediate save after processing 1800 galaxy groups.
# Progress: Processing Galaxy Group 1900 / 3033 with 9 satellitess
# Intermediate save after processing 1900 galaxy groups.
# Progress: Processing Galaxy Group 2000 / 3033 with 8 satellitess
# Intermediate save after processing 2000 galaxy groups.
# Progress: Processing Galaxy Group 2100 / 3033 with 11 satellites
# Intermediate save after processing 2100 galaxy groups.
# Progress: Processing Galaxy Group 2200 / 3033 with 12 satellites
# Intermediate save after processing 2200 galaxy groups.
# Progress: Processing Galaxy Group 2300 / 3033 with 13 satellites
# Intermediate save after processing 2300 galaxy groups.
# Progress: Processing Galaxy Group 2400 / 3033 with 10 satellites
# Intermediate save after processing 2400 galaxy groups.
# Progress: Processing Galaxy Group 2500 / 3033 with 8 satellitess
# Intermediate save after processing 2500 galaxy groups.
# Progress: Processing Galaxy Group 2600 / 3033 with 7 satellitess
# Intermediate save after processing 2600 galaxy groups.
# Progress: Processing Galaxy Group 2700 / 3033 with 8 satellitess
# Intermediate save after processing 2700 galaxy groups.
# Progress: Processing Galaxy Group 2800 / 3033 with 20 satellites
# Intermediate save after processing 2800 galaxy groups.
# Progress: Processing Galaxy Group 2900 / 3033 with 23 satellites
# Intermediate save after processing 2900 galaxy groups.
# Progress: Processing Galaxy Group 3000 / 3033 with 23 satellites
# Intermediate save after processing 3000 galaxy groups.
# Progress: Processing Galaxy Group 3033 / 3033 with 17 satellites
# Final save after processing all galaxy groups.
# choosing ax, 0essing random MRL distribution for Galaxy Group 3033 / 3033 with 17 satellites
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:247: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x_smooth, spline(x_smooth),'k--', alpha=0.5, linewidth=3, c=scatter_color, label=label)
# 99th percentile MRL: 0.8111239210915447
# Overall number of MRL values above 99th percentile: 104 out of 9195
# len listGG: 5, len MRL_values: 9195, len random_MRL_values: 3033
# Resuming from existing temp file: MRL_values_420.hdf5
# Progress: Processing Galaxy Group 100 / 420 with 47 satellites
# Intermediate save after processing 100 galaxy groups.
# Progress: Processing Galaxy Group 200 / 420 with 42 satellites
# Intermediate save after processing 200 galaxy groups.
# Progress: Processing Galaxy Group 300 / 420 with 43 satellites
# Intermediate save after processing 300 galaxy groups.
# Progress: Processing Galaxy Group 400 / 420 with 30 satellites
# Intermediate save after processing 400 galaxy groups.
# Progress: Processing Galaxy Group 420 / 420 with 26 satellites
# Final save after processing all galaxy groups.
# choosing ax, 1essing random MRL distribution for Galaxy Group 420 / 420 with 26 satellites
# 99th percentile MRL: 0.3681158021917084
# Overall number of MRL values above 99th percentile: 57 out of 1260
# len listGG: 5, len MRL_values: 1260, len random_MRL_values: 420
# Resuming from existing temp file: MRL_values_268.hdf5
# Progress: Processing Galaxy Group 100 / 268 with 83 satellites
# Intermediate save after processing 100 galaxy groups.
# Progress: Processing Galaxy Group 200 / 268 with 44 satellitess
# Intermediate save after processing 200 galaxy groups.
# Progress: Processing Galaxy Group 268 / 268 with 67 satellitess
# Final save after processing all galaxy groups.
# choosing ax, 2essing random MRL distribution for Galaxy Group 268 / 268 with 67 satellitess
# 99th percentile MRL: 0.2620216558461764
# Overall number of MRL values above 99th percentile: 60 out of 804
# len listGG: 5, len MRL_values: 804, len random_MRL_values: 268
# Resuming from existing temp file: MRL_values_9.hdf5
# Progress: Processing Galaxy Group 9 / 9 with 307 satellites
# Final save after processing all galaxy groups.
# choosing ax, 3essing random MRL distribution for Galaxy Group 9 / 9 with 307 satellites
# 99th percentile MRL: 0.1270768370178407
# Overall number of MRL values above 99th percentile: 12 out of 27
# len listGG: 5, len MRL_values: 27, len random_MRL_values: 9
# Resuming from existing temp file: MRL_values_3.hdf5
# final: [np.float64(0.0768305673514619), np.float64(0.06112656128062886), np.float64(0.06796948860329918)]
# Progress: Processing Galaxy Group 3 / 3 with 420 satellites
# Final save after processing all galaxy groups.
# choosing ax, 4essing random MRL distribution for Galaxy Group 3 / 3 with 420 satellites
# 99th percentile MRL: 0.09611965853901788
# Overall number of MRL values above 99th percentile: 5 out of 9
# len listGG: 5, len MRL_values: 9, len random_MRL_values: 3
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/MRL_distribution_curves_overlay_TNG300-1_z0p0.pdf
# Finished normal
# Total Galaxy Groups to process: 76 with pairs : 5869
# Resuming from existing temp file: pairwise_differences_206.hdf5
# Processing Subhalo 18/18 in Galaxy Group ID 982 with total pairs 1535
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/high_MRL_pairwise_polar_distribution_TNG300-1.pdf
# total to process: 76
# Total Galaxy Groups to process: 75 with pairs : 2084
# Resuming from existing temp file: pairwise_differences_184.hdf5
# Processing Subhalo 12/12 in Galaxy Group ID 982 with total pairs 668
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# total to process: 76
# Total Galaxy Groups to process: 64 with pairs : 397
# Resuming from existing temp file: pairwise_differences_190.hdf5
# Processing Subhalo 3/3 in Galaxy Group ID 982 with total pairs 301
# Final save after processing all galaxy groups.
# Accumulating results from saved batches...
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/high_MRL_pairwise_polar_distribution_inner_outer_TNG300-1.pdf
# Galaxy Group ID: 1413, Num Subhalos: 15
# Galaxy Group ID: 1475, Num Subhalos: 18
# Galaxy Group ID: 1523, Num Subhalos: 20
# Galaxy Group ID: 1611, Num Subhalos: 15
# Galaxy Group ID: 1646, Num Subhalos: 21
# Galaxy Group ID: 1701, Num Subhalos: 13
# Galaxy Group ID: 1753, Num Subhalos: 25
# Galaxy Group ID: 1759, Num Subhalos: 12
# Galaxy Group ID: 1777, Num Subhalos: 14
# Galaxy Group ID: 1809, Num Subhalos: 8
# Galaxy Group ID: 1908, Num Subhalos: 12
# Galaxy Group ID: 1930, Num Subhalos: 10
# Galaxy Group ID: 1941, Num Subhalos: 19
# Galaxy Group ID: 1944, Num Subhalos: 17
# Galaxy Group ID: 2027, Num Subhalos: 14
# Galaxy Group ID: 2068, Num Subhalos: 10
# Galaxy Group ID: 2078, Num Subhalos: 19
# Galaxy Group ID: 2080, Num Subhalos: 13
# Galaxy Group ID: 2084, Num Subhalos: 15
# Galaxy Group ID: 2233, Num Subhalos: 16
# Galaxy Group ID: 2300, Num Subhalos: 16
# Galaxy Group ID: 2341, Num Subhalos: 11
# Galaxy Group ID: 2353, Num Subhalos: 13
# Galaxy Group ID: 2360, Num Subhalos: 19
# Galaxy Group ID: 2382, Num Subhalos: 10
# Galaxy Group ID: 2395, Num Subhalos: 10
# Galaxy Group ID: 2479, Num Subhalos: 14
# Galaxy Group ID: 2555, Num Subhalos: 13
# Galaxy Group ID: 2564, Num Subhalos: 8
# Galaxy Group ID: 2579, Num Subhalos: 16
# Galaxy Group ID: 2580, Num Subhalos: 15
# Galaxy Group ID: 2582, Num Subhalos: 9
# Galaxy Group ID: 2609, Num Subhalos: 13
# Galaxy Group ID: 2614, Num Subhalos: 8
# Galaxy Group ID: 2615, Num Subhalos: 11
# Galaxy Group ID: 2633, Num Subhalos: 9
# Galaxy Group ID: 2675, Num Subhalos: 9
# Galaxy Group ID: 2695, Num Subhalos: 11
# Galaxy Group ID: 2718, Num Subhalos: 12
# Galaxy Group ID: 2789, Num Subhalos: 10
# Galaxy Group ID: 2815, Num Subhalos: 10
# Galaxy Group ID: 2817, Num Subhalos: 14
# Galaxy Group ID: 2852, Num Subhalos: 13
# Galaxy Group ID: 2879, Num Subhalos: 16
# Galaxy Group ID: 2881, Num Subhalos: 7
# Galaxy Group ID: 2889, Num Subhalos: 9
# Galaxy Group ID: 2903, Num Subhalos: 14
# Galaxy Group ID: 2941, Num Subhalos: 9
# Galaxy Group ID: 2954, Num Subhalos: 13
# Galaxy Group ID: 2963, Num Subhalos: 10
# Galaxy Group ID: 2964, Num Subhalos: 10
# Galaxy Group ID: 2966, Num Subhalos: 10
# Galaxy Group ID: 2979, Num Subhalos: 11
# Galaxy Group ID: 2986, Num Subhalos: 11
# Galaxy Group ID: 2993, Num Subhalos: 8
# Galaxy Group ID: 2994, Num Subhalos: 10
# Galaxy Group ID: 2998, Num Subhalos: 7
# Galaxy Group ID: 3034, Num Subhalos: 7
# Galaxy Group ID: 3044, Num Subhalos: 5
# Galaxy Group ID: 3048, Num Subhalos: 8
# Galaxy Group ID: 3050, Num Subhalos: 13
# Galaxy Group ID: 3065, Num Subhalos: 8
# Galaxy Group ID: 3081, Num Subhalos: 11
# Galaxy Group ID: 3086, Num Subhalos: 12
# Galaxy Group ID: 3095, Num Subhalos: 14
# Galaxy Group ID: 3099, Num Subhalos: 8
# Galaxy Group ID: 3108, Num Subhalos: 3
# Galaxy Group ID: 3109, Num Subhalos: 14
# Galaxy Group ID: 3111, Num Subhalos: 9
# Galaxy Group ID: 3122, Num Subhalos: 8
# Galaxy Group ID: 3125, Num Subhalos: 14
# Galaxy Group ID: 3158, Num Subhalos: 12
# Galaxy Group ID: 3164, Num Subhalos: 5
# Galaxy Group ID: 3191, Num Subhalos: 11
# Galaxy Group ID: 883, Num Subhalos: 23
# Galaxy Group ID: 982, Num Subhalos: 19
# Percentage of High MRL Galaxy Groups with Only 2 Satellites: 0.00% (0 out of 76)
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/satellite_number_distribution_by_mass_bins_TNG300-1.pdf
# choosing ax, 0axy group 999 for M200 distributionn
# choosing ax, 1axy group 946 for M200 distribution
# choosing ax, 2axy group 99 for M200 distributionn
# choosing ax, 3axy group 9 for M200 distributionn
# choosing ax, 4axy group 2 for M200 distribution
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p0/plots/M200_distribution_TNG300-1_z0p0.pdf

# %%
from myproject.utilities.snapshotEnum import SnapshotEnum
# snapshotEnum = SnapshotEnum() #(99, 0, 'z0p0')
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #already processed these snapshots
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisZ0.setSnapshot(snapshot[0])
    # galaxyAnalysisZ0.computeAllPlots()
    # galaxyAnalysisZ0.plot_M200_distribution_for_all_mass_bins()
