# %%
# %load_ext autoreload 
#hopefully this will reload the modules when they are changed specifically when i change the plotting modules
# %autoreload 2

# %% [markdown]
# Plot distribution of m200
# Save the plot data points in txt
# Check what's wrong with bootstrap

# %%
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis
from myproject.listRedshiftGalaxys import ListRedshiftGalaxy
from myproject.utilities.snapshotEnum import SnapshotEnum

# %%
allSnapshotEnums = SnapshotEnum.getAllSnapshots()
# allSnapshots = [snapshotEnum[0] for snapshotEnum in allSnapshotEnums]

#get rid of snapshots < 50:
allSnapshotEnums = [snapshotEnum for snapshotEnum in allSnapshotEnums if snapshotEnum[0] >= 50]
allSnapshots = [snapshotEnum[0] for snapshotEnum in allSnapshotEnums]
print(allSnapshots)
# Out:
# [99, 91, 84, 78, 72, 67, 59, 50]

# %%
mass_bin_labels = [
    '$1e13<M_{200}<1e13.5$',
    '$1e13.5<M_{200}<1e14$',
    '$1e14<M_{200}<1e14.5$',
    '$1e14.5<M_{200}<1e15$',
    '$M_{200}>1e15$',
]

# %%
listRedshiftGalaxyAnalysis = ListRedshiftGalaxy()
listRedshiftGalaxyAnalysis.initializeAllGalaxyAnalysis(snapshot_enums=allSnapshots, simulation='TNG300-1, TNG-Cluster', luminosityType='Default', generalErrorbar='poisson', generalRewrite=True)
# galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=True)
# Out:
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Progress: 352/352
# Loaded 352 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1_.hdf5
# Progress: 3367/3367g Galaxy Group ID 4084 / 4084
# Loaded 3367 galaxy groups from HDF5.
# Progress: 352/352
# Loaded 352 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p1/data/galaxy_data_TNG300-1_.hdf5
# Progress: 3006/3006g Galaxy Group ID 3719 / 3719
# Loaded 3006 galaxy groups from HDF5.
# Progress: 352/352
# Loaded 352 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p2/data/galaxy_data_TNG300-1_.hdf5
# Progress: 2664/2664g Galaxy Group ID 3358 / 3358
# Loaded 2664 galaxy groups from HDF5.
# Progress: 360/360
# Loaded 360 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p3/data/galaxy_data_TNG300-1_.hdf5
# Progress: 2361/2361g Galaxy Group ID 3024 / 3024
# Loaded 2361 galaxy groups from HDF5.
# Progress: 366/366
# Loaded 366 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p4/data/galaxy_data_TNG300-1_.hdf5
# Progress: 2054/2054g Galaxy Group ID 2727 / 2727
# Loaded 2054 galaxy groups from HDF5.
# Progress: 370/370
# Loaded 370 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p5/data/galaxy_data_TNG300-1_.hdf5
# Progress: 1531/1531g Galaxy Group ID 2424 / 2424
# Loaded 1531 galaxy groups from HDF5.
# Progress: 379/379
# Loaded 379 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p7/data/galaxy_data_TNG300-1_.hdf5
# Progress: 900/900ing Galaxy Group ID 1910 / 1910
# Loaded 900 galaxy groups from HDF5.
# Progress: 392/392
# Loaded 392 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z1p0/data/galaxy_data_TNG300-1_.hdf5
# Progress: Processing Galaxy Group ID 1292 / 1292

# %%
#print num of clusters and satellites in each snapshot and mass bin:
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup


for snapshotEnum in allSnapshotEnums:
    snapshot = snapshotEnum[0]
    print(f"Snapshot: {snapshot}")
    galaxyAnalysis = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot)
    mass_bins : list[ListGalaxyGroup] = [
        galaxyAnalysis.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysis.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysis.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysis.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysis.filtered_gt15_list_of_galaxy_groups,
    ]
    for mass_bin, mass_bin_label in zip(mass_bins, mass_bin_labels):
        num_clusters = len(mass_bin.getAllGalaxyGroups())
        num_satellites = sum([len(galaxy_group.getSatelliteSubhalos()) for galaxy_group in mass_bin.getAllGalaxyGroups()])
        print(f" Mass bin: {mass_bin_label}, Num clusters: {num_clusters}, Num satellites: {num_satellites}")
# Out:
# Snapshot: 99
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 2586, Num satellites: 22426
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 866, Num satellites: 22694
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 292, Num satellites: 22543
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 242, Num satellites: 52867
#  Mass bin: $M_{200}>1e15$, Num clusters: 98, Num satellites: 47946
# Snapshot: 91
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 2367, Num satellites: 24438
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 780, Num satellites: 23521
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 287, Num satellites: 26672
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 234, Num satellites: 59144
#  Mass bin: $M_{200}>1e15$, Num clusters: 51, Num satellites: 27797
# Snapshot: 84
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 2152, Num satellites: 25750
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 686, Num satellites: 23632
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 273, Num satellites: 27656
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 219, Num satellites: 58958
#  Mass bin: $M_{200}>1e15$, Num clusters: 28, Num satellites: 16842
# Snapshot: 78
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 1939, Num satellites: 26388
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 610, Num satellites: 23914
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 285, Num satellites: 33064
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 174, Num satellites: 52176
#  Mass bin: $M_{200}>1e15$, Num clusters: 16, Num satellites: 10345
# Snapshot: 72
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 1765, Num satellites: 27558
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 540, Num satellites: 24796
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 278, Num satellites: 35565
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 136, Num satellites: 43820
#  Mass bin: $M_{200}>1e15$, Num clusters: 8, Num satellites: 5565
# Snapshot: 67
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 1570, Num satellites: 28344
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 486, Num satellites: 25030
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 262, Num satellites: 37529
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 104, Num satellites: 35918
#  Mass bin: $M_{200}>1e15$, Num clusters: 2, Num satellites: 1350
# Snapshot: 59
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 1234, Num satellites: 27689
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 408, Num satellites: 25785
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 233, Num satellites: 40088
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 35, Num satellites: 12740
#  Mass bin: $M_{200}>1e15$, Num clusters: 0, Num satellites: 0
# Snapshot: 50
#  Mass bin: $1e13<M_{200}<1e13.5$, Num clusters: 827, Num satellites: 24904
#  Mass bin: $1e13.5<M_{200}<1e14$, Num clusters: 328, Num satellites: 26524
#  Mass bin: $1e14<M_{200}<1e14.5$, Num clusters: 133, Num satellites: 25500
#  Mass bin: $1e14.5<M_{200}<1e15$, Num clusters: 4, Num satellites: 1996
#  Mass bin: $M_{200}>1e15$, Num clusters: 0, Num satellites: 0

# %%
#check in snapshot 0, that all galaxies in the gt13 ls13p5 mass bin have M200 between 1e13 and 1e13.5:
snapshotEnum = SnapshotEnum.SNAPSHOT_99
snapshot = snapshotEnum.value[0]
print(f"Snapshot: {snapshot}")
galaxyAnalysis = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot)
mass_bin = galaxyAnalysis.filtered_gt13_ls13p5_list_of_galaxy_groups
for galaxy_group in mass_bin.getAllGalaxyGroups():
    M200 = galaxy_group.getMCrit200()
    assert M200 > 1e13 and M200 < 10**13.5, f"Galaxy group with M200={M200:.2e} is not in the gt13 ls13p5 mass bin!"
    
mass_bin = galaxyAnalysis.filtered_gt13p5_ls14_list_of_galaxy_groups
for galaxy_group in mass_bin.getAllGalaxyGroups():
    M200 = galaxy_group.getMCrit200()
    assert M200 > 10**13.5 and M200 < 10**14, f"Galaxy group with M200={M200:.2e} is not in the gt13p5 ls14 mass bin!"
    
mass_bin = galaxyAnalysis.filtered_gt14_ls14p5_list_of_galaxy_groups
for galaxy_group in mass_bin.getAllGalaxyGroups():
    M200 = galaxy_group.getMCrit200()
    assert M200 > 10**14 and M200 < 10**14.5, f"Galaxy group with M200={M200:.2e} is not in the gt14 ls14p5 mass bin!"
    
mass_bin = galaxyAnalysis.filtered_gt14p5_ls15_list_of_galaxy_groups
for galaxy_group in mass_bin.getAllGalaxyGroups():
    M200 = galaxy_group.getMCrit200()
    assert M200 > 10**14.5 and M200 < 10**15, f"Galaxy group with M200={M200:.2e} is not in the gt14p5 ls15 mass bin!"
    
mass_bin = galaxyAnalysis.filtered_gt15_list_of_galaxy_groups
for galaxy_group in mass_bin.getAllGalaxyGroups():
    M200 = galaxy_group.getMCrit200()
    assert M200 > 10**15, f"Galaxy group with M200={M200:.2e} is not in the gt15 mass bin!"
# Out:
# Snapshot: 99

# %% [markdown]
# # check snaphot compared to z=0

# %%
# galaxyAnalysisZ0 = GalaxyAnalysis(generalRewrite=True, sim='TNG-Cluster',luminosityType='Default')
# Out:
# Progress: 5612/5612
# Loaded 5612 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/data/galaxy_data_TNG-Cluster_.hdf5
# total to process: 5612
# total to process: 5052alaxy Group ID 5612 / 5612
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# Progress: Processing Galaxy Group ID 5052 / 5052

# %%
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue  # too high redshift

    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    # redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
    galaxyAnalysisSnapshot.computeAllPlots()

# %%
#check the number of galaxy groups loaded
print(f'Number of galaxy groups loaded: {galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups()}')
print(f"Number of subhalos in GG 0: {galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getGalaxyGroupI(0).getNumSubhalos()}")
print(f"Number of subhalos in GG 10: {galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getGalaxyGroupI(10).getNumSubhalos()}")
# print(f"Number of subhalos in GG 912: {galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getGalaxyGroupI(912).getNumSubhalos()}")
rangeSat, allNumSat = galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getRangeOfNumSubhalos()
print(f' Range of satellites: {rangeSat}')
print(f' numer of sat == 1: {len(np.where(np.array(allNumSat) < 5)[0])}')

# %%
#from galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups, save in a txt file
#save all galaxy groups with id, numSat, sum of flags for all satellites, mass, central mass, central flag, central r band, first satellite mass, first satellite flag, first satellite r band
with open('tng_cluster_galaxy_groups_info.txt', 'w') as f:
    f.write('id \t,numSat \t,sumFlags \t,mass \t,centralMass \t,centralFlag \t,centralRband \t,firstSatMass \t,firstSatFlag \t,firstSatRband \n')
    for i in range(galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups()):
        gg = galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getGalaxyGroupI(i)
        id = gg.getGroupID()
        numSat = len(gg.getSatelliteSubhalos())
        sumFlags = np.sum([int(subhalo.getFlag()) for subhalo in gg.getSatelliteSubhalos()])
        mass = f'{gg.getMCrit200():.2e}'
        centralMass = f'{gg.getCentralSubhalo().getStellarMass():.2e}'
        centralFlag = gg.getCentralSubhalo().getFlag()
        centralRband = f'{gg.getCentralSubhalo().getDefaultRbandMagnitude():.2}'
        firstSatMass = f'{gg.getSatelliteSubhalos()[0].getStellarMass():.2e}'
        firstSatFlag = gg.getSatelliteSubhalos()[0].getFlag()
        firstSatRband = f'{gg.getSatelliteSubhalos()[0].getDefaultRbandMagnitude():.2}'
        f.write(f'{id} \t,{numSat} \t,{sumFlags} \t,{mass} \t,{centralMass} \t,{centralFlag} \t,{centralRband} \t,{firstSatMass} \t,{firstSatFlag} \t,{firstSatRband} \n')

# %%
galaxyAnalysisZ0.computeAllPlots()

# %%
galaxyAnalysisZ0.setSnapshot(99, newsim='TNG-Cluster', luminosityType='Default')
# Out:
# Progress: 5612/5612
# Loaded 5612 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/data/galaxy_data_TNG-Cluster_.hdf5
# total to process: 5612
# total to process: 5052alaxy Group ID 5612 / 5612
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# Progress: Processing Galaxy Group ID 5052 / 5052

# %%
galaxyAnalysisZ0.MRLDistributionPlots()

# %%
from myproject.utilities.snapshotEnum import SnapshotEnum
# snapshotEnum = SnapshotEnum() #(99, 0, 'z0p0')
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] == 99: #already processed these snapshots
        continue
    if snapshot[0] > 70:
        continue
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisZ0.setSnapshot(snapshot[0], newsim='TNG-Cluster', luminosityType='Default')
    galaxyAnalysisZ0.computeAllPlots()
    # galaxyAnalysisZ0.plot_M200_distribution_for_all_mass_bins()

# %%
galaxyAnalysisZ0TNG300 = GalaxyAnalysis(generalRewrite=True, sim='TNG300-1',luminosityType='SDSS')
# Out:
# Progress: 3733/3733
# Loaded 3733 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG300-1/z0p0/data/galaxy_data_TNG300-1_.hdf5
# total to process: 3733
# total to process: 3732alaxy Group ID 3733 / 3733
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# total to process: 3732alaxy Group ID 3732 / 3732
# Progress: Processing Galaxy Group ID 3732 / 3732

# %%
print(galaxyAnalysisZ0.sim)
# Out:
# TNG300-1

# %%
from myproject.utilities.snapshotEnum import SnapshotEnum
# snapshotEnum = SnapshotEnum() #(99, 0, 'z0p0')
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] != 99: #already processed these snapshots
        continue
    # if snapshot[0] > 60:
    #     continue
    print(f"Processing snapshot {snapshot[0]}...")
    listRedshiftGG = []
    galaxyAnalysisZ0.setSnapshot(snapshot[0], newsim='TNG-Cluster', luminosityType='Default')
    groupList = []
    groupList.append((galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups, f'$M_{{200}}>14$, z={galaxyAnalysisZ0.snapshot_dic[snapshot[0]][1]}, TNG-Cluster'))
    groupList.append((galaxyAnalysisZ0TNG300.filtered_gt14_list_of_galaxy_groups, f'$M_{{200}}>14$, z=0.0, TNG300-1'))
    listRedshiftGG.append(groupList)

    polar_plotter, polar_fig, polar_ax = galaxyAnalysisZ0.overlay_polar_pairwise_across_redshifts(listRedshiftGG=listRedshiftGG, mrlOrPolar='polar', oneaxis=True)#, plotRows=2, plotCols=3)
    # galaxyAnalysisZ0.plot_M200_distribution_for_all_mass_bins()
    polar_ax.legend(loc='upper right')  # Add legend to the last subplot
    polar_plotter.save_figure(polar_fig, galaxyAnalysisZ0.scratchPlotDirc + f'/pairwise_polar_difference_cluster_vs_tng300z0_{galaxyAnalysisZ0.sim}{galaxyAnalysisZ0.plotEndingFormat}')
# Out:
# Processing snapshot 99...
# Progress: 5612/5612
# Loaded 5612 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/data/galaxy_data_TNG-Cluster_.hdf5
# total to process: 5612
# total to process: 5052alaxy Group ID 5612 / 5612
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# COMPUTING FOR redshift index: 0, label: $M_{200}>14$, z=z0p0, TNG-Cluster
# Total Galaxy Groups to process: 913 with pairs : 18000496
# Processing Subhalo 14/14 in Galaxy Group ID 4254241 with total pairs 91103841COMPUTING FOR redshift index: 0, label: $M_{200}>14$, z=0.0, TNG300-1
# Total Galaxy Groups to process: 280 with pairs : 1753902
# Processing Subhalo 7/550 in Galaxy Group ID 0 with total pairs 150975
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Processing Subhalo 54/54 in Galaxy Group ID 99 with total pairs 1431606Figure saved to: /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/plots/pairwise_polar_difference_cluster_vs_tng300z0_TNG-Cluster

# %%
# make a plot of the number of galaxies per unit volume, per unit r-band magnitude.  That’s the luminosity function
L=205*1e3
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
import numpy as np
import matplotlib.pyplot as plt
def plot_luminosity_function(list_gg:ListGalaxyGroup, plot_dirc:str='', label=None,
                             color=None, hist_kwargs=None, ax=None):
    rmags = []
    for gg in list_gg.getAllGalaxyGroups():
        for galaxy in gg.getSubhalos():
            rmags.append(galaxy.getRbandMagnitude()) if label=='SDSS' else rmags.append(galaxy.getDefaultRbandMagnitude())
    
    bins ='auto'
    xlow=-23
    xhigh=-7
    bins = np.linspace(xlow, xhigh, 100)
    volume =L**3
    print(f"unit volume used: {volume}")
    # print(f"rmags: {rmags}")
    
    mags = np.asarray(rmags)
    hist, edges = np.histogram(mags, bins=bins)
    width = np.diff(edges)
    values = hist.astype(float) / width
    if volume is not None:
        values = values / float(volume)
    centers = edges[:-1] + 0.5 * width
    if ax is None:
        fig, ax = plt.subplots(figsize=(8,5))
    hk = {} if hist_kwargs is None else dict(hist_kwargs)
    ax.step(centers, values, where='mid', label=label, color=color, **hk)
    ax.set_xlabel('r-band magnitude')
    ylabel = 'Number / mag / L^3'
    title = 'Luminosity Function'
    ax.set_ylabel(ylabel)
    ax.legend(loc='upper right')
    ax.set_title(title)
    ax.invert_xaxis()
    ax.set_xlim(xlow, xhigh)
    ax.grid(True, which='both', linestyle='--', alpha=0.5)
    return centers, values

# %%
figSDSS, axSDSS = plt.subplots(figsize=(9,6))
plot_luminosity_function(galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups, ax=axSDSS, label='TNG-Cluster')
# Out:
# unit volume used: 8615125000000000.0
# (array([-22.91919192, -22.75757576, -22.5959596 , -22.43434343,
#         -22.27272727, -22.11111111, -21.94949495, -21.78787879,
#         -21.62626263, -21.46464646, -21.3030303 , -21.14141414,
#         -20.97979798, -20.81818182, -20.65656566, -20.49494949,
#         -20.33333333, -20.17171717, -20.01010101, -19.84848485,
#         -19.68686869, -19.52525253, -19.36363636, -19.2020202 ,
#         -19.04040404, -18.87878788, -18.71717172, -18.55555556,
#         -18.39393939, -18.23232323, -18.07070707, -17.90909091,
#         -17.74747475, -17.58585859, -17.42424242, -17.26262626,
#         -17.1010101 , -16.93939394, -16.77777778, -16.61616162,
#         -16.45454545, -16.29292929, -16.13131313, -15.96969697,
#         -15.80808081, -15.64646465, -15.48484848, -15.32323232,
#         -15.16161616, -15.        , -14.83838384, -14.67676768,
#         -14.51515152, -14.35353535, -14.19191919, -14.03030303,
#         -13.86868687, -13.70707071, -13.54545455, -13.38383838,
#         -13.22222222, -13.06060606, -12.8989899 , -12.73737374,
#         -12.57575758, -12.41414141, -12.25252525, -12.09090909,
#         -11.92929293, -11.76767677, -11.60606061, -11.44444444,
#         -11.28282828, -11.12121212, -10.95959596, -10.7979798 ,
#         -10.63636364, -10.47474747, -10.31313131, -10.15151515,
#          -9.98989899,  -9.82828283,  -9.66666667,  -9.50505051,
#          -9.34343434,  -9.18181818,  -9.02020202,  -8.85858586,
#          -8.6969697 ,  -8.53535354,  -8.37373737,  -8.21212121,
#          -8.05050505,  -7.88888889,  -7.72727273,  -7.56565657,
#          -7.4040404 ,  -7.24242424,  -7.08080808]),
#  array([1.75962334e-13, 1.96072315e-13, 2.46347267e-13, 2.49938335e-13,
#         3.31814686e-13, 4.00763193e-13, 4.53192786e-13, 5.24295933e-13,
#         6.00426575e-13, 6.77275431e-13, 8.52519551e-13, 9.92571205e-13,
#         1.07732041e-12, 1.19223459e-12, 1.31648554e-12, 1.40698046e-12,
#         1.33515910e-12, 1.38327941e-12, 1.38902512e-12, 1.45438255e-12,
#         1.44863685e-12, 1.56498745e-12, 1.56570566e-12, 1.67631056e-12,
#         1.67200128e-12, 1.77255118e-12, 1.79481580e-12, 1.83647219e-12,
#         1.90542070e-12, 1.90039320e-12, 1.85514575e-12, 2.02033488e-12,
#         1.95354101e-12, 1.99735204e-12, 1.93558567e-12, 2.06989162e-12,
#         2.05480913e-12, 2.09574730e-12, 2.19126971e-12, 2.11513907e-12,
#         2.12806692e-12, 2.29828354e-12, 2.26093643e-12, 2.34496743e-12,
#         2.31982995e-12, 2.48286444e-12, 2.57264114e-12, 2.64087143e-12,
#         2.84125303e-12, 1.47808360e-12, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]))

# %%
# %pwd
# Out:
# '/home/poulin.al/git/sat-lopsidedness/src/myproject'

# %%
#given a txt file that looks like:
# '''
# # # TNG-Cluster Catalog (see: https://www.tng-project.org/data/cluster/ and http://arxiv.org/abs/2311.06338)
# # Note: this table is dynamic, and new columns are frequently added. Requests for additions are welcome.
# # If you use quantities from this table, please also cite the relevant paper, when indicated for a column.
# # [352] halos, all properties at [z=0] unless specified otherwise.
# #
# # columns: 
# # [1] origID: Original Parent Halo ID (for reference only)
# # [2] haloID: TNG-Cluster Halo ID (in the group catalog)
# # [3] mhalo_200c: Halo mass within r200c [log M$_\odot$]
# # [4] mhalo_500c: Halo mass within r500c [log M$_\odot$]
# # [5] r200c: Halo radius r200c [Mpc]
# #
#    0        0 15.29 15.13 2.629 1.711 12.58 12.76 11.74 10.51 0.145   nan 45.28 -3.69  34.05 -0.79  8.11 0.49 854 502 248  62  CC  0.45  39.57  -0.93  1.69 0.14 0.64 0  0.23  0.67  0.55  0.60  0.45  0.72 
#    1   252455 15.40 15.27 2.871 1.912 12.16 12.49 11.37  9.35 0.126   nan 44.96 -3.48  11.91 -2.16  8.36 0.38 708 423 202  63 NCC 12.96 566.18  -2.20  0.19 0.01 0.12 0  1.91  2.81  1.84  1.35  1.75  1.93 
#    2   476245 15.16 14.99 2.378 1.541 12.16 12.40 11.82 10.17 0.132   nan 44.59 -3.94   3.61 -2.35  8.17 0.39 718 427 210  68 NCC 16.48 515.67  -2.41  0.19 0.01 0.10 0  1.41  2.29  2.23  1.04  1.26  1.63 
#    3   692426 15.36 15.14 2.782 1.731 12.53 12.72 11.55 10.19 0.149   nan 45.06 -3.61   9.16 -1.33  7.95 0.08 628 363 167  49 WCC  1.13  57.04  -1.44  0.81 0.07 0.26 0  1.02  0.46  0.93  2.68  2.72  2.84 
# '''
   
#read the id's
primary_halo_ids = []
with open('tng-cluster-primaryinfo.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        print(line)
        if line.startswith('#') or line.strip() == '':
            continue  # Skip header or empty lines
        parts = line.split()
        if len(parts) > 1:
            primary_halo_ids.append(int(parts[1]))  # Assuming haloID is the second column
# Out:
# # TNG-Cluster Catalog (see: https://www.tng-project.org/data/cluster/ and http://arxiv.org/abs/2311.06338)
#
# # Note: this table is dynamic, and new columns are frequently added. Requests for additions are welcome.
#
# # If you use quantities from this table, please also cite the relevant paper, when indicated for a column.
#
# # [352] halos, all properties at [z=0] unless specified otherwise.
#
# #
#
# # columns:
#
# # [1] origID: Original Parent Halo ID (for reference only)
#
# # [2] haloID: TNG-Cluster Halo ID (in the group catalog)
#
# # [3] mhalo_200c: Halo mass within r200c [log M$_\odot$]
#
# # [4] mhalo_500c: Halo mass within r500c [log M$_\odot$]
#
# # [5] r200c: Halo radius r200c [Mpc]
#
# # [6] r500c: Halo radius r500c [Mpc]
#
# # [7] mstar_30kpc: Stellar mass within 30 kpc [log(M$_\star$ / M$_\odot$]
#
# # [8] mstar_100kpc: Stellar mass within 100 kpc [log(M$_\star$ / M$_\odot$]
#
# # [9] mhi_halo: Neutral HI mass within the (FoF) halo [log M$_\odot$]
#
# # [10] mass_smbh: Mass of central SMBH [log M$_\odot$]
#
# # [11] fgas_r500: Gas fraction within r500c [unitless]
#
# # [12] sfr_30pkpc: Star formation rate within 30 pkpc (nan indicates an upper limit of -3.0) [log M$_\odot$ / yr]
#
# # [13] xray_0.5-2.0kev: X-ray luminosity 0.5-2 keV soft-band, within r500c in 3D [log erg/s]
#
# # [14] szy_r500c: Integrated Y_SZ parameter within r500c in 3D [log Mpc$^2$]
#
# # [15] Bmag_uG_10kpc: Magnetic field magnitude within 10 kpc, mass-weighted mean of log(T)>5.5 gas [micro Gauss]
#
# # [16] ne_10kpc: Electron density within 10 kpc, mass-weighted mean of log(T)>5.5 gas [log cm$^{-3}$]
#
# # [17] temp_10kpc: Temperature within 10 kpc, mass-weighted mean of log(T)>5.5 gas [log K]
#
# # [18] zform: Formation redshift [unitless]
#
# # [19] richness_9.5: Number of satellite galaxies with log(M*) (30pkpc) > 9.5 Msun [unitless]
#
# # [20] richness_10.0: Number of satellite galaxies with log(M*) (30pkpc) > 10.0 Msun [unitless]
#
# # [21] richness_10.5: Number of satellite galaxies with log(M*) (30pkpc) > 10.5 Msun [unitless]
#
# # [22] richness_11.0: Number of satellite galaxies with log(M*) (30pkpc) > 11.0 Msun [unitless]
#
# # [23] coolcore_flag: Cool core status, based on central cooling time (0=CC, 1=WCC, or 2=NCC) {Source: Lehle+2024}
#
# # [24] coolcore_tcool: Central cooling time, computed within a 3D aperture of 0.012*r500c {Source: Lehle+2024} [Gyr]
#
# # [25] coolcore_entropy: Central entropy, computed within a 3D aperture of 0.012*r500c {Source: Lehle+2024} [keV cm$^2$]
#
# # [26] coolcore_ne: Central electron density, computed within a 3D aperture of 0.012*r500c {Source: Lehle+2024} [log cm$^{-3}$]
#
# # [27] coolcore_ne_slope: Central electron density slope (alpha), computed at 0.04*r500c {Source: Lehle+2024} [unitless]
#
# # [28] coolcore_C_phys: X-ray concentration parameter C_phys, computed for 40kpc versus 400kpc. {Source: Lehle+2024} [unitless]
#
# # [29] coolcore_C_scaled: X-ray concentration parameter C_scaled, computed for 0.15*r500c versus r500c. {Source: Lehle+2024} [unitless]
#
# # [30] perseus_like_flag: Perseus-like flag (9=no, 1=yes) {Source: Truong+2024} [unitless]
#
# # [31] peakoffset_xray_x: X-ray peak offset in x-direction [log pkpc]
#
# # [32] peakoffset_xray_y: X-ray peak offset in y-direction [log pkpc]
#
# # [33] peakoffset_xray_z: X-ray peak offset in z-direction [log pkpc]
#
# # [34] peakoffset_sz_x: SZ peak offset in x-direction [log pkpc]
#
# # [35] peakoffset_sz_y: SZ peak offset in y-direction [log pkpc]
#
# # [36] peakoffset_sz_z: SZ peak offset in z-direction [log pkpc]
#
# #
#
#    0        0 15.29 15.13 2.629 1.711 12.58 12.76 11.74 10.51 0.145   nan 45.28 -3.69  34.05 -0.79  8.11 0.49 854 502 248  62  CC  0.45  39.57  -0.93  1.69 0.14 0.64 0  0.23  0.67  0.55  0.60  0.45  0.72
#
#    1   252455 15.40 15.27 2.871 1.912 12.16 12.49 11.37  9.35 0.126   nan 44.96 -3.48  11.91 -2.16  8.36 0.38 708 423 202  63 NCC 12.96 566.18  -2.20  0.19 0.01 0.12 0  1.91  2.81  1.84  1.35  1.75  1.93
#
#    2   476245 15.16 14.99 2.378 1.541 12.16 12.40 11.82 10.17 0.132   nan 44.59 -3.94   3.61 -2.35  8.17 0.39 718 427 210  68 NCC 16.48 515.67  -2.41  0.19 0.01 0.10 0  1.41  2.29  2.23  1.04  1.26  1.63
#
#    3   692426 15.36 15.14 2.782 1.731 12.53 12.72 11.55 10.19 0.149   nan 45.06 -3.61   9.16 -1.33  7.95 0.08 628 363 167  49 WCC  1.13  57.04  -1.44  0.81 0.07 0.26 0  1.02  0.46  0.93  2.68  2.72  2.84
#
#    4   880597 14.94 14.71 2.018 1.248 12.14 12.25 11.66  9.64 0.136   nan 44.51 -4.42   3.04 -1.91  7.79 0.17 641 382 180  53 WCC  3.48 116.71  -2.02  0.57 0.02 0.05 0  2.75  2.41  2.79  2.70  2.36  2.79
#
#    5  1068507 15.16 15.02 2.389 1.575 12.20 12.45 11.56 10.43 0.142   nan 45.08 -3.84  18.00 -1.45  8.07 0.57 628 357 178  47 WCC  1.82  94.28  -1.53  0.49 0.03 0.29 0  0.30  1.18  0.33 -0.03  0.25  0.08
#
# 5122 19429412 14.26 14.00 1.195 0.719 11.71 11.85 10.47  9.24 0.118   nan 43.37 -5.57   1.40 -2.12  7.40 0.23  38  22  12   5 WCC  1.38  52.81  -2.09  0.62 0.03 0.07 0  2.21  2.11  2.08  1.99  1.90  1.78
#
# 5711 19441351 14.31 14.19 1.241 0.837 11.92 12.10 10.39  9.63 0.132   nan 43.89 -5.25   1.52 -1.93  7.68 1.00  35  21   8   4 WCC  2.30  80.52  -1.93  0.37 0.03 0.14 0 -0.53 -0.32 -0.07 -0.29 -0.08 -0.31

# %%
galaxyAnalysisZ0PrimaryOnly = GalaxyAnalysis(generalRewrite=True, sim='TNG-Cluster',luminosityType='Default')
# Out:
# Progress: 5612/5612
# Loaded 5612 galaxy groups from HDF5.
# Loaded galaxy data from /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/data/galaxy_data_TNG-Cluster_.hdf5
# total to process: 5612
# total to process: 5052alaxy Group ID 5612 / 5612
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# total to process: 5052alaxy Group ID 5052 / 5052
# Progress: Processing Galaxy Group ID 5052 / 5052

# %%
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
#now filter to only the primary halo ids that are in our galaxy groups
filtered_primary_gt14_list_of_galaxy_groups = []
for gg in galaxyAnalysisZ0PrimaryOnly.filtered_gt14_list_of_galaxy_groups.getAllGalaxyGroups():
    if gg.getGroupID() in primary_halo_ids:
        print(f"Galaxy group with primary halo ID {gg.getGroupID()} is in the TNG-Cluster catalog.")
        filtered_primary_gt14_list_of_galaxy_groups.append(gg)
        
galaxyAnalysisZ0PrimaryOnly.filtered_gt14_list_of_galaxy_groups = ListGalaxyGroup(filtered_primary_gt14_list_of_galaxy_groups, headerInformation=galaxyAnalysisZ0.filtered_gt14_list_of_galaxy_groups.getHeaderInformation())
# Out:
# Galaxy group with primary halo ID 0 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4356618 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4461296 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4561713 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4656216 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4753637 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 476245 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4854863 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 4959833 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5059214 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5160063 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5251697 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5348819 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5432141 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5524229 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5608717 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5693289 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5787144 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5873398 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 5956970 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6043040 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6130348 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6225917 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6325415 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 692426 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6412656 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6499612 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6574070 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6664769 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6748564 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6834499 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6913365 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 6991026 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7065334 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7146294 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7235867 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7325028 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7403396 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7474466 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7547375 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7630798 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7706133 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7778424 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7860333 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 7935722 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8012756 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8094210 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 880597 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8175593 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8241267 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8311356 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8384388 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8460952 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8560074 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8629805 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8714627 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8790231 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8874396 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 8943467 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9009954 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9083738 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9158821 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9229180 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9298035 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9363765 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9439759 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9513551 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9574391 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9644244 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9720881 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 1068507 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9819553 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9890449 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 9956048 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10017312 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10087222 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10157377 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10219640 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10293151 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10351662 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10422957 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10484363 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10545631 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10612178 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10672584 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10739656 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10809596 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10886163 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 10943032 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11009511 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11069985 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11128914 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11186149 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11247535 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11318647 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11375025 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11433807 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11484512 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 1263653 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11543591 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11603245 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11659115 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11713845 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11767506 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11823213 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11876224 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11929315 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 11988351 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12045847 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12109947 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12169414 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12224103 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12274768 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12334208 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12381782 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12432056 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12485362 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12534413 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 1431487 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12582631 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12632860 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12698185 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12755885 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12816749 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12871237 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12925049 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 12981983 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13035077 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13083432 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13133868 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13176044 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13231280 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13291544 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13341116 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13388143 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13432142 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13479426 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13532711 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13581051 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13634459 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 1580995 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13686751 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13737849 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13792287 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13845328 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13886810 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13927129 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 13988217 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 14038844 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 14084296 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 14128437 is in the TNG-Cluster catalog.
# Galaxy group with primary halo ID 
# galaxyAnalysisZ0.plot_M200_distribution_for_all_mass_bins()
polar_ax.legend(loc='upper right')  # Add legend to the last subplot
polar_plotter.save_figure(polar_fig, galaxyAnalysisZ0.scratchPlotDirc + f'/pairwise_polar_difference_cluster_vs_cluster-primaries_{galaxyAnalysisZ0.sim}{galaxyAnalysisZ0.plotEndingFormat}')
# Out:
# COMPUTING FOR redshift index: 0, label: $M_{200}>14$, z=z0p0, TNG-Cluster
# Total Galaxy Groups to process: 352 with pairs : 17732249
# Processing Subhalo 639/639 in Galaxy Group ID 4254230 with total pairs 203841COMPUTING FOR redshift index: 0, label: $M_{200}>14$, z=0.0, TNG-Cluster only primaries
# Total Galaxy Groups to process: 352 with pairs : 17732249
# Processing Subhalo 6/626 in Galaxy Group ID 0 with total pairs 195625
# /home/poulin.al/git/sat-lopsidedness/src/myproject/utilities/plottingTools.py:236: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   sc = ax.scatter(x, y, c=scatter_color, cmap=cmap, alpha=alpha, s=s,
# Processing Subhalo 639/639 in Galaxy Group ID 4254230 with total pairs 203841Figure saved to: /scratch/poulin.al/lopsided/TNG-Cluster/z0p0/plots/pairwise_polar_difference_cluster_vs_cluster-primaries_TNG-Cluster

# %% [markdown]
# # overall change dependence

# %% [markdown]
# ## consistency plots

# %%
# get the percent of clusters below the 99% / 95% / 90% CL of random MRL, and plot it across redshift
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
import numpy as np

redshifts = []
fracBelow99 = []
fracBelow95 = []
fracBelow90 = []

errBelow99 = []
errBelow95 = []
errBelow90 = []


def binomial_sigma(p, n):
    p = float(p)
    n = int(n)
    if n <= 0:
        return 0.0
    return float(np.sqrt(p * (1.0 - p) / n))


for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue  # too high redshift

    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])

    # Note: getPercentOfClustersAboveRandomMRLCL returns the fraction/count/total *below* the percentile.
    (f99, c99, n99, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
        galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, percentageMRL=99
    )
    (f95, c95, n95, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
        galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, percentageMRL=95
    )
    (f90, c90, n90, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
        galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, percentageMRL=90
    )

    fracBelow99.append(f99)
    fracBelow95.append(f95)
    fracBelow90.append(f90)

    errBelow99.append(binomial_sigma(f99, n99))
    errBelow95.append(binomial_sigma(f95, n95))
    errBelow90.append(binomial_sigma(f90, n90))
# Out:
# Processing snapshot 99...
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.7289 (1382/1896)es
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.6176 (1171/1896)es
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.5374 (1019/1896)es
# Processing snapshot 91...
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.7127 (1223/1716)es
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5962 (1023/1716)es
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.5227 (897/1716)tes
# Processing snapshot 84...
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.7019 (1095/1560)es
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5917 (923/1560)tes
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.5103 (796/1560)tes
# Processing snapshot 78...
# final: [np.float64(0.10178159166350641), np.float64(0.08176720603855406), np.float64(0.08886135895531226)]
# final: [np.float64(0.08723910280936222), np.float64(0.2362091438610991), np.float64(0.2634763048281343)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6842 (975/1425)tes
# final: [np.float64(0.10178159166350641), np.float64(0.08176720603855406), np.float64(0.08886135895531226)]
# final: [np.float64(0.08723910280936222), np.float64(0.2362091438610991), np.float64(0.2634763048281343)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5649 (805/1425)tes
# final: [np.float64(0.10178159166350641), np.float64(0.08176720603855406), np.float64(0.08886135895531226)]
# final: [np.float64(0.08723910280936222), np.float64(0.2362091438610991), np.float64(0.2634763048281343)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4870 (694/1425)tes
# Processing snapshot 72...
# final: [np.float64(0.13863870193693267), np.float64(0.11809557032938062), np.float64(0.07446720286031323)]
# final: [np.float64(0.24335120537729815), np.float64(0.21682027909470164), np.float64(0.1599090838066422)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6319 (800/1266)tes
# final: [np.float64(0.13863870193693267), np.float64(0.11809557032938062), np.float64(0.07446720286031323)]
# final: [np.float64(0.24335120537729815), np.float64(0.21682027909470164), np.float64(0.1599090838066422)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5174 (655/1266)tes
# final: [np.float64(0.13863870193693267), np.float64(0.11809557032938062), np.float64(0.07446720286031323)]
# final: [np.float64(0.24335120537729815), np.float64(0.21682027909470164), np.float64(0.1599090838066422)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4415 (559/1266)tes
# Processing snapshot 67...
# final: [np.float64(0.07720842804377734), np.float64(0.11493837229877198), np.float64(0.15173163563535094)]
# final: [np.float64(0.08726924721024983), np.float64(0.29958337287907344), np.float64(0.3292444900693247)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6313 (697/1104)tes
# final: [np.float64(0.07720842804377734), np.float64(0.11493837229877198), np.float64(0.15173163563535094)]
# final: [np.float64(0.08726924721024983), np.float64(0.29958337287907344), np.float64(0.3292444900693247)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5063 (559/1104)tes
# final: [np.float64(0.07720842804377734), np.float64(0.11493837229877198), np.float64(0.15173163563535094)]
# final: [np.float64(0.08726924721024983), np.float64(0.29958337287907344), np.float64(0.3292444900693247)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4312 (476/1104)tes
# Processing snapshot 59...
# final: [np.float64(0.15122848085944132), np.float64(0.18857702029690565), np.float64(0.13566882401263117)]
# final: [np.float64(0.1262600703847171), np.float64(0.13323402499521325), np.float64(0.10937229163236431)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.5821 (468/804)ites
# final: [np.float64(0.15122848085944132), np.float64(0.18857702029690565), np.float64(0.13566882401263117)]
# final: [np.float64(0.1262600703847171), np.float64(0.13323402499521325), np.float64(0.10937229163236431)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.4726 (380/804)ites
# final: [np.float64(0.15122848085944132), np.float64(0.18857702029690565), np.float64(0.13566882401263117)]
# final: [np.float64(0.1262600703847171), np.float64(0.13323402499521325), np.float64(0.10937229163236431)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4067 (327/804)ites
# Processing snapshot 50...
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.5742 (236/411)ites
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.4720 (194/411)ites
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4015 (165/411)ites

# %%
MRL_CL_plotter = AstroPlotter()
MRL_CL_fig, MRL_CL_ax = MRL_CL_plotter.create_figure()

MRL_CL_ax.errorbar(
    redshifts,
    1-np.array(fracBelow99),
    yerr=errBelow99,
    label='Fraction above 99% CL of random MRL',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
)
MRL_CL_ax.errorbar(
    redshifts,
    1-np.array(fracBelow95),
    yerr=errBelow95,
    label='Fraction above 95% CL of random MRL',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
)
MRL_CL_ax.errorbar(
    redshifts,
    1-np.array(fracBelow90),
    yerr=errBelow90,
    label='Fraction above 90% CL of random MRL',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
)

MRL_CL_ax.set_xlabel('Redshift')
MRL_CL_ax.set_ylabel('Fraction of MRL values above random percentile')
MRL_CL_ax.set_title('Fraction above random MRL CL vs Redshift')
MRL_CL_ax.legend(loc='upper left')

MRL_CL_plotter.save_figure(
    MRL_CL_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/percent_clusters_above_random_MRL_CL_vs_redshift_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/percent_clusters_above_random_MRL_CL_vs_redshift_TNG300-1, TNG-Cluster

# %%
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(99)
random_MRL_values = galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(
            parallelize=False, num_samples=1000
        )
print(f"num galaxies in gt13 lt13p5: {galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups.getNumGalaxyGroups()}")
(f99, c99, n99, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
            galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups, percentageMRL=90, random_mrl_values=random_MRL_values
        )
print(f99, c99, n99)
# Out:
# num galaxies in gt13 lt13p5: 2586istribution for Galaxy Group 2586 / 2586 with 13 satellites
# Fraction of MRL values below the 90th percentile of random MRL values: 0.8447 (6553/7758)
# 0.8446764630059294 6553 7758

# %%
# do the same but for the 5 mass groups
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
import numpy as np

redshifts = []

mass_bin_labels = [
    '$1e13<M_{200}<1e13.5$',
    '$1e13.5<M_{200}<1e14$',
    '$1e14<M_{200}<1e14.5$',
    '$1e14.5<M_{200}<1e15$',
    '$M_{200}>1e15$',
]

fracBelow99_mass_bins = [[] for _ in range(len(mass_bin_labels))]
fracBelow95_mass_bins = [[] for _ in range(len(mass_bin_labels))]
fracBelow90_mass_bins = [[] for _ in range(len(mass_bin_labels))]

errBelow99_mass_bins = [[] for _ in range(len(mass_bin_labels))]
errBelow95_mass_bins = [[] for _ in range(len(mass_bin_labels))]
errBelow90_mass_bins = [[] for _ in range(len(mass_bin_labels))]


def binomial_sigma(p, n):
    p = float(p)
    n = int(n)
    if n <= 0:
        return 0.0
    return float(np.sqrt(p * (1.0 - p) / n))


for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue  # too high redshift

    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    

    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]

    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])

    for i, mass_bin in enumerate(mass_bins):
        random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(
            parallelize=False, num_samples=10000
        )

        (f99, c99, n99, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
            mass_bin, percentageMRL=99, random_mrl_values=random_MRL_values
        )
        (f95, c95, n95, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
            mass_bin, percentageMRL=95, random_mrl_values=random_MRL_values
        )
        (f90, c90, n90, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
            mass_bin, percentageMRL=90, random_mrl_values=random_MRL_values
        )

        fracBelow99_mass_bins[i].append(f99)
        fracBelow95_mass_bins[i].append(f95)
        fracBelow90_mass_bins[i].append(f90)

        errBelow99_mass_bins[i].append(binomial_sigma(f99, n99))
        errBelow95_mass_bins[i].append(binomial_sigma(f95, n95))
        errBelow90_mass_bins[i].append(binomial_sigma(f90, n90))
# Out:
# Processing snapshot 99...
# Fraction of MRL values below the 99th percentile of random MRL values: 0.9626 (7468/7758) with 13 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9035 (7009/7758)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.8434 (6543/7758)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.9430 (2450/2598)ith 13 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.8780 (2281/2598)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.8052 (2092/2598)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.8642 (757/876) with 60 satellitess
# Fraction of MRL values below the 95th percentile of random MRL values: 0.7603 (666/876)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.6849 (600/876)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6708 (487/726) with 317 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5455 (396/726)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4656 (338/726)
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.4694 (138/294)
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.3673 (108/294)
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.2653 (78/294)
# Processing snapshot 91...
# Fraction of MRL values below the 99th percentile of random MRL values: 0.9659 (6859/7101) with 9 satellitess
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9054 (6429/7101)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.8375 (5947/7101)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.9286 (2173/2340)ith 19 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.8423 (1971/2340)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.7675 (1796/2340)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.8211 (707/861) with 124 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.6980 (601/861)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.6214 (535/861)
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6339 (445/702) with 322 satellites
# Fraction of MRL values below the 95th percentile of random MRL values: 0.5128 (360/702)
# Fraction of MRL values below the 90th percentile of random MRL values: 0.4473 (314/702)
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.4706 (72/153)
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.3791 (58/153)
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# Fraction of MRL values below the 90th percentile of random MRL values: 0.3137 (48/153)
# Processing snapshot 84...
# Progress: Processing random MRL distribution, samples:10000, for Galaxy Group 676 / 2152 with 9 satellitess
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 52
#      49 redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
#      51 for i, mass_bin in enumerate(mass_bins):
# ---> 52     random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(
#      53         parallelize=False, num_samples=10000
#      54     )
#      56     (f99, c99, n99, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
#      57         mass_bin, percentageMRL=99, random_mrl_values=random_MRL_values
#      58     )
#      59     (f95, c95, n95, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(
#      60         mass_bin, percentageMRL=95, random_mrl_values=random_MRL_values
#      61     )
#
# File <string>:12, in compute_MRL_random_distribution_curves_for_LGG(self, num_samples, parallelize, n_processes, tempSaveDir, rewrite)
#
# File <string>:29, in compute_an_MRL_distribution_curves(num_samples, num_non_centrals, parallelize, n_processes, tempSaveDir, rewrite)
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
mass_bin_MRL_CL_plotter = AstroPlotter()
mass_bin_MRL_CL_fig, mass_bin_MRL_CL_ax = mass_bin_MRL_CL_plotter.create_figure(
    nrows=1,
    ncols=3,
    figsize=(15, 5),
)  # each col is a different confidence level, each line is a different mass bin

redshifts = SnapshotEnum.getAllRedshifts()[:8]


for i in range(len(mass_bin_labels)):
    # 99% CL — select non-zero entries and sort by redshift before plotting
    y99 = np.array(fracBelow99_mass_bins[i], dtype=float)
    mask99 = y99 != 0
    if np.any(mask99):
        x99 = np.array(redshifts)[mask99]
        y99_sel = 1.0 - y99[mask99]
        yerr99 = np.array(errBelow99_mass_bins[i])[mask99]
        order99 = np.argsort(x99)
        mass_bin_MRL_CL_ax[0].errorbar(
            x99[order99],
            y99_sel[order99],
            yerr=yerr99[order99],
            label=f'99% CL, {mass_bin_labels[i]}',
            marker='o',
            linestyle='-',
            capsize=2,
            elinewidth=1,
            linewidth=1,
            markersize=3,
        )

    # 95% CL
    y95 = np.array(fracBelow95_mass_bins[i], dtype=float)
    mask95 = y95 != 0
    if np.any(mask95):
        x95 = np.array(redshifts)[mask95]
        y95_sel = 1.0 - y95[mask95]
        yerr95 = np.array(errBelow95_mass_bins[i])[mask95]
        order95 = np.argsort(x95)
        mass_bin_MRL_CL_ax[1].errorbar(
            x95[order95],
            y95_sel[order95],
            yerr=yerr95[order95],
            label=f'95% CL, {mass_bin_labels[i]}',
            marker='o',
            linestyle='-',
            capsize=2,
            elinewidth=1,
            linewidth=1,
            markersize=3,
        )

    # 90% CL
    y90 = np.array(fracBelow90_mass_bins[i], dtype=float)
    mask90 = y90 != 0
    if np.any(mask90):
        x90 = np.array(redshifts)[mask90]
        y90_sel = 1.0 - y90[mask90]
        yerr90 = np.array(errBelow90_mass_bins[i])[mask90]
        order90 = np.argsort(x90)
        mass_bin_MRL_CL_ax[2].errorbar(
            x90[order90],
            y90_sel[order90],
            yerr=yerr90[order90],
            label=f'90% CL, {mass_bin_labels[i]}',
            marker='o',
            linestyle='-',
            capsize=2,
            elinewidth=1,
            linewidth=1,
            markersize=3,
        )

mass_bin_MRL_CL_ax[0].set_xlabel('Redshift')
mass_bin_MRL_CL_ax[1].set_xlabel('Redshift')
mass_bin_MRL_CL_ax[2].set_xlabel('Redshift')

mass_bin_MRL_CL_ax[0].set_ylabel('Fraction above random 99% percentile')
mass_bin_MRL_CL_ax[1].set_ylabel('Fraction above random 95% percentile')
mass_bin_MRL_CL_ax[2].set_ylabel('Fraction above random 90% percentile')

mass_bin_MRL_CL_ax[1].set_title('Fraction above random MRL CL vs Redshift (by mass bin)')

mass_bin_MRL_CL_ax[0].legend(fontsize=6, loc='upper left')

mass_bin_MRL_CL_plotter.save_figure(
    mass_bin_MRL_CL_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/percent_clusters_above_random_MRL_CL_vs_redshift_for_mass_bins_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/percent_clusters_above_random_MRL_CL_vs_redshift_for_mass_bins_TNG300-1, TNG-Cluster

# %% [markdown]
# ## first assymetry plots

# %%
#take the difference of polar pairwise < 90º with polar pairwise > 90º and plot it across redshift for the full sample and for the 5 mass bins
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
import numpy as np

def polar_lt90_ge90_stats_from_hist(angles_deg, bin_size_deg=5.0):
    """
    Compute counts and fractions using a (normalized) histogram with an edge at 90°.

    Returns a dict with:
      - total
      - n_lt90, n_ge90 (expected counts from histogram; equals counts for equal weights)
      - frac_lt90, frac_ge90 (fractions; sum to 1 when total>0)
      - diff = n_lt90 - n_ge90
      - sigma_poisson = sqrt(n_lt90 + n_ge90)
    """
    angles = np.asarray(angles_deg, dtype=float)
    if angles.size == 0:
        return {
            'total': 0,
            'n_lt90': 0.0,
            'n_ge90': 0.0,
            'frac_lt90': 0.0,
            'frac_ge90': 0.0,
            'diff': 0.0,
            'sigma_poisson': 0.0,
        }
    bins = np.arange(0.0, 180.0 + bin_size_deg, bin_size_deg)
    counts, edges = np.histogram(angles, bins=bins)
    total = int(counts.sum())
    if total == 0:
        return {
            'total': 0,
            'n_lt90': 0.0,
            'n_ge90': 0.0,
            'frac_lt90': 0.0,
            'frac_ge90': 0.0,
            'diff': 0.0,
            'sigma_poisson': 0.0,
        }
    # normalized histogram (probability mass per bin)
    prob = counts / total
    lt_mask = edges[:-1] < 90.0  # bins with left edge < 90° are counted as <90° (e.g. [85,90))
    frac_lt90 = float(prob[lt_mask].sum())
    frac_ge90 = float(prob[~lt_mask].sum())
    # expected counts from normalized histogram
    n_lt90 = frac_lt90 * total
    n_ge90 = frac_ge90 * total
    diff = n_lt90 - n_ge90
    sigma_poisson = float(np.sqrt(n_lt90 + n_ge90))
    return {
        'total': total,
        'n_lt90': float(n_lt90),
        'n_ge90': float(n_ge90),
        'frac_lt90': float(frac_lt90),
        'frac_ge90': float(frac_ge90),
        'diff': float(diff),
        'sigma_poisson': float(sigma_poisson),
    }

redshifts = []

# values used for plotting (counts-difference + poisson errors)
polarDifference_full_sample = []
polarDifference_full_sample_err = []
polarDifference_mass_bins = []
polarDifference_mass_bins_err = []

# keep both expected counts and fractions for later inspection/analysis
full_total_pairs = []
full_n_lt90 = []
full_n_ge90 = []
full_frac_lt90 = []
full_frac_ge90 = []

mass_bin_labels = ['$1e13<M_{200}<1e13.5$', '$1e13.5<M_{200}<1e14$', '$1e14<M_{200}<1e14.5$', '$1e14.5<M_{200}<1e15$', '$M_{200}>1e15$']
mass_total_pairs = [[] for _ in range(len(mass_bin_labels))]
mass_n_lt90 = [[] for _ in range(len(mass_bin_labels))]
mass_n_ge90 = [[] for _ in range(len(mass_bin_labels))]
mass_frac_lt90 = [[] for _ in range(len(mass_bin_labels))]
mass_frac_ge90 = [[] for _ in range(len(mass_bin_labels))]

polarDifference_mass_bins = [[] for _ in range(len(mass_bin_labels))]
polarDifference_mass_bins_err = [[] for _ in range(len(mass_bin_labels))]

for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
    
    # Build the "full sample" by accumulating angles from the mass bins,
    # so we don't recompute the polar differences twice.
    full_angles = []
    for i, mass_bin in enumerate(mass_bins):
        polarRawValues = mass_bin.compute_probablity_distribution_of_polar_differences()
        full_angles.extend(polarRawValues)
        stats = polar_lt90_ge90_stats_from_hist(polarRawValues, bin_size_deg=5.0)
        polarDifference_mass_bins[i].append(stats['diff'])
        polarDifference_mass_bins_err[i].append(stats['sigma_poisson'])
        mass_total_pairs[i].append(stats['total'])
        mass_n_lt90[i].append(stats['n_lt90'])
        mass_n_ge90[i].append(stats['n_ge90'])
        mass_frac_lt90[i].append(stats['frac_lt90'])
        mass_frac_ge90[i].append(stats['frac_ge90'])
    
    stats_full = polar_lt90_ge90_stats_from_hist(full_angles, bin_size_deg=5.0)
    polarDifference_full_sample.append(stats_full['diff'])
    polarDifference_full_sample_err.append(stats_full['sigma_poisson'])
    full_total_pairs.append(stats_full['total'])
    full_n_lt90.append(stats_full['n_lt90'])
    full_n_ge90.append(stats_full['n_ge90'])
    full_frac_lt90.append(stats_full['frac_lt90'])
    full_frac_ge90.append(stats_full['frac_ge90'])
# Out:
# Processing snapshot 99...
# Total Galaxy Groups to process: 2586 with pairs : 131308
# Processing Subhalo 12/12 in Galaxy Group ID 993 with total pairs 6655Total Galaxy Groups to process: 866 with pairs : 350183
# Processing Subhalo 12/12 in Galaxy Group ID 999 with total pairs 6615Total Galaxy Groups to process: 292 with pairs : 975806
# Processing Subhalo 1/85 in Galaxy Group ID 116 with total pairs 3570650
# Processing Subhalo 59/59 in Galaxy Group ID 19441351 with total pairs 1711218Total Galaxy Groups to process: 242 with pairs : 6422297
# Processing Subhalo 316/316 in Galaxy Group ID 9720881 with total pairs 497703Total Galaxy Groups to process: 98 with pairs : 12402548
# Processing Subhalo 427/427 in Galaxy Group ID 9956048 with total pairs 909516Processing snapshot 91...
# Total Galaxy Groups to process: 2367 with pairs : 165155
# Processing Subhalo 8/8 in Galaxy Group ID 996 with total pairs 286600Total Galaxy Groups to process: 780 with pairs : 412397
# Processing Subhalo 18/18 in Galaxy Group ID 1000 with total pairs 153Total Galaxy Groups to process: 287 with pairs : 1367441
# Processing Subhalo 123/123 in Galaxy Group ID 5413090 with total pairs 750351Total Galaxy Groups to process: 234 with pairs : 8289605
# Processing Subhalo 321/321 in Galaxy Group ID 10060723 with total pairs 51360Total Galaxy Groups to process: 51 with pairs : 7870756
# Processing Subhalo 488/488 in Galaxy Group ID 9557666 with total pairs 118828Processing snapshot 84...
# Total Galaxy Groups to process: 2152 with pairs : 196607
# Processing Subhalo 10/10 in Galaxy Group ID 1001 with total pairs 455Total Galaxy Groups to process: 686 with pairs : 476941
# Processing Subhalo 30/30 in Galaxy Group ID 19733768 with total pairs 4353Total Galaxy Groups to process: 273 with pairs : 1550241
# Processing Subhalo 127/127 in Galaxy Group ID 8732471 with total pairs 800135Total Galaxy Groups to process: 219 with pairs : 8890504
# Processing Subhalo 373/373 in Galaxy Group ID 10118255 with total pairs 693781Total Galaxy Groups to process: 28 with pairs : 5193355
# Processing Subhalo 567/567 in Galaxy Group ID 1791552 with total pairs 160461Processing snapshot 78...
# Total Galaxy Groups to process: 1939 with pairs : 225477
# Processing Subhalo 17/17 in Galaxy Group ID 1000 with total pairs 136Total Galaxy Groups to process: 610 with pairs : 551864
# Processing Subhalo 20/20 in Galaxy Group ID 19937182 with total pairs 1908Total Galaxy Groups to process: 285 with pairs : 2138477
# Processing Subhalo 135/135 in Galaxy Group ID 9951187 with total pairs 904508Total Galaxy Groups to process: 174 with pairs : 8646549
# Processing Subhalo 278/278 in Galaxy Group ID 9870715 with total pairs 3850350Total Galaxy Groups to process: 16 with pairs : 3425569
# Processing Subhalo 852/852 in Galaxy Group ID 1630676 with total pairs 362526Processing snapshot 72...
# Total Galaxy Groups to process: 1765 with pairs : 264808
# Processing Subhalo 21/21 in Galaxy Group ID 20045398 with total pairs 210Total Galaxy Groups to process: 540 with pairs : 661789
# Processing Subhalo 28/28 in Galaxy Group ID 20031389 with total pairs 3781Total Galaxy Groups to process: 278 with pairs : 2528690
# Processing Subhalo 146/146 in Galaxy Group ID 9106562 with total pairs 105850Total Galaxy Groups to process: 136 with pairs : 7788458
# Processing Subhalo 225/225 in Galaxy Group ID 9624704 with total pairs 2520038Total Galaxy Groups to process: 8 with pairs : 1960153
# Processing Subhalo 709/709 in Galaxy Group ID 1114731 with total pairs 250986Processing snapshot 67...
# Total Galaxy Groups to process: 1570 with pairs : 312670
# Processing Subhalo 24/24 in Galaxy Group ID 20137649 with total pairs 276Total Galaxy Groups to process: 486 with pairs : 743637
# Processing Subhalo 61/61 in Galaxy Group ID 8838475 with total pairs 18305Total Galaxy Groups to process: 262 with pairs : 3029842
# Processing Subhalo 207/207 in Galaxy Group ID 9601067 with total pairs 213210Total Galaxy Groups to process: 104 with pairs : 6898864
# Processing Subhalo 200/200 in Galaxy Group ID 9677312 with total pairs 1990085Total Galaxy Groups to process: 2 with pairs : 461925
# Processing Subhalo 750/750 in Galaxy Group ID 3565276 with total pairs 280875Processing snapshot 59...
# Total Galaxy Groups to process: 1234 with pairs : 373520
# Processing Subhalo 24/24 in Galaxy Group ID 20390671 with total pairs 276Total Galaxy Groups to process: 408 with pairs : 921762
# Processing Subhalo 59/59 in Galaxy Group ID 9122911 with total pairs 1711550Total Galaxy Groups to process: 233 with pairs : 3858488
# Processing Subhalo 263/263 in Galaxy Group ID 9589125 with total pairs 344538Total Galaxy Groups to process: 35 with pairs : 2445618
# Processing Subhalo 261/261 in Galaxy Group ID 9512963 with total pairs 339305Total Galaxy Groups to process: 0 with pairs : 0
# Processing snapshot 50...
# Total Galaxy Groups to process: 827 with pairs : 432869
# Processing Subhalo 27/27 in Galaxy Group ID 8662185 with total pairs 35181Total Galaxy Groups to process: 328 with pairs : 1204842
# Processing Subhalo 50/50 in Galaxy Group ID 9303357 with total pairs 12256006Total Galaxy Groups to process: 133 with pairs : 2651757
# Processing Subhalo 190/190 in Galaxy Group ID 9381209 with total pairs 179551Total Galaxy Groups to process: 4 with pairs : 520235
# Processing Subhalo 361/361 in Galaxy Group ID 5903274 with total pairs 649808Total Galaxy Groups to process: 0 with pairs : 0

# %%
polarPairwiseDifference_plotter = AstroPlotter()
polarPairwiseDifference_fig, polarPairwiseDifference_ax = polarPairwiseDifference_plotter.create_figure()
polarPairwiseDifference_ax.errorbar(
    redshifts,
    polarDifference_full_sample,
    yerr=polarDifference_full_sample_err,
    label='Polar Pairwise Difference, Full Sample',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
    )
for i in range(len(mass_bin_labels)):
    polarPairwiseDifference_ax.errorbar(
        redshifts,
        polarDifference_mass_bins[i],
        yerr=polarDifference_mass_bins_err[i],
        label=f'Polar Pairwise Difference, {mass_bin_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
polarPairwiseDifference_ax.set_xlabel('Redshift')
polarPairwiseDifference_ax.set_ylabel('N(<90º) - N(>=90º)')
polarPairwiseDifference_ax.set_title('Polar Pairwise Difference vs Redshift for Full Sample and Mass Bins')
polarPairwiseDifference_ax.legend(fontsize=6)
polarPairwiseDifference_plotter.save_figure(polarPairwiseDifference_fig, galaxyAnalysisSnapshot.scratchPlotDirc + f'/polar_pairwise_difference_vs_redshift_for_full_sample_and_mass_bins_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}')
# Out:
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_for_full_sample_and_mass_bins_TNG300-1, TNG-Cluster

# %%
#take the difference of polar pairwise < 90º with polar pairwise > 90º and plot it across redshift for the full sample and for the 5 mass bins
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
# plot the normalized version of the above (frac(<90º) - frac(>=90º)) vs redshift for the full sample and mass bins
import numpy as np

# Choose error model for d = f_lt - f_ge
# - 'binomial': previous multinomial/binomial approximation
# - 'poisson_propagated': Poisson on <90 and >=90 counts, normalized by N, then propagated
error_model = 'poisson_propagated'  # set to 'binomial' to recover the previous behavior

def frac_diff_and_sigma(frac_lt, frac_ge, n_total, n_lt, n_ge, model='binomial'):
    d = float(frac_lt) - float(frac_ge)
    n = int(n_total)
    if n <= 0:
        return d, 0.0

    if model == 'binomial':
        # Previous formula: Var(d) = (1 - d^2) / N
        sigma = float(np.sqrt(max(0.0, 1.0 - d * d) / n))
        return d, sigma

    if model == 'poisson_propagated':
        # Poisson on counts, then normalize to fractions by N
        sigma_f_lt = np.sqrt(max(float(n_lt), 0.0)) / n
        sigma_f_ge = np.sqrt(max(float(n_ge), 0.0)) / n
        sigma = float(np.sqrt(sigma_f_lt**2 + sigma_f_ge**2))
        return d, sigma

    raise ValueError(f'Unknown error model: {model}')

full_frac_diff = []
full_frac_diff_err = []
for frac_lt, frac_ge, n, n_lt, n_ge in zip(full_frac_lt90, full_frac_ge90, full_total_pairs, full_n_lt90, full_n_ge90):
    d, s = frac_diff_and_sigma(frac_lt, frac_ge, n, n_lt, n_ge, model=error_model)
    full_frac_diff.append(d)
    full_frac_diff_err.append(s)

mass_frac_diff = [[] for _ in range(len(mass_bin_labels))]
mass_frac_diff_err = [[] for _ in range(len(mass_bin_labels))]
for i in range(len(mass_bin_labels)):
    for frac_lt, frac_ge, n, n_lt, n_ge in zip(
        mass_frac_lt90[i],
        mass_frac_ge90[i],
        mass_total_pairs[i],
        mass_n_lt90[i],
        mass_n_ge90[i],
    ):
        d, s = frac_diff_and_sigma(frac_lt, frac_ge, n, n_lt, n_ge, model=error_model)
        mass_frac_diff[i].append(d)
        mass_frac_diff_err[i].append(s)

polarPairwiseDifferenceNorm_plotter = AstroPlotter()
polarPairwiseDifferenceNorm_fig, polarPairwiseDifferenceNorm_ax = polarPairwiseDifferenceNorm_plotter.create_figure()

polarPairwiseDifferenceNorm_ax.errorbar(
    redshifts,
    full_frac_diff,
    yerr=full_frac_diff_err,
    label=f'Polar Pairwise Difference (Normalized), Full Sample [{error_model}]',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
)

for i in range(len(mass_bin_labels)):
    polarPairwiseDifferenceNorm_ax.errorbar(
        redshifts,
        mass_frac_diff[i],
        yerr=mass_frac_diff_err[i],
        label=f'Polar Pairwise Difference (Normalized), {mass_bin_labels[i]} [{error_model}]',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )

polarPairwiseDifferenceNorm_ax.set_xlabel('Redshift')
polarPairwiseDifferenceNorm_ax.set_ylabel('Fraction(<90º) - Fraction(>=90º)')
polarPairwiseDifferenceNorm_ax.set_title('Normalized Polar Pairwise Difference vs Redshift for Full Sample and Mass Bins')
polarPairwiseDifferenceNorm_ax.legend(fontsize=6)

polarPairwiseDifferenceNorm_plotter.save_figure(
    polarPairwiseDifferenceNorm_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_pairwise_difference_normalized_vs_redshift_for_full_sample_and_mass_bins_{error_model}_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_normalized_vs_redshift_for_full_sample_and_mass_bins_poisson_propagated_TNG300-1, TNG-Cluster

# %% [markdown]
# ## more reliable assymetry plots

# %%
#try a different method:
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
import numpy as np

def asymetryPlots(redshifts, listRedshiftGG : list[list[ListGalaxyGroup]], listGGLabels, plotRows=1, plotCols=1):
    
    polar_pairwise_by_type_by_redshift : dict[float, dict[str, dict[str, list]]] = {}  # dict of snapshot -> type -> {'differences': [], 'binned': [], 'bin_centers': [], 'errorbars': []}

    for snapshot, mass_bins in zip(redshifts, listRedshiftGG):
        polar_pairwise_by_type : dict[str, dict[str, list]] = {}
        polar_pairwise_by_type['full_sample'] = {
        'differences': [],
        'binned': [],
        'bin_centers': [],
        'errorbars': [],
        }
        polar_pairwise_by_type = {}
        for i, mass_bin in enumerate(mass_bins):
            list_pairwise_polar_differences = mass_bin.compute_probablity_distribution_of_polar_differences(parallelize=False)
            
            pairwise_polar_differences_binned, polar_bin_centers, pairwise_polar_errorbars = ListGalaxyGroup.get_histogram_bins(list_pairwise_polar_differences, bins = np.arange(0, 185, 10), errorbarType='poisson', normalize_to_one=True)
            
            polar_pairwise_by_type[listGGLabels[i]] = {
                'differences': list_pairwise_polar_differences,
                'binned': pairwise_polar_differences_binned,
                'bin_centers': polar_bin_centers,
                'errorbars': pairwise_polar_errorbars,
            }
            
            extended_list_of_full_sample_polar_differences = polar_pairwise_by_type[listGGLabels[i]]['differences'] if 'full_sample' not in polar_pairwise_by_type else extended_list_of_full_sample_polar_differences + polar_pairwise_by_type[listGGLabels[i]]['differences']
            extended_full_sample_pairwise_polar_differences_binned = polar_pairwise_by_type[listGGLabels[i]]['binned'] if 'full_sample' not in polar_pairwise_by_type else extended_full_sample_pairwise_polar_differences_binned + polar_pairwise_by_type[listGGLabels[i]]['binned']
            extended_full_sample_polar_bin_centers = polar_pairwise_by_type[listGGLabels[i]]['bin_centers'] if 'full_sample' not in polar_pairwise_by_type else extended_full_sample_polar_bin_centers
            extended_full_sample_pairwise_polar_errorbars = polar_pairwise_by_type[listGGLabels[i]]['errorbars'] if 'full_sample' not in polar_pairwise_by_type else extended_full_sample_pairwise_polar_errorbars + polar_pairwise_by_type[listGGLabels[i]]['errorbars']
            
            polar_pairwise_by_type['full_sample'] = {
                'differences': extended_list_of_full_sample_polar_differences,
                'binned': extended_full_sample_pairwise_polar_differences_binned,
                'bin_centers': extended_full_sample_polar_bin_centers,
                'errorbars': extended_full_sample_pairwise_polar_errorbars,
            }

            polar_pairwise_by_type_by_redshift[snapshot] = polar_pairwise_by_type
            
    #now sum the points below 90º and above 90º for the full sample and for the mass bins, and plot the difference with error bars across redshift
    # print(polar_pairwise_by_type_by_redshift)
    for redshift, polar_pairwise_by_type in polar_pairwise_by_type_by_redshift.items():
        for type_key, stats in polar_pairwise_by_type.items():
            lt90_mask = stats['bin_centers'] < 90.0
            ge90_mask = stats['bin_centers'] >= 90.0
            n_lt90 = np.sum(stats['binned'][lt90_mask])
            n_ge90 = np.sum(stats['binned'][ge90_mask])
            diff = n_lt90 - n_ge90
            #propogate error of subtraction in quadrature, assuming poisson errors on each bin
            sigma_poisson = np.sqrt(np.sum(stats['errorbars'][lt90_mask]**2) + np.sum(stats['errorbars'][ge90_mask]**2))
            polar_pairwise_by_type_by_redshift[redshift][type_key]['diff'] = diff
            polar_pairwise_by_type_by_redshift[redshift][type_key]['diff_err'] = sigma_poisson

    by_mass_diff = {type_key: [] for type_key in listGGLabels}
    by_mass_diff_err = {type_key: [] for type_key in listGGLabels}
    redshift_list = []
    for redshift, polar_pairwise_by_type in polar_pairwise_by_type_by_redshift.items():
        redshift_list.append(redshift)
        for type_key in listGGLabels:
            by_mass_diff[type_key].append(polar_pairwise_by_type[type_key]['diff'])
            by_mass_diff_err[type_key].append(polar_pairwise_by_type[type_key]['diff_err'])
        
    polarPairwiseDifference_plotter = AstroPlotter()
    polarPairwiseDifference_fig, polarPairwiseDifference_ax = polarPairwiseDifference_plotter.create_figure()
    for type_key in listGGLabels:
        polarPairwiseDifference_ax.errorbar(
            redshift_list,
            by_mass_diff[type_key],
            yerr=by_mass_diff_err[type_key],
            label=f'Polar Pairwise Difference, {type_key}',
            marker='o',
            linestyle='-',
            capsize=2,
            elinewidth=1,
            linewidth=1,
            markersize=3,
        )

    polarPairwiseDifference_ax.set_xlabel('Redshift')
    polarPairwiseDifference_ax.set_ylabel('N(<90º) - N(>=90º)')
    polarPairwiseDifference_ax.legend(fontsize=6)
    return polarPairwiseDifference_plotter, polarPairwiseDifference_fig, polarPairwiseDifference_ax, polar_pairwise_by_type_by_redshift

# %%
mass_bin_labels = ['$1e13<M_{200}<1e13.5$', '$1e13.5<M_{200}<1e14$', '$1e14<M_{200}<1e14.5$', '$1e14.5<M_{200}<1e15$', '$M_{200}>1e15$']
redshift_mass_bins : list[list[ListGalaxyGroup]]= []
redshifts = []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
    redshift_mass_bins.append(mass_bins)
    
polarPairwiseDifference_plotter, polarPairwiseDifference_fig, polarPairwiseDifference_ax, polar_pairwise_by_type_by_redshift = asymetryPlots(redshifts, listRedshiftGG=redshift_mass_bins, listGGLabels=mass_bin_labels, plotRows=1, plotCols=1)

polarPairwiseDifference_ax.set_title('Polar Pairwise Difference vs Redshift for Full Sample and Mass Bins')
polarPairwiseDifference_plotter.save_figure(polarPairwiseDifference_fig, galaxyAnalysisSnapshot.scratchPlotDirc + f'/polar_pairwise_difference_vs_redshift_for_full_sample_and_mass_bins_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat
# Progress: Processing Galaxy Group ID 1114731, 8 / 8Total Galaxy Groups to process: 1570 with pairs : 312670
# Progress: Processing Galaxy Group ID 20137649, 1570 / 1570Total Galaxy Groups to process: 486 with pairs : 743637
# Progress: Processing Galaxy Group ID 8838475, 486 / 4866Total Galaxy Groups to process: 262 with pairs : 3029842
# Progress: Processing Galaxy Group ID 9601067, 262 / 2622Total Galaxy Groups to process: 104 with pairs : 6898864
# Progress: Processing Galaxy Group ID 9677312, 104 / 104Total Galaxy Groups to process: 2 with pairs : 461925
# Progress: Processing Galaxy Group ID 3565276, 2 / 2Total Galaxy Groups to process: 1234 with pairs : 373520
# Progress: Processing Galaxy Group ID 20390671, 1234 / 1234Total Galaxy Groups to process: 408 with pairs : 921762
# Progress: Processing Galaxy Group ID 9122911, 408 / 4088Total Galaxy Groups to process: 233 with pairs : 3858488
# Progress: Processing Galaxy Group ID 9589125, 233 / 2333Total Galaxy Groups to process: 35 with pairs : 2445618
# Progress: Processing Galaxy Group ID 9512963, 35 / 355Total Galaxy Groups to process: 0 with pairs : 0
# Total Galaxy Groups to process: 827 with pairs : 432869
# Progress: Processing Galaxy Group ID 8662185, 827 / 8277Total Galaxy Groups to process: 328 with pairs : 1204842
# Progress: Processing Galaxy Group ID 9303357, 328 / 3288Total Galaxy Groups to process: 133 with pairs : 2651757
# Progress: Processing Galaxy Group ID 9381209, 133 / 133Total Galaxy Groups to process: 4 with pairs : 520235
# Progress: Processing Galaxy Group ID 5903274, 4 / 4Total Galaxy Groups to process: 0 with pairs : 0
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_for_full_sample_and_mass_bins_TNG300-1, TNG-Cluster

# %%
# make assymetry plots for GT150 members vs LT50 members
bin_labels = ['GT150 members', 'LT50 members']
redshifts = []
redshift_gg_bins = []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    # use the length of the satellite list when filtering (getSatelliteSubhalos() returns a list)
    gt150_list_of_galaxy_groups = ListGalaxyGroup.getFilterSubhalosLambda(listGalaxyGroups=galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, lambda_func=lambda g: len(g.getSatelliteSubhalos()) > 150)
    lt50_list_of_galaxy_groups = ListGalaxyGroup.getFilterSubhalosLambda(listGalaxyGroups=galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, lambda_func=lambda g: len(g.getSatelliteSubhalos()) < 50)
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
    redshift_gg_bins.append([gt150_list_of_galaxy_groups, lt50_list_of_galaxy_groups])

    
polarPairwiseDifference_plotter, polarPairwiseDifference_fig, polarPairwiseDifference_ax, polar_pairwise_by_type_by_redshift = asymetryPlots(redshifts, listRedshiftGG=redshift_gg_bins, listGGLabels=bin_labels, plotRows=1, plotCols=1)

polarPairwiseDifference_ax.set_title('Polar Pairwise Difference vs Redshift for GT150 vs LT50 members')
polarPairwiseDifference_plotter.save_figure(polarPairwiseDifference_fig, galaxyAnalysisSnapshot.scratchPlotDirc + f'/polar_pairwise_difference_vs_redshift_for_gt150_vs_lt50_members_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}')
# Out:
# Processing snapshot 99...
# Processing snapshot 91...xy Group ID 632 / 632
# Processing snapshot 84...xy Group ID 572 / 572
# Processing snapshot 78...xy Group ID 520 / 520
# Processing snapshot 72...xy Group ID 475 / 475
# Processing snapshot 67...xy Group ID 422 / 422
# Processing snapshot 59...xy Group ID 368 / 368
# Processing snapshot 50...xy Group ID 268 / 268
# Total Galaxy Groups to process: 295 with pairs : 18447145
# Progress: Processing Galaxy Group ID 9956048, 295 / 2955Total Galaxy Groups to process: 35 with pairs : 33908
# Progress: Processing Galaxy Group ID 75, 35 / 355Total Galaxy Groups to process: 274 with pairs : 16090725
# Progress: Processing Galaxy Group ID 10060723, 274 / 274Total Galaxy Groups to process: 5 with pairs : 5420
# Progress: Processing Galaxy Group ID 300, 5 / 5Total Galaxy Groups to process: 258 with pairs : 14278724
# Progress: Processing Galaxy Group ID 10118255, 258 / 258Total Galaxy Groups to process: 2 with pairs : 2401
# Progress: Processing Galaxy Group ID 19088975, 2 / 2Total Galaxy Groups to process: 238 with pairs : 12852764
# Progress: Processing Galaxy Group ID 9870715, 238 / 2388Total Galaxy Groups to process: 1 with pairs : 1225
# Progress: Processing Galaxy Group ID 19239026, 1 / 1Total Galaxy Groups to process: 224 with pairs : 11080952
# Progress: Processing Galaxy Group ID 9624704, 224 / 2244Total Galaxy Groups to process: 1 with pairs : 1225
# Progress: Processing Galaxy Group ID 8794157, 1 / 1Total Galaxy Groups to process: 217 with pairs : 9444811
# Progress: Processing Galaxy Group ID 9677312, 217 / 2177Total Galaxy Groups to process: 1 with pairs : 903
# Progress: Processing Galaxy Group ID 20044919, 1 / 1Total Galaxy Groups to process: 170 with pairs : 5585845
# Progress: Processing Galaxy Group ID 9589125, 170 / 1700Total Galaxy Groups to process: 0 with pairs : 0
# Total Galaxy Groups to process: 104 with pairs : 2879295
# Progress: Processing Galaxy Group ID 9381209, 104 / 104Total Galaxy Groups to process: 0 with pairs : 0
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_for_gt150_vs_lt50_members_TNG300-1, TNG-Cluster

# %% [markdown]
# ## see what is causing assymetry plots

# %% [markdown]
# ### snapshot 99

# %%
#get the subhalos which are inconsistent with random
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(99)
random_MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000) # 1000 samples for each subhalo, for the three different projection angles #i.e. total of 3000 random MRL values for each subhalo, for the three different projection angles
MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_probablity_distribution_of_MRL_directionality(parallelize=False) #three MRL values for each subhalo, for the three different projection angles

(fraction, count, total, gg_indices_inconsistent) = GalaxyAnalysis.calculate_fraction_less_than_percentile(MRL_values=MRL_values, random_MRL_values=random_MRL_values, percentile=95)
# print(len(gg_indices_inconsistent), gg_indices_inconsistent)
# print(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups())
# Out:
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]s
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Progress: Processing Galaxy Group 632 / 632 with 428 satellites

# %%
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis
print(gg_indices_inconsistent)
print(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups())
#see what are the properties of the gg which are inconsistent with random at 99 percentile, and see if they have any common properties among their subhalos which might be driving the lopsidedness in the polar pairwise distribution, and also see if they have any common properties among themselves (e.g. mass, redshift, number of subhalos, etc.)
high_galaxy_groups = []
non_high_galaxy_groups = []
for i, gg in enumerate(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getAllGalaxyGroups()):
    if i not in gg_indices_inconsistent:
        print(f'Galaxy Group {i} is consistent with random at 95 percentile')
        non_high_galaxy_groups.append(gg)
        continue
    high_galaxy_groups.append(gg)
# Out:
# [0, 1, 2, 3, 4, 5, 6,
# Galaxy Group 49 is consistent with random at 95 percentile
# Galaxy Group 51 is consistent with random at 95 percentile
# Galaxy Group 53 is consistent with random at 95 percentile
# Galaxy Group 55 is consistent with random at 95 percentile
# Galaxy Group 56 is consistent with random at 95 percentile
# Galaxy Group 57 is consistent with random at 95 percentile
# Galaxy Group 59 is consistent with random at 95 percentile
# Galaxy Group 60 is consistent with random at 95 percentile
# Galaxy Group 61 is consistent with random at 95 percentile
# Galaxy Group 63 is consistent with random at 95 percentile
# Galaxy Group 66 is consistent with random at 95 percentile
# Galaxy Group 67 is consistent with random at 95 percentile
# Galaxy Group 70 is consistent with random at 95 percentile
# Galaxy Group 75 is consistent with random at 95 percentile
# Galaxy Group 76 is consistent with random at 95 percentile
# Galaxy Group 78 is consistent with random at 95 percentile
# Galaxy Group 80 is consistent with random at 95 percentile
# Galaxy Group 81 is consistent with random at 95 percentile
# Galaxy Group 82 is consistent with random at 95 percentile
# Galaxy Group 84 is consistent with random at 95 percentile
# Galaxy Group 88 is consistent with random at 95 percentile
# Galaxy Group 89 is consistent with random at 95 percentile
# Galaxy Group 90 is consistent with random at 95 percentile
# Galaxy Group 91 is consistent with random at 95 percentile
# Galaxy Group 93 is consistent with random at 95 percentile
# Galaxy Group 94 is consistent with random at 95 percentile
# Galaxy Group 95 is consistent with random at 95 percentile
# Galaxy Group 96 is consistent with random at 95 percentile
# Galaxy Group 97 is consistent with random at 95 percentile
# Galaxy Group 99 is consistent with random at 95 percentile
# Galaxy Group 104 is consistent with random at 95 percentile
# Galaxy Group 105 is consistent with random at 95 percentile
# Galaxy Group 109 is consistent with random at 95 percentile
# Galaxy Group 110 is consistent with random at 95 percentile
# Galaxy Group 112 is consistent with random at 95 percentile
# Galaxy Group 113 is consistent with random at 95 percentile
# Galaxy Group 114 is consistent with random at 95 percentile
# Galaxy Group 115 is consistent with random at 95 percentile
# Galaxy Group 117 is consistent with random at 95 percentile
# Galaxy Group 118 is consistent with random at 95 percentile
# Galaxy Group 119 is consistent with random at 95 percentile
# Galaxy Group 121 is consistent with random at 95 percentile
# Galaxy Group 122 is consistent with random at 95 percentile
# Galaxy Group 123 is consistent with random at 95 percentile
# Galaxy Group 124 is consistent with random at 95 percentile
# Galaxy Group 125 is consistent with random at 95 percentile
# Galaxy Group 127 is consistent with random at 95 percentile
# Galaxy Group 128 is consistent with random at 95 percentile
# Galaxy Group 129 is consistent with random at 95 percentile
# Galaxy Group 131 is consistent with random at 95 percentile
# Galaxy Group 133 is consistent with random at 95 percentile
# Galaxy Group 134 is consistent with random at 95 percentile
# Galaxy Group 137 is consistent with random at 95 percentile
# Galaxy Group 138 is consistent with random at 95 percentile
# Galaxy Group 139 is consistent with random at 95 percentile
# Galaxy Group 141 is consistent with random at 95 percentile
# Galaxy Group 142 is consistent with random at 95 percentile
# Galaxy Group 143 is consistent with random at 95 percentile
# Galaxy Group 144 is consistent with random at 95 percentile
# Galaxy Group 146 is consistent with random at 95 percentile
# Galaxy Group 147 is consistent with random at 95 percentile
# Galaxy Group 150 is consistent with random at 95 percentile
# Galaxy Group 151 is consistent with random at 95 percentile
# Galaxy Group 152 is consistent with random at 95 percentile
# Galaxy Group 153 is consistent with random at 95 percentile
# Galaxy Group 154 is consistent with random at 95 percentile
# Galaxy Group 155 is consistent with random at 95 percentile
# Galaxy Group 156 is consistent with random at 95 percentile
# Galaxy Group 157 is consistent with random at 95 percentile
# Galaxy Group 159 is consistent with random at 95 percentile
# Galaxy Group 160 is consistent with random at 95 percentile
# Galaxy Group 161 is consistent with random at 95 percentile
# Galaxy Group 163 is consistent with random at 95 percentile
# Galaxy Group 164 is consistent with random at 95 percentile
# Galaxy Group 165 is consistent with random at 95 percentile
# Galaxy Group 166 is consistent with random at 95 percentile
# Galaxy Group 169 is consistent with random at 95 percentile
# Galaxy Group 170 is consistent with random at 95 percentile
# Galaxy Group 171 is consistent with random at 95 percentile
# Galaxy Group 172 is consistent with random at 95 percentile
# Galaxy Group 173 is consistent with random at 95 percentile
# Galaxy Group 177 is consistent with random at 95 percentile
# Galaxy Group 182 is consistent with random at 95 percentile
# Galaxy Group 183 is consistent with random at 95 percentile
# Galaxy Group 184 is consistent with random at 95 percentile
# Galaxy Group 187 is consistent with random at 95 percentile
# Galaxy Group 188 is consistent with random at 95 percentile
# Galaxy Group 189 is consistent with random at 95 percentile
# Galaxy Group 190 is consistent with random at 95 percentile
# Galaxy Group 191 is consistent with random at 95 percentile
# Galaxy Group 192 is consistent with random at 95 percentile
# Galaxy Group 194 is consistent with random at 95 percentile
# Galaxy Group 195 is consistent with random at 95 percentile
# Galaxy Group 196 is consistent with random at 95 percentile
# Galaxy Group 198 is consistent with random at 95 percentile
# Galaxy Group 200 is consistent with random at 95 percentile
# Galaxy Group 201 is consistent with random at 95 percentile
# Galaxy Group 202 is consistent with random at 95 percentile
# Galaxy Group 203 is consistent with random at 95 percentile
# Galaxy Group 205 is consistent with random at 95 percentile
# Galaxy Group 206 is consistent with random at 95 percentile
# Galaxy Group 207 is consistent with random at 95 percentile
# Galaxy Group 208 is consistent with random at 95 percentile
# Galaxy Group 209 is consistent with random at 95 percentile
# Galaxy Group 212 is consistent with random at 95 percentile
# Galaxy Group 214 is consistent with random at 95 percentile
# Galaxy Group 215 is consistent with random at 95 percentile
# Galaxy Group 218 is consistent with random at 95 percentile
# Galaxy Group 219 is consistent with random at 95 percentile
# Galaxy Group 220 is consistent with random at 95 percentile
# Galaxy Group 221 is consistent with random at 95 percentile
# Galaxy Group 222 is consistent with random at 95 percentile
# Galaxy Group 223 is consistent with random at 95 percentile
# Galaxy Group 224 is consistent with random at 95 percentile
# Galaxy Group 228 is consistent with random at 95 percentile
# Galaxy Group 230 is consistent with random at 95 percentile
# Galaxy Group 231 is consistent with random at 95 percentile
# Galaxy Group 233 is consistent with random at 95 percentile
# Galaxy Group 234 is consistent with random at 95 percentile
# Galaxy Group 235 is consistent with random at 95 percentile
# Galaxy Group 237 is consistent with random at 95 percentile
# Galaxy Group 241 is consistent with random at 95 percentile
# Galaxy Group 242 is consistent with random at 95 percentile
# Galaxy Group 243 is consistent with random at 95 percentile
# Galaxy Group 245 is consistent with random at 95 percentile
# Galaxy Group 246 is consistent with random at 95 percentile
# Galaxy Group 247 is consistent with random at 95 percentile
# Galaxy Group 248 is consistent with random at 95 percentile
# Galaxy Group 249 is consistent with random at 95 percentile
# Galaxy Group 250 is consistent with random at 95 percentile
# Galaxy Group 251 is consistent with random at 95 percentile
# Galaxy Group 253 is consistent with random at 95 percentile
# Galaxy Group 254 is consistent with random at 95 percentile
# Galaxy Group 255 is consistent with random at 95 percentile
# Galaxy Group 257 is consistent with random at 95 percentile
# Galaxy Group 260 is consistent with random at 95 percentile
# Galaxy Group 262 is consistent with random at 95 percentile
# Galaxy Group 264 is consistent with random at 95 percentile
# Galaxy Group 265 is consistent with random at 95 percentile
# Galaxy Group 267 is consistent with random at 95 percentile
# Galaxy Group 269 is consistent with random at 95 percentile
# Galaxy Group 271 is consistent with random at 95 percentile
# Galaxy Group 272 is consistent with random at 95 percentile
# Galaxy Group 273 is consistent with random at 95 percentile
# Galaxy Group 274 is consistent with random at 95 percentile
# Galaxy Group 275 is consistent with random at 95 percentile
# Galaxy Group 284 is consistent with random at 95 percentile
# Galaxy Group 285 is consistent with random at 95 percentile
# Galaxy Group 286 is consistent with random at 95 percentile
# Galaxy Group 294 is consistent with random at 95 percentile
# Galaxy Group 295 is consistent with random at 95 percentile
# Galaxy Group 298 is consistent with random at 95 percentile
# Galaxy Group 300 is consistent with random at 95 percentile
# Galaxy Group 302 is consistent with random at 95 percentile
# Galaxy Group 303 is consistent with random at 95 percentile
# Galaxy Group 317 is consistent with random at 95 percentile
# Galaxy Group 324 is consistent with random at 95 percentile
# Galaxy Group 337 is consistent with random at 95 percentile
# Galaxy Group 338 is consistent with random at 95 percentile
# Galaxy Group 339 is consistent with random at 95 percentile
# Galaxy Group 343 is consistent with random at 95 percentile
# Galaxy Group 344 is consistent with random at 95 percentile
# Galaxy Group 345 is consistent with random at 95 percentile
# Galaxy Group 346 is consistent with random at 95 percentile
# Galaxy Group 347 is consistent with random at 95 percentile
# Galaxy Group 349 is consistent with random at 95 percentile
# Galaxy Group 351 is consistent with random at 95 percentile
# Galaxy Group 353 is consistent with random at 95 percentile
# Galaxy Group 356 is consistent with random at 95 percentile
# Galaxy Group 358 is consistent with random at 95 percentile
# Galaxy Group 360 is consistent with random at 95 percentile
# Galaxy Group 362 is consistent with random at 95 percentile
# Galaxy Group 366 is consistent with random at 95 percentile
# Galaxy Group 367 is consistent with random at 95 percentile
# Galaxy Group 368 is consistent with random at 95 percentile
# Galaxy Group 371 is consistent with random at 95 percentile
# Galaxy Group 375 is consistent with random at 95 percentile
# Galaxy Group 377 is consistent with random at 95 percentile
# Galaxy Group 378 is consistent with random at 95 percentile
# Galaxy Group 383 is consistent with random at 95 percentile
# Galaxy Group 387 is consistent with random at 95 percentile
# Galaxy Group 388 is consistent with random at 95 percentile
# Galaxy Group 391 is consistent with random at 95 percentile
# Galaxy Group 392 is consistent with random at 95 percentile
# Galaxy Group 396 is consistent with random at 95 percentile
# Galaxy Group 398 is consistent with random at 95 percentile
# Galaxy Group 402 is consistent with random at 95 percentile
# Galaxy Group 406 is consistent with random at 95 percentile
# Galaxy Group 408 is consistent with random at 95 percentile
# Galaxy Group 413 is consistent with random at 95 percentile
# Galaxy Group 415 is consistent with random at 95 percentile
# Galaxy Group 416 is consistent with random at 95 percentile
# Galaxy Group 423 is consistent with random at 95 percentile
# Galaxy Group 424 is consistent with random at 95 percentile
# Galaxy Group 428 is consistent with random at 95 percentile
# Galaxy Group 434 is consistent with random at 95 percentile
# Galaxy Group 435 is consistent with random at 95 percentile
# Galaxy Group 436 is consistent with random at 95 percentile
# Galaxy Group 437 is consistent with random at 95 percentile
# Galaxy Group 438 is consistent with random at 95 percentile
# Galaxy Group 442 is consistent with random at 95 percentile
# Galaxy Group 445 is consistent with random at 95 percentile
# Galaxy Group 447 is consistent with random at 95 percentile
# Galaxy Group 451 is consistent with random at 95 percentile
# Galaxy Group 456 is consistent with random at 95 percentile
# Galaxy Group 457 is consistent with random at 95 percentile
# Galaxy Group 462 is consistent with random at 95 percentile
# Galaxy Group 463 is consistent with random at 95 percentile
# Galaxy Group 464 is consistent with random at 95 percentile
# Galaxy Group 465 is consistent with random at 95 percentile
# Galaxy Group 466 is consistent with random at 95 percentile
# Galaxy Group 467 is consistent with random at 95 percentile
# Galaxy Group 473 is consistent with random at 95 percentile
# Galaxy Group 474 is consistent with random at 95 percentile
# Galaxy Group 475 is consistent with random at 95 percentile
# Galaxy Group 476 is consistent with random at 95 percentile
# Galaxy Group 479 is consistent with random at 95 percentile
# Galaxy Group 483 is consistent with random at 95 percentile
# Galaxy Group 486 is consistent with random at 95 percentile
# Galaxy Group 489 is consistent with random at 95 percentile
# Galaxy Group 491 is consistent with random at 95 percentile
# Galaxy Group 494 is consistent with random at 95 percentile
# Galaxy Group 498 is consistent with random at 95 percentile
# Galaxy Group 500 is consistent with random at 95 percentile
# Galaxy Group 501 is consistent with random at 95 percentile
# Galaxy Group 502 is consistent with random at 95 percentile
# Galaxy Group 505 is consistent with random at 95 percentile
# Galaxy Group 506 is consistent with random at 95 percentile
# Galaxy Group 507 is consistent with random at 95 percentile
# Galaxy Group 510 is consistent with random at 95 percentile
# Galaxy Group 511 is consistent with random at 95 percentile
# Galaxy Group 512 is consistent with random at 95 percentile
# Galaxy Group 513 is consistent with random at 95 percentile
# Galaxy Group 514 is consistent with random at 95 percentile
# Galaxy Group 515 is consistent with random at 95 percentile
# Galaxy Group 519 is consistent with random at 95 percentile
# Galaxy Group 520 is consistent with random at 95 percentile
# Galaxy Group 521 is consistent with random at 95 percentile
# Galaxy Group 524 is consistent with random at 95 percentile
# Galaxy Group 526 is consistent with random at 95 percentile
# Galaxy Group 528 is consistent with random at 95 percentile
# Galaxy Group 529 is consistent with random at 95 percentile
# Galaxy Group 530 is consistent with random at 95 percentile
# Galaxy Group 534 is consistent with random at 95 percentile
# Galaxy Group 538 is consistent with random at 95 percentile
# Galaxy Group 540 is consistent with random at 95 percentile
# Galaxy Group 543 is consistent with random at 95 percentile
# Galaxy Group 544 is consistent with random at 95 percentile
# Galaxy Group 549 is consistent with random at 95 percentile
# Galaxy Group 551 is consistent with random at 95 percentile
# Galaxy Group 553 is consistent with random at 95 percentile
# Galaxy Group 554 is consistent with random at 95 percentile
# Galaxy Group 555 is consistent with random at 95 percentile
# Galaxy Group 557 is consistent with random at 95 percentile
# Galaxy Group 559 is consistent with random at 95 percentile
# Galaxy Group 561 is consistent with random at 95 percentile
# Galaxy Group 562 is consistent with random at 95 percentile
# Galaxy Group 563 is consistent with random at 95 percentile
# Galaxy Group 570 is consistent with random at 95 percentile
# Galaxy Group 573 is consistent with random at 95 percentile
# Galaxy Group 577 is consistent with random at 95 percentile
# Galaxy Group 579 is consistent with random at 95 percentile
# Galaxy Group 585 is consistent with random at 95 percentile
# Galaxy Group 589 is consistent with random at 95 percentile
# Galaxy Group 593 is consistent with random at 95 percentile
# Galaxy Group 595 is consistent with random at 95 percentile
# Galaxy Group 607 is consistent with random at 95 percentile
# Galaxy Group 609 is consistent with random at 95 percentile
# Galaxy Group 610 is consistent with random at 95 percentile
# Galaxy Group 617 is consistent with random at 95 percentile
# Galaxy Group 619 is consistent with random at 95 percentile
# Galaxy Group 621 is consistent with random at 95 percentile
# Galaxy Group 623 is consistent with random at 95 percentile

# %%
high_list_galaxy_groups = ListGalaxyGroup(high_galaxy_groups)
non_high_list_galaxy_groups = ListGalaxyGroup(non_high_galaxy_groups)
print(f"high len: {len(high_list_galaxy_groups.getAllGalaxyGroups())}")
print(f"nonhigh len: {len(non_high_list_galaxy_groups.getAllGalaxyGroups())}")

#plot polar pairwise distribution for the high galaxy groups and the non-high galaxy groups, and see if the lopsidedness in the polar pairwise distribution is being really driven by just a few (which we won't see in mrl since its cluster by cluster).
high_nonhigh_polar_plot, high_nonhigh_fig, high_nonhigh_ax = galaxyAnalysisSnapshot.overlay_polar_pairwise_across_redshifts([
    [(high_list_galaxy_groups, "High GG (Inconsistent at 95% CL) Snapshot 99"),
    (non_high_list_galaxy_groups, "Non-High GG (Consistent at 95% CL) Snapshot 99")]],
    oneaxis=True, 
    include_metrics=True,
)

high_nonhigh_ax.legend(fontsize=8)

print("\nnow plotting MRL\n")

#plot MRL
high_nonhigh_MRL_plot, high_nonhigh_MRL_fig, high_nonhigh_MRL_ax = galaxyAnalysisSnapshot.overlayMRLAndMRLRandom([
    (high_list_galaxy_groups, "High GG (Inconsistent at 95% CL) Snapshot 99"),
    (non_high_list_galaxy_groups, "Non-High GG (Consistent at 95% CL) Snapshot 99")],
    filename='mrl_difference_high_nonhigh_snapshot_99', oneaxis=True, savefig=False, percentageMRL=95
)
# Out:
# high len: 330
# nonhigh len: 302
# COMPUTING FOR redshift index: 0, label: High GG (Inconsistent at 95% CL) Snapshot 99
# Total Galaxy Groups to process: 330 with pairs : 14589088
# Progress: Processing Galaxy Group ID 9956048, 330 / 33000.05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 99
# Total Galaxy Groups to process: 302 with pairs : 5211563
# Progress: Processing Galaxy Group ID 9363765, 302 / 30220.1
#
# now plotting MRL
#
# running label with list: 330
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.2697 (267/990)with 428 satellites
# running label with list: 302
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9890 (896/906)with 330 satellites

# %% [markdown]
# ### snapshot 50

# %%
#get the subhalos which are inconsistent with random
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(50)
random_MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000) # 1000 samples for each subhalo, for the three different projection angles #i.e. total of 3000 random MRL values for each subhalo, for the three different projection angles
MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_probablity_distribution_of_MRL_directionality(parallelize=False) #three MRL values for each subhalo, for the three different projection angles

(fraction, count, total, gg_indices_inconsistent) = GalaxyAnalysis.calculate_fraction_less_than_percentile(MRL_values=MRL_values, random_MRL_values=random_MRL_values, percentile=95)
# print(len(gg_indices_inconsistent), gg_indices_inconsistent)
# print(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups())
# Out:
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]s
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Progress: Processing Galaxy Group 137 / 137 with 191 satellites

# %%
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis
print(gg_indices_inconsistent)
print(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getNumGalaxyGroups())
#see what are the properties of the gg which are inconsistent with random at 99 percentile, and see if they have any common properties among their subhalos which might be driving the lopsidedness in the polar pairwise distribution, and also see if they have any common properties among themselves (e.g. mass, redshift, number of subhalos, etc.)
high_galaxy_groups = []
non_high_galaxy_groups = []
for i, gg in enumerate(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getAllGalaxyGroups()):
    if i not in gg_indices_inconsistent:
        print(f'Galaxy Group {i} is consistent with random at 95 percentile')
        non_high_galaxy_groups.append(gg)
        continue
    high_galaxy_groups.append(gg)
# Out:
# [0, 1, 3, 4, 5, 7, 9, 10, 11, 12, 13, 15, 16, 18, 19, 20, 21, 22, 23, 24, 25, 27, 29, 30, 31, 32, 33, 35, 37, 38, 41, 42, 44, 45, 46, 49, 51, 52, 53, 55, 56, 57, 58, 60, 61, 63, 64, 66, 67, 68, 69, 70, 71, 72, 74, 75, 78, 80, 83, 85, 86, 87, 88, 89, 90, 91, 92, 93, 95, 96, 97, 99, 100, 102, 104, 105, 106, 107, 109, 110, 111, 112, 115, 117, 119, 120, 121, 122, 124, 126, 127, 128, 129, 130, 131, 132, 135, 136]
# 137
# Galaxy Group 2 is consistent with random at 95 percentile
# Galaxy Group 6 is consistent with random at 95 percentile
# Galaxy Group 8 is consistent with random at 95 percentile
# Galaxy Group 14 is consistent with random at 95 percentile
# Galaxy Group 17 is consistent with random at 95 percentile
# Galaxy Group 26 is consistent with random at 95 percentile
# Galaxy Group 28 is consistent with random at 95 percentile
# Galaxy Group 34 is consistent with random at 95 percentile
# Galaxy Group 36 is consistent with random at 95 percentile
# Galaxy Group 39 is consistent with random at 95 percentile
# Galaxy Group 40 is consistent with random at 95 percentile
# Galaxy Group 43 is consistent with random at 95 percentile
# Galaxy Group 47 is consistent with random at 95 percentile
# Galaxy Group 48 is consistent with random at 95 percentile
# Galaxy Group 50 is consistent with random at 95 percentile
# Galaxy Group 54 is consistent with random at 95 percentile
# Galaxy Group 59 is consistent with random at 95 percentile
# Galaxy Group 62 is consistent with random at 95 percentile
# Galaxy Group 65 is consistent with random at 95 percentile
# Galaxy Group 73 is consistent with random at 95 percentile
# Galaxy Group 76 is consistent with random at 95 percentile
# Galaxy Group 77 is consistent with random at 95 percentile
# Galaxy Group 79 is consistent with random at 95 percentile
# Galaxy Group 81 is consistent with random at 95 percentile
# Galaxy Group 82 is consistent with random at 95 percentile
# Galaxy Group 84 is consistent with random at 95 percentile
# Galaxy Group 94 is consistent with random at 95 percentile
# Galaxy Group 98 is consistent with random at 95 percentile
# Galaxy Group 101 is consistent with random at 95 percentile
# Galaxy Group 103 is consistent with random at 95 percentile
# Galaxy Group 108 is consistent with random at 95 percentile
# Galaxy Group 113 is consistent with random at 95 percentile
# Galaxy Group 114 is consistent with random at 95 percentile
# Galaxy Group 116 is consistent with random at 95 percentile
# Galaxy Group 118 is consistent with random at 95 percentile
# Galaxy Group 123 is consistent with random at 95 percentile
# Galaxy Group 125 is consistent with random at 95 percentile
# Galaxy Group 133 is consistent with random at 95 percentile
# Galaxy Group 134 is consistent with random at 95 percentile

# %%
high_list_galaxy_groups = ListGalaxyGroup(high_galaxy_groups)
non_high_list_galaxy_groups = ListGalaxyGroup(non_high_galaxy_groups)
print(f"high len: {len(high_list_galaxy_groups.getAllGalaxyGroups())}")
print(f"nonhigh len: {len(non_high_list_galaxy_groups.getAllGalaxyGroups())}")

#plot polar pairwise distribution for the high galaxy groups and the non-high galaxy groups, and see if the lopsidedness in the polar pairwise distribution is being really driven by just a few (which we won't see in mrl since its cluster by cluster).
high_nonhigh_polar_plot, high_nonhigh_fig, high_nonhigh_ax = galaxyAnalysisSnapshot.overlay_polar_pairwise_across_redshifts([
    [(high_list_galaxy_groups, "High GG (Inconsistent at 95% CL) Snapshot 50"),
    (non_high_list_galaxy_groups, "Non-High GG (Consistent at 95% CL) Snapshot 50")]],
    oneaxis=True, 
    include_metrics=True,
)

high_nonhigh_ax.legend(fontsize=8)

print("\nnow plotting MRL\n")

#plot MRL
high_nonhigh_MRL_plot, high_nonhigh_MRL_fig, high_nonhigh_MRL_ax = galaxyAnalysisSnapshot.overlayMRLAndMRLRandom([
    (high_list_galaxy_groups, "High GG \n(Inconsistent at 95% CL) Snapshot 50"),
    (non_high_list_galaxy_groups, "Non-High GG \n(Consistent at 95% CL) Snapshot 50")],
    filename='mrl_difference_high_nonhigh_snapshot_50', oneaxis=True, savefig=False, percentageMRL=95
)
# Out:
# high len: 98
# nonhigh len: 39
# COMPUTING FOR redshift index: 0, label: High GG (Inconsistent at 95% CL) Snapshot 50
# Total Galaxy Groups to process: 98 with pairs : 2425221
# Progress: Processing Galaxy Group ID 9381209, 98 / 9880.05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 50
# Total Galaxy Groups to process: 39 with pairs : 746771
# Progress: Processing Galaxy Group ID 9062442, 39 / 3990.1
#
# now plotting MRL
#
# running label with list: 98
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.2585 (76/294)ith 191 satellites
# running label with list: 39
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9915 (116/117)th 154 satellites

# %% [markdown]
# ### separate by mass bins

# %%
#do but separate for each mass bin, and see if the high vs non-high difference is being driven by a particular mass bin
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(99)
mass_bin_labels = ['$1e13<M_{200}<1e13.5$', '$1e13.5<M_{200}<1e14$', '$1e14<M_{200}<1e14.5$', '$1e14.5<M_{200}<1e15$', '$M_{200}>1e15$']
mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
random_MRL_values_by_mass_bin = []
MRL_values_by_mass_bin = []
for mass_bin in mass_bins:
    random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000) # 1000 samples for each subhalo, for the three different projection angles #i.e. total of 3000 random MRL values for each subhalo, for the three different projection angles
    MRL_values = mass_bin.compute_probablity_distribution_of_MRL_directionality(parallelize=False) #three MRL values for each subhalo, for the three different projection angles
    random_MRL_values_by_mass_bin.append(random_MRL_values)
    MRL_values_by_mass_bin.append(MRL_values)
    
high_galaxy_groups_by_mass_bin = []
non_high_galaxy_groups_by_mass_bin = []
for i, mass_bin in enumerate(mass_bins):
    (fraction, count, total, gg_indices_inconsistent) = GalaxyAnalysis.calculate_fraction_less_than_percentile(MRL_values=MRL_values_by_mass_bin[i], random_MRL_values=random_MRL_values_by_mass_bin[i], percentile=95)
    high_galaxy_groups = []
    non_high_galaxy_groups = []
    for j, gg in enumerate(mass_bin.getAllGalaxyGroups()):
        if j not in gg_indices_inconsistent:
            print(f'Galaxy Group {j} in mass bin {mass_bin_labels[i]} is consistent with random at 95 percentile')
            non_high_galaxy_groups.append(gg)
            continue
        high_galaxy_groups.append(gg)
    high_list_galaxy_groups = ListGalaxyGroup(high_galaxy_groups)
    non_high_list_galaxy_groups = ListGalaxyGroup(non_high_galaxy_groups)
    high_galaxy_groups_by_mass_bin.append(high_list_galaxy_groups)
    non_high_galaxy_groups_by_mass_bin.append(non_high_list_galaxy_groups)
    print(f"Mass Bin {mass_bin_labels[i]}: high len: {len(high_list_galaxy_groups.getAllGalaxyGroups())}, nonhigh len: {len(non_high_list_galaxy_groups.getAllGalaxyGroups())}")
    
#plot polar pairwise distribution for the high galaxy groups and the non-high galaxy groups, and see if the lopsidedness in the polar pairwise distribution is being really driven by just a few (which we won't see in mrl since its cluster by cluster).
for i in range(len(mass_bin_labels)):
    high_nonhigh_polar_plot, high_nonhigh_fig, high_nonhigh_ax = galaxyAnalysisSnapshot.overlay_polar_pairwise_across_redshifts([
        [(high_galaxy_groups_by_mass_bin[i], f"High GG (Inconsistent at 95% CL) Snapshot 99, {mass_bin_labels[i]}"),
        (non_high_galaxy_groups_by_mass_bin[i], f"Non-High GG (Consistent at 95% CL) Snapshot 99, {mass_bin_labels[i]}")]],
        oneaxis=True, 
        include_metrics=True,
    )

    high_nonhigh_ax.legend(fontsize=8)

    print(f"\nnow plotting MRL for mass bin {mass_bin_labels[i]}\n")

    #plot MRL
    high_nonhigh_MRL_plot, high_nonhigh_MRL_fig, high_nonhigh_MRL_ax = galaxyAnalysisSnapshot.overlayMRLAndMRLRandom([
        (high_galaxy_groups_by_mass_bin[i], f"High GG \n(Inconsistent at 95% CL) Snapshot 99, {mass_bin_labels[i]}"),
        (non_high_galaxy_groups_by_mass_bin[i], f"Non-High GG \n(Consistent at 95% CL) Snapshot 99, {mass_bin_labels[i]}")],
        filename=f'mrl_difference_high_nonhigh_snapshot_99_{i}', oneaxis=True, savefig=False, percentageMRL=95
    )
# Out:
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]ss
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Galaxy Group 0 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 1 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 3 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 4 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 5 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 6 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 7 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 8 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 10 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 11 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 12 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 14 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 17 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 18 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 19 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 20 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 21 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 22 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 23 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 27 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 29 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 30 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 31 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 32 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 33 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 34 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 35 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 37 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 38 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 39 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 40 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 41 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 42 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 43 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 44 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 45 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 46 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 47 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 48 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 49 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 50 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 51 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 52 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 53 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 54 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 55 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 56 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 57 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 58 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group 59 in mass bin $1e13<M_{200}<1e13.5$ is consistent with random at 95 percentile
# Galaxy Group
05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 99, $1e13.5<M_{200}<1e14$
# Total Galaxy Groups to process: 684 with pairs : 266512
# Progress: Processing Galaxy Group ID 999, 684 / 68440.1
#
# now plotting MRL for mass bin $1e13.5<M_{200}<1e14$
#
# running label with list: 182
# Fraction of MRL values below the 95th percentile of random MRL values: 0.4249 (232/546)with 16 satellites
# running label with list: 684
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9956 (2043/2052)th 13 satellites
# COMPUTING FOR redshift index: 0, label: High GG (Inconsistent at 95% CL) Snapshot 99, $1e14<M_{200}<1e14.5$
# Total Galaxy Groups to process: 106 with pairs : 389853
# Progress: Processing Galaxy Group ID 19429412, 106 / 1060.05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 99, $1e14<M_{200}<1e14.5$
# Total Galaxy Groups to process: 186 with pairs : 585953
# Progress: Processing Galaxy Group ID 19441351, 186 / 1860.1
#
# now plotting MRL for mass bin $1e14<M_{200}<1e14.5$
#
# running label with list: 106
# Fraction of MRL values below the 95th percentile of random MRL values: 0.3553 (113/318)with 77 satellitess
# running label with list: 186
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9928 (554/558)with 60 satellitess
# COMPUTING FOR redshift index: 0, label: High GG (Inconsistent at 95% CL) Snapshot 99, $1e14.5<M_{200}<1e15$
# Total Galaxy Groups to process: 149 with pairs : 4366610
# Progress: Processing Galaxy Group ID 9720881, 149 / 14990.05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 99, $1e14.5<M_{200}<1e15$
# Total Galaxy Groups to process: 93 with pairs : 2055687
# Progress: Processing Galaxy Group ID 7474466, 93 / 9330.1
#
# now plotting MRL for mass bin $1e14.5<M_{200}<1e15$
#
# running label with list: 149
# Fraction of MRL values below the 95th percentile of random MRL values: 0.2550 (114/447)with 317 satellites
# running label with list: 93
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9928 (277/279)th 328 satellites
# COMPUTING FOR redshift index: 0, label: High GG (Inconsistent at 95% CL) Snapshot 99, $M_{200}>1e15$
# Total Galaxy Groups to process: 78 with pairs : 10044425
# Progress: Processing Galaxy Group ID 9956048, 78 / 7880.05
# COMPUTING FOR redshift index: 0, label: Non-High GG (Consistent at 95% CL) Snapshot 99, $M_{200}>1e15$
# Total Galaxy Groups to process: 20 with pairs : 2358123
# Progress: Processing Galaxy Group ID 9819553, 20 / 200.1
#
# now plotting MRL for mass bin $M_{200}>1e15$
#
# running label with list: 78
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 95th percentile of random MRL values: 0.2137 (50/234)ith 428 satellites
# running label with list: 20
# Fraction of MRL values below the 95th percentile of random MRL values: 0.9833 (59/60)with 379 satellites

# %%
# Replicate Cell 55, but for each mass bin.
# For each snapshot and each mass bin:
#   1) compute MRL inconsistency indices
#   2) split into High vs Non-High
#   3) plot polar asymmetry (N(<90) - N(>=90)) vs redshift

mass_bin_labels = [
    "$1e13<M_{200}<1e13.5$",
    "$1e13.5<M_{200}<1e14$",
    "$1e14<M_{200}<1e14.5$",
    "$1e14.5<M_{200}<1e15$",
    "$M_{200}>1e15$",
]

mass_bin_getters = [
    lambda ga: ga.filtered_gt13_ls13p5_list_of_galaxy_groups,
    lambda ga: ga.filtered_gt13p5_ls14_list_of_galaxy_groups,
    lambda ga: ga.filtered_gt14_ls14p5_list_of_galaxy_groups,
    lambda ga: ga.filtered_gt14p5_ls15_list_of_galaxy_groups,
    lambda ga: ga.filtered_gt15_list_of_galaxy_groups,
]

for bin_i, (mass_label, get_mass_bin) in enumerate(zip(mass_bin_labels, mass_bin_getters)):
    redshifts = []
    redshift_gg_bins: list[list[ListGalaxyGroup]] = []

    for snapshot_enum in allSnapshotEnums:
        snapshot_num = snapshot_enum[0]
        galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot_num)

        mass_bin = get_mass_bin(galaxyAnalysisSnapshot)
        if mass_bin.getNumGalaxyGroups() == 0:
            continue

        random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(
            parallelize=False,
            num_samples=1000,
        )
        MRL_values = mass_bin.compute_probablity_distribution_of_MRL_directionality(
            parallelize=False
        )

        (fraction, count, total, gg_indices_inconsistent) = GalaxyAnalysis.calculate_fraction_less_than_percentile(
            MRL_values=MRL_values,
            random_MRL_values=random_MRL_values,
            percentile=95,
        )

        high_galaxy_groups = []
        non_high_galaxy_groups = []
        inconsistent_set = set(gg_indices_inconsistent)
        for i, gg in enumerate(mass_bin.getAllGalaxyGroups()):
            if i in inconsistent_set:
                high_galaxy_groups.append(gg)
            else:
                non_high_galaxy_groups.append(gg)

        high_list_galaxy_groups = ListGalaxyGroup(high_galaxy_groups)
        non_high_list_galaxy_groups = ListGalaxyGroup(non_high_galaxy_groups)

        redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot_num][1])
        redshift_gg_bins.append([high_list_galaxy_groups, non_high_list_galaxy_groups])

    if len(redshifts) == 0:
        print(f"Skipping {mass_label}: no groups across snapshots")
        continue

    plotter, fig, ax, polar_pairwise_by_type_by_redshift = asymetryPlots(
        redshifts,
        listRedshiftGG=redshift_gg_bins,
        listGGLabels=[
            f"High GG (Inconsistent at 95% CL) — {mass_label}",
            f"Non-High GG (Consistent at 95% CL) — {mass_label}",
        ],
        plotRows=1,
        plotCols=1,
    )

    ax.set_title(f"Polar Pairwise Difference vs Redshift — High vs Non-High ({mass_label})")
    plotter.save_figure(
        fig,
        galaxyAnalysisSnapshot.scratchPlotDirc
        + f"/polar_pairwise_difference_vs_redshift_high_vs_nonhigh_massbin_{bin_i}_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}",
    )
# Out:
# Total Galaxy Groups to process: 444 with pairs : 26507tellitesr Galaxy Group 827 / 827 with 28 satelliteses
# Progress: Processing Galaxy Group ID 970, 444 / 4444Total Galaxy Groups to process: 2142 with pairs : 104801
# Progress: Processing Galaxy Group ID 993, 2142 / 21422Total Galaxy Groups to process: 433 with pairs : 34869
# Progress: Processing Galaxy Group ID 961, 433 / 4333Total Galaxy Groups to process: 1934 with pairs : 130286
# Progress: Processing Galaxy Group ID 996, 1934 / 19344Total Galaxy Groups to process: 457 with pairs : 48289
# Progress: Processing Galaxy Group ID 990, 457 / 4577Total Galaxy Groups to process: 1695 with pairs : 148318
# Progress: Processing Galaxy Group ID 1001, 1695 / 1695Total Galaxy Groups to process: 427 with pairs : 57844
# Progress: Processing Galaxy Group ID 999, 427 / 4277Total Galaxy Groups to process: 1512 with pairs : 167633
# Progress: Processing Galaxy Group ID 1000, 1512 / 1512Total Galaxy Groups to process: 432 with pairs : 78874
# Progress: Processing Galaxy Group ID 20045398, 432 / 432Total Galaxy Groups to process: 1333 with pairs : 185934
# Progress: Processing Galaxy Group ID 1003, 1333 / 1333Total Galaxy Groups to process: 443 with pairs : 107812
figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_high_vs_nonhigh_massbin_3_TNG300-1, TNG-Cluster
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]s
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# final: [np.float64(0.10178159166350641), np.float64(0.08176720603855406), np.float64(0.08886135895531226)]
# final: [np.float64(0.08723910280936222), np.float64(0.2362091438610991), np.float64(0.2634763048281343)]
# final: [np.float64(0.24335120537729815), np.float64(0.21682027909470164), np.float64(0.1599090838066422)]
# Total Galaxy Groups to process: 77 with pairs : 9945155ites for Galaxy Group 2 / 2 with 751 satellites
# Progress: Processing Galaxy Group ID 9956048, 77 / 777Total Galaxy Groups to process: 21 with pairs : 2457393
# Progress: Processing Galaxy Group ID 9363765, 21 / 21Total Galaxy Groups to process: 40 with pairs : 6406060
# Progress: Processing Galaxy Group ID 9557666, 40 / 40Total Galaxy Groups to process: 11 with pairs : 1464696
# Progress: Processing Galaxy Group ID 1772296, 11 / 11Total Galaxy Groups to process: 23 with pairs : 4076502
# Progress: Processing Galaxy Group ID 1791552, 23 / 23Total Galaxy Groups to process: 5 with pairs : 1116853
# Progress: Processing Galaxy Group ID 1617102, 5 / 5Total Galaxy Groups to process: 16 with pairs : 3425569
# Progress: Processing Galaxy Group ID 1630676, 16 / 16Total Galaxy Groups to process: 0 with pairs : 0
# Total Galaxy Groups to process: 7 with pairs : 1733352
# Progress: Processing Galaxy Group ID 1114731, 7 / 7Total Galaxy Groups to process: 1 with pairs : 226801
# Progress: Processing Galaxy Group ID 2570531, 1 / 1Total Galaxy Groups to process: 2 with pairs : 461925
# Progress: Processing Galaxy Group ID 3565276, 2 / 2Total Galaxy Groups to process: 0 with pairs : 0
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_high_vs_nonhigh_massbin_4_TNG300-1, TNG-Cluster

# %% [markdown]
# ### assymetry of high vs nonhigh

# %%
#make assymetry plots for the high galaxy groups and the non-high galaxy groups
# for snapshot_num in [50, 99]:
redshifts = []
redshift_mass_bins : list[list[ListGalaxyGroup]]= []

for snapshot_enum in allSnapshotEnums:
    snapshot_num = snapshot_enum[0]
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot_num)
    random_MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000) # 1000 samples for each subhalo, for the three different projection angles #i.e. total of 3000 random MRL values for each subhalo, for the three different projection angles
    MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_probablity_distribution_of_MRL_directionality(parallelize=False) #three MRL values for each subhalo, for the three different projection angles

    (fraction, count, total, gg_indices_inconsistent) = GalaxyAnalysis.calculate_fraction_less_than_percentile(MRL_values=MRL_values, random_MRL_values=random_MRL_values, percentile=95)
    high_galaxy_groups = []
    non_high_galaxy_groups = []
    for i, gg in enumerate(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.getAllGalaxyGroups()):
        if i not in gg_indices_inconsistent:
            non_high_galaxy_groups.append(gg)
            continue
        high_galaxy_groups.append(gg)

    high_list_galaxy_groups = ListGalaxyGroup(high_galaxy_groups)
    non_high_list_galaxy_groups = ListGalaxyGroup(non_high_galaxy_groups)
    
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot_num][1])
    redshift_mass_bins.append([high_list_galaxy_groups, non_high_list_galaxy_groups])
polarPairwiseDifference_plotter, polarPairwiseDifference_fig, polarPairwiseDifference_ax, polar_pairwise_by_type_by_redshift = asymetryPlots(redshifts, listRedshiftGG=redshift_mass_bins, listGGLabels=['High GG (Inconsistent at 95% CL)', 'Non-High GG (Consistent at 95% CL)'], plotRows=1, plotCols=1)
polarPairwiseDifference_ax.set_title('Polar Pairwise Difference vs Redshift for High vs Non-High Galaxy Groups')
polarPairwiseDifference_plotter.save_figure(polarPairwiseDifference_fig, galaxyAnalysisSnapshot.scratchPlotDirc + f'/polar_pairwise_difference_vs_redshift_for_high_vs_nonhigh_galaxy_groups_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}')
# Out:
# Progress: Processing random MRL distribution, samples:1000, for Galaxy Group 5 / 632 with 66 satellitess
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]s
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# final: [np.float64(0.07045621701195942), np.float64(0.08737062781987599), np.float64(0.027148921200896785)]
# final: [np.float64(0.04457546409561305), np.float64(0.11148411266146875), np.float64(0.13464093389144446)]
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]tes
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# final: [np.float64(0.10178159166350641), np.float64(0.08176720603855406), np.float64(0.08886135895531226)]
# final: [np.float64(0.08723910280936222), np.float64(0.2362091438610991), np.float64(0.2634763048281343)]
# final: [np.float64(0.13863870193693267), np.float64(0.11809557032938062), np.float64(0.07446720286031323)]
# final: [np.float64(0.24335120537729815), np.float64(0.21682027909470164), np.float64(0.1599090838066422)]
# final: [np.float64(0.07720842804377734), np.float64(0.11493837229877198), np.float64(0.15173163563535094)]
# final: [np.float64(0.08726924721024983), np.float64(0.29958337287907344), np.float64(0.3292444900693247)]
# final: [np.float64(0.15122848085944132), np.float64(0.18857702029690565), np.float64(0.13566882401263117)]
# final: [np.float64(0.1262600703847171), np.float64(0.13323402499521325), np.float64(0.10937229163236431)]
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]s
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Total Galaxy Groups to process: 334 with pairs : 14867803llites
# Progress: Processing Galaxy Group ID 9956048, 334 / 3344Total Galaxy Groups to process: 298 with pairs : 4932848
# Progress: Processing Galaxy Group ID 9819553, 298 / 2988Total Galaxy Groups to process: 320 with pairs : 12911556
# Progress: Processing Galaxy Group ID 9995792, 320 / 3200Total Galaxy Groups to process: 252 with pairs : 4616246
# Progress: Processing Galaxy Group ID 10060723, 252 / 252Total Galaxy Groups to process: 286 with pairs : 11220764
# Progress: Processing Galaxy Group ID 10050921, 286 / 286Total Galaxy Groups to process: 234 with pairs : 4413336
# Progress: Processing Galaxy Group ID 10118255, 234 / 234Total Galaxy Groups to process: 283 with pairs : 11294222
# Progress: Processing Galaxy Group ID 9951187, 283 / 2833Total Galaxy Groups to process: 192 with pairs : 2916373
# Progress: Processing Galaxy Group ID 9736794, 192 / 1922Total Galaxy Groups to process: 267 with pairs : 9745183
# Progress: Processing Galaxy Group ID 9624704, 267 / 2677Total Galaxy Groups to process: 155 with pairs : 2532118
# Progress: Processing Galaxy Group ID 1479238, 155 / 1555Total Galaxy Groups to process: 238 with pairs : 8079631
# Progress: Processing Galaxy Group ID 9601067, 238 / 2388Total Galaxy Groups to process: 130 with pairs : 2311000
# Progress: Processing Galaxy Group ID 9677312, 130 / 1300Total Galaxy Groups to process: 191 with pairs : 4939501
# Progress: Processing Galaxy Group ID 9589125, 191 / 1911Total Galaxy Groups to process: 77 with pairs : 1364605
# Progress: Processing Galaxy Group ID 9043227, 77 / 777Total Galaxy Groups to process: 97 with pairs : 2414195
# Progress: Processing Galaxy Group ID 9381209, 97 / 977Total Galaxy Groups to process: 40 with pairs : 757797
# Progress: Processing Galaxy Group ID 9062442, 40 / 400Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_pairwise_difference_vs_redshift_for_high_vs_nonhigh_galaxy_groups_TNG300-1, TNG-Cluster

# %% [markdown]
# ## median mass/members

# %%
#see how median mass changes with redshift for the full sample and for the 5 mass bins (should be relatively flat since we are binning by mass, but good to check)
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
import numpy as np
redshifts = []
median_mass_full_sample = []
median_mass_mass_bins = [[] for _ in range(len(mass_bin_labels))]

for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][1])
    
    # Full sample median mass
    all_masses = []
    for mass_bin in mass_bins:
        for gg in mass_bin.getAllGalaxyGroups():
            all_masses.append(gg.getMCrit200())
    if len(all_masses) > 0:
        median_mass_full_sample.append(float(np.median(all_masses)))
    else:        
        median_mass_full_sample.append(np.nan)
    # Mass bin median masses
    for i, mass_bin in enumerate(mass_bins):
        masses = [gg.getMCrit200() for gg in mass_bin.getAllGalaxyGroups()]
        if len(masses) > 0:
            median_mass_mass_bins[i].append(float(np.median(masses)))
        else:
            median_mass_mass_bins[i].append(np.nan)
mass_bin_median_mass_plotter = AstroPlotter()
mass_bin_median_mass_fig, mass_bin_median_mass_ax = mass_bin_median_mass_plotter.create_figure()
mass_bin_median_mass_ax.plot(
    redshifts,
    median_mass_full_sample,
    label='Median Mass, Full Sample',
    marker='o',
    linestyle='-',
    linewidth=1,
    markersize=3,
)
for i in range(len(mass_bin_labels)):
    mass_bin_median_mass_ax.plot(
        redshifts,
        median_mass_mass_bins[i],
        label=f'Median Mass, {mass_bin_labels[i]}',
        marker='o',
        linestyle='-',
        linewidth=1,
        markersize=3,
    )
mass_bin_median_mass_ax.set_xlabel('Redshift')
mass_bin_median_mass_ax.set_ylabel('Median M_200c [log M_sun]')
mass_bin_median_mass_ax.set_title('Median Mass vs Redshift for Full Sample and Mass Bins')
mass_bin_median_mass_ax.legend(fontsize=6)
mass_bin_median_mass_ax.set_yscale('log')
mass_bin_median_mass_plotter.save_figure(
    mass_bin_median_mass_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/median_mass_vs_redshift_for_full_sample_and_mass_bins_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Processing snapshot 99...
# Processing snapshot 91...
# Processing snapshot 84...
# Processing snapshot 78...
# Processing snapshot 72...
# Processing snapshot 67...
# Processing snapshot 59...
# Processing snapshot 50...
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/median_mass_vs_redshift_for_full_sample_and_mass_bins_TNG300-1, TNG-Cluster

# %%
# plot number of members in the clusters across redshift for the full sample and for the 5 mass bins
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
import numpy as np
redshifts = []
median_num_members_full_sample = []
median_num_members_mass_bins = [[] for _ in range(len(mass_bin_labels))]

for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
    print(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][0])
    redshifts.append(galaxyAnalysisSnapshot.snapshot_dic[snapshot[0]][0])
    
    # Full sample median number of members
    all_num_members = []
    for mass_bin in mass_bins:
        for gg in mass_bin.getAllGalaxyGroups():
            all_num_members.append(len(gg.getSatelliteSubhalos()))
    if len(all_num_members) > 0:
        median_num_members_full_sample.append(float(np.median(all_num_members)))
    else:
        median_num_members_full_sample.append(np.nan)
    
    # Mass bin median number of members
    for i, mass_bin in enumerate(mass_bins):
        num_members = [len(gg.getSatelliteSubhalos()) for gg in mass_bin.getAllGalaxyGroups()]
        if len(num_members) > 0:
            median_num_members_mass_bins[i].append(float(np.median(num_members)))
        else:
            median_num_members_mass_bins[i].append(np.nan)
            
mass_bin_median_num_members_plotter = AstroPlotter()
mass_bin_median_num_members_fig, mass_bin_median_num_members_ax = mass_bin_median_num_members_plotter.create_figure()
mass_bin_median_num_members_ax.plot(
    redshifts,
    median_num_members_full_sample,
    label='Median Number of Members, Full Sample',
    marker='o',
    linestyle='-',
    linewidth=1,
    markersize=3,
)
for i in range(len(mass_bin_labels)):
    mass_bin_median_num_members_ax.plot(
        redshifts,
        median_num_members_mass_bins[i],
        label=f'Median Number of Members, {mass_bin_labels[i]}',
        marker='o',
        linestyle='-',
        linewidth=1,
        markersize=3,
    )
mass_bin_median_num_members_ax.set_xlabel('Redshift')
mass_bin_median_num_members_ax.set_ylabel('Median Number of Members')
mass_bin_median_num_members_ax.set_title('Median Number of Members vs Redshift for Full Sample and Mass Bins')
mass_bin_median_num_members_ax.legend(fontsize=6)
mass_bin_median_num_members_ax.set_yscale('log')
mass_bin_median_num_members_plotter.save_figure(
    mass_bin_median_num_members_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/median_number_of_members_vs_redshift_for_full_sample_and_mass_bins_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Processing snapshot 99...
# Processing snapshot 91...
# Processing snapshot 84...
# Processing snapshot 78...
# Processing snapshot 72...
# Processing snapshot 67...
# Processing snapshot 59...
# Processing snapshot 50...
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/median_number_of_members_vs_redshift_for_full_sample_and_mass_bins_TNG300-1, TNG-Cluster

# %% [markdown]
# ## single polar piecewise plots

# %%
#make p(delta phi) plots for the 1e15 mass bin in snapshot 67
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
import numpy as np
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(67)
mass_bin = galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups
list_mass_1e15_polar_differences = []
for gg in mass_bin.getAllGalaxyGroups():
    list_mass_1e15_polar_differences.append(ListGalaxyGroup._compute_pairwise_for_group(gg))
    print(f"Processed group with M_200c = {gg.getMCrit200()} and {len(gg.getSatelliteSubhalos())} members")
    
list_mass_1e15_counts, list_mass_1e15_bin_centers, list_mass_1e15_errorbars = [], [], []
for polar_differences in list_mass_1e15_polar_differences:
     counts, bin_edges, errorbars = ListGalaxyGroup.get_histogram_bins(polar_differences, bins=np.arange(0, 185, 10), errorbarType='poisson', normalize_to_one=True)
     list_mass_1e15_counts.append(counts)
     list_mass_1e15_bin_centers.append(bin_edges)
     list_mass_1e15_errorbars.append(errorbars)
     
polarDifference_1e15_plotter = AstroPlotter()
polarDifference_1e15_fig, polarDifference_1e15_ax = polarDifference_1e15_plotter.create_figure(ncols=2, nrows=1, figsize=(10, 5))
for i, polar_differences in enumerate(list_mass_1e15_polar_differences):
    polarDifference_1e15_ax[i].errorbar(
        list_mass_1e15_bin_centers[i],
        list_mass_1e15_counts[i],
        yerr=list_mass_1e15_errorbars[i],
        label=f'Group {i}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
polarDifference_1e15_ax[0].set_xlabel('Pairwise Polar Difference (degrees)')
polarDifference_1e15_ax[0].set_ylabel('Probability Density')
polarDifference_1e15_ax[0].set_title('Pairwise Polar Difference Distribution for 1e15 Mass Bin, Snapshot 67')
polarDifference_1e15_ax[0].legend(fontsize=6)

#include MRL value and MRL fraction above 99% random MRL CL for each group in the 1e15 mass bin in snapshot 67 as a text box
for i, gg in enumerate(mass_bin.getAllGalaxyGroups()):
    MRL_value = ListGalaxyGroup._compute_MRL_for_group(gg)
    random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=100000)
    (MRL_fraction_above_99_CL, counts_above_99_CL, total_count, subhaloIndexInconsistentWithRandom), MRL_values, random_MRL_values = GalaxyAnalysis.getPercentOfClustersAboveRandomMRLCL(MRL_values = MRL_value, percentageMRL=99, random_mrl_values=random_MRL_values)
    
    textstr = f'Group {i}\nMRL xy: {MRL_value[0]:.2f} MRL yz: {MRL_value[1]:.2f}, MRL xz: {MRL_value[2]:.2f}\nFrac above 99% CL: {MRL_fraction_above_99_CL:.2f}\nCount above 99% CL: {counts_above_99_CL}/{total_count}'
    # place all group boxes on the right side of the second subplot, stacked vertically, right-aligned
    polarDifference_1e15_ax[1].text(
        0.98,
        0.93 - i * 0.15,
        textstr,
        transform=polarDifference_1e15_ax[1].transAxes,
        fontsize=8,
        ha='right',
        va='top',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.85),
    )
# polarDifference_1e15_ax[1].axis('off')
# polarDifference_1e15_ax[1].set_title('MRL and Fraction Above 99% CL for Each Group in 1e15 Mass Bin, Snapshot 67')
polarDifference_1e15_ax[1].legend(fontsize=6)
polarDifference_1e15_plotter.save_figure(
    polarDifference_1e15_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_difference_and_MRL_stats_for_1e15_mass_bin_snapshot_67_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Processed group with M_200c = 1008248471683072.0 and 600 members
# Processed group with M_200c = 1008924056616960.0 and 750 members
# Fraction of MRL values below the 99th percentile of random MRL values: 0.0000 (0/3)2 with 751 satellites
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6667 (2/3)2 with 751 satellites
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z0p5/plots/combinedTNG300-1_TNGCluster/polar_difference_and_MRL_stats_for_1e15_mass_bin_snapshot_67_TNG300-1, TNG-Cluster

# %%
#do the same for the 4 1e14.5-1e15 at snapshot 50
galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(50)
mass_bin = galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups
list_mass_14p5_15_polar_differences = []
for gg in mass_bin.getAllGalaxyGroups():
    list_mass_14p5_15_polar_differences.append(ListGalaxyGroup._compute_pairwise_for_group(gg))
    print(f"Processed group with M_200c = {gg.getMCrit200()} and {len(gg.getSatelliteSubhalos())} members")
list_mass_14p5_15_counts, list_mass_14p5_15_bin_centers, list_mass_14p5_15_errorbars = [], [], []
for polar_differences in list_mass_14p5_15_polar_differences:
     counts, bin_edges, errorbars = ListGalaxyGroup.get_histogram_bins(polar_differences, bins=np.arange(0, 185, 10), errorbarType='poisson', normalize_to_one=True)
     list_mass_14p5_15_counts.append(counts)
     list_mass_14p5_15_bin_centers.append(bin_edges)
     list_mass_14p5_15_errorbars.append(errorbars)
polarDifference_14p5_15_plotter = AstroPlotter()
polarDifference_14p5_15_fig, polarDifference_14p5_15_ax = polarDifference_14p5_15_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
for i, polar_differences in enumerate(list_mass_14p5_15_polar_differences):
    polarDifference_14p5_15_ax[i//2, i%2].errorbar(
        list_mass_14p5_15_bin_centers[i],
        list_mass_14p5_15_counts[i],
        yerr=list_mass_14p5_15_errorbars[i],
        label=f'Group {i}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    MRL_value = ListGalaxyGroup._compute_MRL_for_group(mass_bin.getAllGalaxyGroups()[i])
    random_MRL_values = mass_bin.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=100000)
    (MRL_fraction_above_99_CL, counts_above_99_CL, total_count, subhaloIndexInconsistentWithRandom), MRL_values, random_MRL_values = GalaxyAnalysis.getPercentOfClustersAboveRandomMRLCL(MRL_values = MRL_value, percentageMRL=99, random_mrl_values=random_MRL_values)
    
    textstr = f'Group {i}\nMRL xy: {MRL_value[0]:.2f} MRL yz: {MRL_value[1]:.2f}, MRL xz: {MRL_value[2]:.2f}\nFrac above 99% CL: {MRL_fraction_above_99_CL:.2f}\nCount above 99% CL: {counts_above_99_CL}/{total_count}'
    # place all group boxes on the right side of the second subplot, stacked vertically, right-aligned
    polarDifference_14p5_15_ax[i//2, i%2].text(
        0.98,
        0.93,
        textstr,
        transform=polarDifference_14p5_15_ax[i//2, i%2].transAxes,
        fontsize=8,
        ha='right',
        va='top',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.85),
    )
    polarDifference_14p5_15_ax[i//2, i%2].set_xlabel('Pairwise Polar Difference (degrees)')
    polarDifference_14p5_15_ax[i//2, i%2].set_ylabel('Probability Density')
    polarDifference_14p5_15_ax[i//2, i%2].set_title(f'Pairwise Polar Difference Distribution for \nGroup {i} in 1e14.5-1e15 Mass Bin, Snapshot 50')
    polarDifference_14p5_15_ax[i//2, i%2].legend(fontsize=6)
polarDifference_14p5_15_plotter.save_figure(
    polarDifference_14p5_15_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_difference_and_MRL_stats_for_1e14.5-1e15_mass_bin_snapshot_50_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Processed group with M_200c = 494967835328512.0 and 632 members
# Processed group with M_200c = 468957177839616.0 and 555 members
# Processed group with M_200c = 319796923072512.0 and 448 members
# Processed group with M_200c = 331614995349504.0 and 361 members
# Fraction of MRL values below the 99th percentile of random MRL values: 0.3333 (1/3)4 with 362 satellites
# Fraction of MRL values below the 99th percentile of random MRL values: 0.3333 (1/3)4 with 362 satellites
# Fraction of MRL values below the 99th percentile of random MRL values: 0.3333 (1/3)4 with 362 satellites
# Fraction of MRL values below the 99th percentile of random MRL values: 1.0000 (3/3)4 with 362 satellites
# Figure saved to: /scratch/poulin.al/lopsided/TNG300-1/z1p0/plots/combinedTNG300-1_TNGCluster/polar_difference_and_MRL_stats_for_1e14.5-1e15_mass_bin_snapshot_50_TNG300-1, TNG-Cluster

# %% [markdown]
# ## keep static mass groups

# %%
from myproject.utilities.snapshotEnum import SnapshotEnum
from myproject.utilities.plottingTools import AstroPlotter
from myproject.utilities.ListGalaxyGroup import ListGalaxyGroup
from myproject.redshiftGalaxyAnalysis import GalaxyAnalysis
from myproject.listRedshiftGalaxys import ListRedshiftGalaxy
import numpy as np

galaxyAnalysisSnapshot.setSnapshot(99)
mass_bins_ids_z0 = {}
mass_bins_ids_z0['gt13_ls13p5'] = [gg.getGroupID() for gg in galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups.getAllGalaxyGroups()]
mass_bins_ids_z0['gt13p5_ls14'] = [gg.getGroupID() for gg in galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups.getAllGalaxyGroups()]
mass_bins_ids_z0['gt14_ls14p5'] = [gg.getGroupID() for gg in galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups.getAllGalaxyGroups()]
mass_bins_ids_z0['gt14p5_ls15'] = [gg.getGroupID() for gg in galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups.getAllGalaxyGroups()]
mass_bins_ids_z0['gt15'] = [gg.getGroupID() for gg in galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups.getAllGalaxyGroups()]

# listGalaxyAnalysis = []
galaxyAnalysisSnapshotStaticMassBins = ListRedshiftGalaxy()

for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    
    mass_bins : list[ListGalaxyGroup]= [
        [],
        [],
        [],
        [],
        [],
    ]
    for gg in galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups.getAllGalaxyGroups():
        if gg.getGroupID() in mass_bins_ids_z0['gt13_ls13p5']:
            mass_bins[0].append(gg)
    for gg in galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups.getAllGalaxyGroups():
        if gg.getGroupID() in mass_bins_ids_z0['gt13p5_ls14']:
            mass_bins[1].append(gg)
    for gg in galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups.getAllGalaxyGroups():
        if gg.getGroupID() in mass_bins_ids_z0['gt14_ls14p5']:
            mass_bins[2].append(gg)
    for gg in galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups.getAllGalaxyGroups():
        if gg.getGroupID() in mass_bins_ids_z0['gt14p5_ls15']:
            mass_bins[3].append(gg)
    for gg in galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups.getAllGalaxyGroups():
        if gg.getGroupID() in mass_bins_ids_z0['gt15']:
            mass_bins[4].append(gg)
            
    for i, massgg in enumerate(mass_bins):
        mass_bins[i] = ListGalaxyGroup(massgg)
        
    print(f"Snapshot {snapshot[0]}: Mass bins have {[len(mass_bin.getAllGalaxyGroups()) for mass_bin in mass_bins]} groups respectively.")
        
    galaxyanalysis = GalaxyAnalysis(sim='TNG300-1, TNG-Cluster', snapshot=snapshot[0], luminosityType='Default', generalErrorbar='poisson', generalRewrite=True, loaded_list_of_galaxy_groupsRaw=mass_bins)
    
    galaxyAnalysisSnapshotStaticMassBins.addGalaxyAnalysis(galaxy_analysis=galaxyanalysis, snapshot_enum = snapshot[0])

# %% [markdown]
# # compile plots

# %%
# make four panel plot with the following:
# - top left: overall polar pairwise difference at z = 0
# - top right: overlay polar pairwise differences for z=0.2, 
# - bottom left: polar pairwise differences for z=0.5
# - bottom right: polar pairwise differences for z=1.0

pairwise_bins = np.arange(0, 180 + 10, 10)  # 5 degree bins from 0 to 180

polar_pairwise_differences_list_redshift, polar_pairwise_differences_bin_centers_list_redshift, polar_pairwise_differences_err_list_redshift = [], [], []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] not in [99, 84, 67, 50]: #only do the 4 redshifts we want to plot
        continue #skip other redshifts
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    list_polar_pairwise_difference_z0 = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_difference_z0, polar_pairwise_difference_z0_bin_centers, polar_pairwise_difference_z0_err = ListGalaxyGroup.get_histogram_bins(list_polar_pairwise_difference_z0, pairwise_bins, errorbarType='poisson')
    
    polar_pairwise_differences_list_redshift.append(polar_pairwise_difference_z0)
    polar_pairwise_differences_bin_centers_list_redshift.append(polar_pairwise_difference_z0_bin_centers)
    polar_pairwise_differences_err_list_redshift.append(polar_pairwise_difference_z0_err)

polar_pairwise_difference_overlay_plotter = AstroPlotter()
polar_pairwise_difference_overlay_fig, polar_pairwise_difference_overlay_ax = polar_pairwise_difference_overlay_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
redshift_labels = [0.0, 0.2, 0.5, 1.0]
for i in range(len(polar_pairwise_differences_list_redshift)):
    polar_pairwise_difference_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_differences_bin_centers_list_redshift[i],
        polar_pairwise_differences_list_redshift[i],
        yerr=polar_pairwise_differences_err_list_redshift[i],
        label=f'z={redshift_labels[i]}',
        marker='o',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_difference_overlay_ax[i//2, i%2].set_xlabel('Angle Difference (degrees)')
    polar_pairwise_difference_overlay_ax[i//2, i%2].set_ylabel('Count')
    polar_pairwise_difference_overlay_ax[i//2, i%2].set_title(f'Polar Pairwise Difference at z={redshift_labels[i]}')
    polar_pairwise_difference_overlay_ax[i//2, i%2].legend()
# Out:
# Processing snapshot 99...
# Total Galaxy Groups to process: 4084 with pairs : 20282142
# Progress: Processing Galaxy Group ID 9956048 / 40844Processing snapshot 84...
# Total Galaxy Groups to process: 3358 with pairs : 16307648
# Progress: Processing Galaxy Group ID 10118255 / 3358Processing snapshot 67...
# Total Galaxy Groups to process: 2424 with pairs : 11446938
# Progress: Processing Galaxy Group ID 9677312 / 24244Processing snapshot 50...
# Total Galaxy Groups to process: 1292 with pairs : 4809703
# Progress: Processing Galaxy Group ID 9381209 / 12922

# %%
# make two panel plot with the following:
# - top left: fraction of clusters above random MRL CL vs redshift for 99%, 95%, 90% CL
# - top right: normalized polar pairwise difference (N(<90º) - N(>=90º)) vs redshift for full sample and mass bins

mrl_bins = np.arange(0, 1.05, 0.05)  # 5% bins from 0 to 1
CL_bins = [99, 95, 90]
mrl_cl_data_list_redshift = []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mrl_cl_data_redshift = []
    for cl in CL_bins:
        random_MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000)
        (f_cl, c_cl, n_cl, _), _, _ = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, percentageMRL=cl, random_mrl_values=random_MRL_values)
        mrl_cl_data_redshift.append((f_cl, n_cl))
    mrl_cl_data_list_redshift.append(mrl_cl_data_redshift)
polar_pairwise_difference_norm_data_list_redshift = []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    mass_bins = [
        galaxyAnalysisSnapshot.filtered_gt13_ls13p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt13p5_ls14_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14_ls14p5_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt14p5_ls15_list_of_galaxy_groups,
        galaxyAnalysisSnapshot.filtered_gt15_list_of_galaxy_groups,
    ]
    full_angles = []
    for mass_bin in mass_bins:
        polarRawValues = mass_bin.compute_probablity_distribution_of_polar_differences()
        full_angles.extend(polarRawValues)
    stats_full = polar_lt90_ge90_stats_from_hist(full_angles, bin_size_deg=5.0)
    d, s = frac_diff_and_sigma(stats_full['frac_lt90'], stats_full['frac_ge90'], stats_full['total'], stats_full['n_lt90'], stats_full['n_ge90'], model=error_model)
    polar_pairwise_difference_norm_data_list_redshift.append((d, s))
two_panel_plotter = AstroPlotter()
two_panel_fig, two_panel_ax = two_panel_plotter.create_figure(ncols=2, nrows=1, figsize=(15, 5))
# Left panel: MRL CL
for i, cl in enumerate(CL_bins):
    f_cl_values = [data[i][0] for data in mrl_cl_data_list_redshift]
    n_cl_values = [data[i][1] for data in mrl_cl_data_list_redshift]
    err_cl_values = [binomial_sigma(f, n) for f, n in zip(f_cl_values, n_cl_values)]
    two_panel_ax[0].errorbar(
        redshifts,
        [1.0 - f for f in f_cl_values],
        yerr=err_cl_values,
        label=f'Fraction above random {cl}% CL',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
two_panel_ax[0].set_xlabel('Redshift')
two_panel_ax[0].set_ylabel('Fraction of MRL values above random percentile')
two_panel_ax[0].set_title('Fraction above random MRL CL vs Redshift')
two_panel_ax[0].legend(loc='upper left')
# Right panel: Polar pairwise difference normalized
d_values = [data[0] for data in polar_pairwise_difference_norm_data_list_redshift]
s_values = [data[1] for data in polar_pairwise_difference_norm_data_list_redshift]
two_panel_ax[1].errorbar(
    redshifts,
    d_values,
    yerr=s_values,
    label=f'Polar Pairwise Difference (Normalized), Full Sample [{error_model}]',
    marker='o',
    linestyle='-',
    capsize=2,
    elinewidth=1,
    linewidth=1,
    markersize=3,
)
two_panel_ax[1].set_xlabel('Redshift')
two_panel_ax[1].set_ylabel('Fraction(<90º) - Fraction(>=90º)')
two_panel_ax[1].set_title('Normalized Polar Pairwise Difference vs Redshift')
two_panel_ax[1].legend(fontsize=6)
two_panel_plotter.save_figure(
    two_panel_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/mrl_cl_and_polar_pairwise_difference_normalized_vs_redshift_full_sample_{error_model}_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)

# %%
# make four panel plot with the following for MRL distribution at 99% CL:
# - top left: z=0 MRL distribution for the full sample
# - top right: z=0.2
# - bottom left: z=0.5
# - bottom right: z=1.0

MRL_values_list_redshift, MRL_bin_centers_list_redshift, MRL_errors_list_redshift = [], [], []
for snapshot in SnapshotEnum.getAllSnapshots():
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] not in [99, 84, 67, 50]: #only do the 4 redshifts we want to plot
        continue #skip other redshifts
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    random_MRL_values = galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups.compute_MRL_random_distribution_curves_for_LGG(parallelize=False, num_samples=1000)
    (f_cl, c_cl, n_cl, MRL_values), MRL_bin_centers, MRL_errors = galaxyAnalysisSnapshot.getPercentOfClustersAboveRandomMRLCL(galaxyAnalysisSnapshot.filtered_gt14_list_of_galaxy_groups, percentageMRL=99, random_mrl_values=random_MRL_values)
    
    MRL_values_list_redshift.append(MRL_values)
    MRL_bin_centers_list_redshift.append(MRL_bin_centers)
    MRL_errors_list_redshift.append(MRL_errors)
    
MRL_distribution_overlay_plotter = AstroPlotter()
MRL_distribution_overlay_fig, MRL_distribution_overlay_ax = MRL_distribution_overlay_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
redshift_labels = [0.0, 0.2, 0.5, 1.0]
for i in range(len(MRL_values_list_redshift)):
    MRL_distribution_overlay_ax[i//2, i%2].errorbar(
        MRL_bin_centers_list_redshift[i],
        MRL_values_list_redshift[i],
        yerr=MRL_errors_list_redshift[i],
        label=f'z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    MRL_distribution_overlay_ax[i//2, i%2].set_xlabel('MRL Value')
    MRL_distribution_overlay_ax[i//2, i%2].set_ylabel('Fraction of Clusters Above Random MRL CL')
    MRL_distribution_overlay_ax[i//2, i%2].set_title(f'MRL Distribution at z={redshift_labels[i]}')
    MRL_distribution_overlay_ax[i//2, i%2].legend()
MRL_distribution_overlay_plotter.save_figure(
    MRL_distribution_overlay_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/mrl_distribution_at_99_CL_overlay_for_redshifts_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
# Out:
# Processing snapshot 99...
# final: [np.float64(0.07055262092751405), np.float64(0.06882863379814345), np.float64(0.0791280534930706)]
# final: [np.float64(0.06258291970169315), np.float64(0.08903413663791833), np.float64(0.0892243707794891)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.7268 (1378/1896)
# Processing snapshot 84...
# final: [np.float64(0.07407873219552794), np.float64(0.1490439529890689), np.float64(0.135591915397977)]
# final: [np.float64(0.07639660348812406), np.float64(0.0250205135474481), np.float64(0.03310036231362333)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6981 (1089/1560)
# Processing snapshot 67...
# final: [np.float64(0.07720842804377734), np.float64(0.11493837229877198), np.float64(0.15173163563535094)]
# final: [np.float64(0.08726924721024983), np.float64(0.29958337287907344), np.float64(0.3292444900693247)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.6313 (697/1104)
# Processing snapshot 50...
# final: [np.float64(0.21950132912741394), np.float64(0.1909765970003609), np.float64(0.09771630873771779)]
# final: [np.float64(0.1466120670381405), np.float64(0.1394453313515473), np.float64(0.1387503304018235)]
# Fraction of MRL values below the 99th percentile of random MRL values: 0.5864 (241/411)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 26
#      24 redshift_labels = [0.0, 0.2, 0.5, 1.0]
#      25 for i in range(len(MRL_values_list_redshift)):
# ---> 26     MRL_distribution_overlay_ax[i//2, i%2].errorbar(
#      27         MRL_bin_centers_list_redshift[i],
#      28         MRL_values_list_redshift[i],
#      29         yerr=MRL_errors_list_redshift[i],
#      30         label=f'z={redshift_labels[i]}',
#      31         marker='o',
#      32         linestyle='-',
#      33         capsize=2,
#      34         elinewidth=1,
#      35         linewidth=1,
#      36         markersize=3,
#      37     )
#      38     MRL_distribution_overlay_ax[i//2, i%2].set_xlabel('MRL Value')
#      39     MRL_distribution_overlay_ax[i//2, i%2].set_ylabel('Fraction of Clusters Above Random MRL CL')
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/.conda/envs/myenv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:3712, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3710 x, y = np.atleast_1d(x, y)  # Make sure all the args are iterable.
#    3711 if len(x) != len(y):
# -> 3712     raise ValueError("'x' and 'y' must have the same size")
#    3714 everymask = self._errorevery_to_mask(x, errorevery)
#    3716 label = kwargs.pop("label", None)
#
# ValueError: 'x' and 'y' must have the same size

# %%
# make four panel plot with the following for overlay polar difference of member gt150 lt50
# - top right: z=0
# - top left: z= 0.2
# - bottom left: z=0.5
# - bottom right: z=1.0

pairwise_bins = np.arange(0, 180 + 5, 5)  # 5 degree bins from 0 to 180

polar_pairwise_gt150_list_redshift, polar_pairwise_gt150_bin_centers_list_redshift, polar_pairwise_gt150_err_list_redshift = [], [], []
polar_pairwise_lt50_list_redshift, polar_pairwise_lt50_bin_centers_list_redshift, polar_pairwise_lt50_err_list_redshift = [], [], []
for snapshot in SnapshotEnum:
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] not in [99, 84, 67, 50]: #only do the 4 redshifts we want to plot
        continue #skip other redshifts
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    list_galaxy_groups_gt150 = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(minNumGalaxies=150)
    list_galaxy_groups_lt50 = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(maxNumGalaxies=50)
    
    polarRawValues_gt150 = list_galaxy_groups_gt150.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_gt150, polar_pairwise_gt150_bin_centers, polar_pairwise_gt150_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_gt150, pairwise_bins, errorbarType='poisson')
    
    polarRawValues_lt50 = list_galaxy_groups_lt50.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_lt50, polar_pairwise_lt50_bin_centers, polar_pairwise_lt50_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_lt50, pairwise_bins, errorbarType='poisson')
    
    polar_pairwise_gt150_list_redshift.append(polar_pairwise_gt150)
    polar_pairwise_gt150_bin_centers_list_redshift.append(polar_pairwise_gt150_bin_centers)
    polar_pairwise_gt150_err_list_redshift.append(polar_pairwise_gt150_err)
    
    polar_pairwise_lt50_list_redshift.append(polar_pairwise_lt50)
    polar_pairwise_lt50_bin_centers_list_redshift.append(polar_pairwise_lt50_bin_centers)
    polar_pairwise_lt50_err_list_redshift.append(polar_pairwise_lt50_err)
    
polar_pairwise_overlay_plotter = AstroPlotter()
polar_pairwise_overlay_fig, polar_pairwise_overlay_ax = polar_pairwise_overlay_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
redshift_labels = [0.2, 0.0, 0.5, 1.0]
for i in range(len(polar_pairwise_gt150_list_redshift)):
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_gt150_bin_centers_list_redshift[i],
        polar_pairwise_gt150_list_redshift[i],
        yerr=polar_pairwise_gt150_err_list_redshift[i],
        label=f'>150 members, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_lt50_bin_centers_list_redshift[i],
        polar_pairwise_lt50_list_redshift[i],
        yerr=polar_pairwise_lt50_err_list_redshift[i],
        label=f'<50 members, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].set_xlabel('Angle Difference (degrees)')
    polar_pairwise_overlay_ax[i//2, i%2].set_ylabel('Count')
    polar_pairwise_overlay_ax[i//2, i%2].set_title(f'Polar Pairwise Difference at z={redshift_labels[i]}')
    polar_pairwise_overlay_ax[i//2, i%2].legend()
polar_pairwise_overlay_plotter.save_figure(
    polar_pairwise_overlay_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_pairwise_difference_overlay_gt150_lt50_for_redshifts_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)

# %%
# make four panel plot with the following for overlay polar difference of radius gt0p65 lt0p35
# - top right: z=0
# - top left: z= 0.2
# - bottom left: z=0.5
# - bottom right: z=1.0

pairwise_bins = np.arange(0, 180 + 5, 5)  # 5 degree bins from 0 to 180

polar_pairwise_gt0p65_list_redshift, polar_pairwise_gt0p65_bin_centers_list_redshift, polar_pairwise_gt0p65_err_list_redshift = [], [], []
polar_pairwise_lt0p35_list_redshift, polar_pairwise_lt0p35_bin_centers_list_redshift, polar_pairwise_lt0p35_err_list_redshift = [], [], []
for snapshot in SnapshotEnum:
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] not in [99, 84, 67, 50]: #only do the 4 redshifts we want to plot
        continue #skip other redshifts
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    list_galaxy_groups_gt0p65 = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(withinXPercentR200=[0.65, 1.0])
    list_galaxy_groups_lt0p35 = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(withinXPercentR200=[0.0, 0.35])
    
    polarRawValues_gt0p65 = list_galaxy_groups_gt0p65.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_gt0p65, polar_pairwise_gt0p65_bin_centers, polar_pairwise_gt0p65_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_gt0p65, pairwise_bins, errorbarType='poisson')
    
    polarRawValues_lt0p35 = list_galaxy_groups_lt0p35.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_lt0p35, polar_pairwise_lt0p35_bin_centers, polar_pairwise_lt0p35_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_lt0p35, pairwise_bins, errorbarType='poisson')
    
    polar_pairwise_gt0p65_list_redshift.append(polar_pairwise_gt0p65)
    polar_pairwise_gt0p65_bin_centers_list_redshift.append(polar_pairwise_gt0p65_bin_centers)
    polar_pairwise_gt0p65_err_list_redshift.append(polar_pairwise_gt0p65_err)
    
    polar_pairwise_lt0p35_list_redshift.append(polar_pairwise_lt0p35)
    polar_pairwise_lt0p35_bin_centers_list_redshift.append(polar_pairwise_lt0p35_bin_centers)
    polar_pairwise_lt0p35_err_list_redshift.append(polar_pairwise_lt0p35_err)

polar_pairwise_overlay_plotter = AstroPlotter()
polar_pairwise_overlay_fig, polar_pairwise_overlay_ax = polar_pairwise_overlay_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
redshift_labels = [0.2, 0.0, 0.5, 1.0]
for i in range(len(polar_pairwise_gt0p65_list_redshift)):       
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_gt0p65_bin_centers_list_redshift[i],
        polar_pairwise_gt0p65_list_redshift[i],
        yerr=polar_pairwise_gt0p65_err_list_redshift[i],
        label=f'>0.65 R200, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_lt0p35_bin_centers_list_redshift[i],
        polar_pairwise_lt0p35_list_redshift[i],
        yerr=polar_pairwise_lt0p35_err_list_redshift[i],
        label=f'<0.35 R200, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].set_xlabel('Angle Difference (degrees)')
    polar_pairwise_overlay_ax[i//2, i%2].set_ylabel('Count')
    polar_pairwise_overlay_ax[i//2, i%2].set_title(f'Polar Pairwise Difference at z={redshift_labels[i]}')
    polar_pairwise_overlay_ax[i//2, i%2].legend()
polar_pairwise_overlay_plotter.save_figure(
    polar_pairwise_overlay_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_pairwise_difference_overlay_gt0p65_lt0p35_for_redshifts_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)

# %%
# make four panel plot with the following for overlay polar difference of red blue galaxies
# - top right: z=0
# - top left: z= 0.2
# - bottom left: z=0.5
# - bottom right: z=1.0

pairwise_bins = np.arange(0, 180 + 5, 5)  # 5 degree bins from 0 to 180

polar_pairwise_red_list_redshift, polar_pairwise_red_bin_centers_list_redshift, polar_pairwise_red_err_list_redshift = [], [], []
polar_pairwise_blue_list_redshift, polar_pairwise_blue_bin_centers_list_redshift, polar_pairwise_blue_err_list_redshift = [], [], []
for snapshot in SnapshotEnum:
    if snapshot[0] < 45:
        continue #too high redshift
    if snapshot[0] not in [99, 84, 67, 50]: #only do the 4 redshifts we want to plot
        continue #skip other redshifts
    print(f"Processing snapshot {snapshot[0]}...")
    galaxyAnalysisSnapshot = listRedshiftGalaxyAnalysis.getGalaxyAnalysisSnapshot(snapshot[0])
    list_galaxy_groups_red = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(redDefaultGalaxies=True)
    list_galaxy_groups_blue = galaxyAnalysisSnapshot.loaded_list_of_galaxy_groups.getFilterSubhalos(blueDefaultGalaxies=True)
    
    polarRawValues_red = list_galaxy_groups_red.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_red, polar_pairwise_red_bin_centers, polar_pairwise_red_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_red, pairwise_bins, errorbarType='poisson')
    
    polarRawValues_blue = list_galaxy_groups_blue.compute_probablity_distribution_of_polar_differences()
    polar_pairwise_blue, polar_pairwise_blue_bin_centers, polar_pairwise_blue_err = ListGalaxyGroup.get_histogram_bins(polarRawValues_blue, pairwise_bins, errorbarType='poisson')
    
    polar_pairwise_red_list_redshift.append(polar_pairwise_red)
    polar_pairwise_red_bin_centers_list_redshift.append(polar_pairwise_red_bin_centers)
    polar_pairwise_red_err_list_redshift.append(polar_pairwise_red_err)
    
    polar_pairwise_blue_list_redshift.append(polar_pairwise_blue)
    polar_pairwise_blue_bin_centers_list_redshift.append(polar_pairwise_blue_bin_centers)
    polar_pairwise_blue_err_list_redshift.append(polar_pairwise_blue_err)
    
polar_pairwise_overlay_plotter = AstroPlotter()
polar_pairwise_overlay_fig, polar_pairwise_overlay_ax = polar_pairwise_overlay_plotter.create_figure(ncols=2, nrows=2, figsize=(10, 10))
redshift_labels = [0.2, 0.0, 0.5, 1.0]
for i in range(len(polar_pairwise_red_list_redshift)):
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_red_bin_centers_list_redshift[i],
        polar_pairwise_red_list_redshift[i],
        yerr=polar_pairwise_red_err_list_redshift[i],
        label=f'Red Galaxies, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].errorbar(
        polar_pairwise_blue_bin_centers_list_redshift[i],
        polar_pairwise_blue_list_redshift[i],
        yerr=polar_pairwise_blue_err_list_redshift[i],
        label=f'Blue Galaxies, z={redshift_labels[i]}',
        marker='o',
        linestyle='-',
        capsize=2,
        elinewidth=1,
        linewidth=1,
        markersize=3,
    )
    polar_pairwise_overlay_ax[i//2, i%2].set_xlabel('Angle Difference (degrees)')
    polar_pairwise_overlay_ax[i//2, i%2].set_ylabel('Count')
    polar_pairwise_overlay_ax[i//2, i%2].set_title(f'Polar Pairwise Difference at z={redshift_labels[i]}')
    polar_pairwise_overlay_ax[i//2, i%2].legend()
polar_pairwise_overlay_plotter.save_figure(
    polar_pairwise_overlay_fig,
    galaxyAnalysisSnapshot.scratchPlotDirc
    + f'/polar_pairwise_difference_overlay_red_blue_for_redshifts_{galaxyAnalysisSnapshot.sim}{galaxyAnalysisSnapshot.plotEndingFormat}',
)
